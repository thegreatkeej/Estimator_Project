# %%
# Dependencies
from config import homeDepot_API
from serpapi import GoogleSearch
import pandas as pd
import numpy as np
from datetime import datetime
import os
os.getcwd()
# Out:
# 'C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\Resources'

# %% [markdown]
# STEP 1: EXTRACT

# %%
# Created Working 'Material Description by grabbing names from Home Depot'

common_name = []

ids = ['100400409', '100400406', '100137321', '100400405', 
       '202241090', '100144234', '202077145', '202077147', 
       '202288508', '202304774', '202304649', '202304645', 
       '202019377', '202316275', '202019375', '202316276']

for i in ids:

    params = {
      "engine": "home_depot_product",
      "product_id": i,
      "api_key": homeDepot_API
    }

    search = GoogleSearch(params)
    results = search.get_dict()
    products = results['product_results']
    
    common_name.append(products['title'])
# Out:
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search

# %%
# Order and establish index_name

index_name = []

index_name.append(common_name[3])
index_name.append(common_name[1])
index_name.append(common_name[0])
index_name.append(common_name[5])
index_name.append(common_name[8])
index_name.append(common_name[4])
index_name.append(common_name[2])
index_name.append(common_name[6])
index_name.append(common_name[7])
index_name.append(common_name[12])
index_name.append(common_name[13])
index_name.append(common_name[14])
index_name.append(common_name[15])
index_name.append(common_name[9])
index_name.append(common_name[10])
index_name.append(common_name[11])

#index_name

# %%
def searcher(Q, R):
    params = {
      "engine": "google",
      "q": Q,
      "api_key": homeDepot_API
    }
    search = GoogleSearch(params)
    results = search.get_dict()
    products = results["organic_results"]
   
    for p in products[0:10]:
        try:

            title = p['title']
            link = p['link']
            price = (p['rich_snippet']['top']['detected_extensions']['price'])            
    
            result = {'Manufactures Description': title, 'Link': link, 'Material Price': price, 'VENDOR': link}
            R.append(result)
                        
        except (KeyError):
            price = 'NaN'
            result = {'Manufactures Description': title, 'Link': link, 'Material Price': price, 'VENDOR': link}
            R.append(result)

# %% [markdown]
# STEP 2: TRANSFORM

# %%
# Grab raw data

R = []
for i in range(16):
    R_i = []
   
    searcher(index_name[i], R_i)
    R.append(R_i)
# Out:
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search

# %%
# Create a data frame
all_prices = []
lowest_prices = []
for i in range(len(R)):
    df = pd.DataFrame(R[i]).assign(Common_name=index_name[i])
# Create a 'Vendor location' column    
    df['Vendor Location'] = (np.where(df['VENDOR'].str.contains('.'), df['VENDOR'].str.split('.').str[1], df['VENDOR']))
    df.drop(columns =['VENDOR'], inplace = True)
# Change data type of price to numeric and drop NaN's    
    df['Material Price'] = df['Material Price'].apply(pd.to_numeric, args=('coerce',))
    df.dropna(inplace=True)
# Filter out scaling issues
    if i == 0:
        df.drop(df[df['Material Price'] < .77].index, inplace = True)
    if i == 1 or i == 2:
        df.drop(df[df['Material Price'] > 130].index, inplace = True)
        df.drop(df[df['Material Price'] < 2.60].index, inplace = True)
    if i == 4:
        df.drop(df[df['Material Price'] > 130].index, inplace = True)
    if i == 5 or i == 8:
        df.drop(df[df['Material Price'] > 5.98].index, inplace = True)
    if i == 9:
        df.drop(df[df['Material Price'] < 80].index, inplace = True)
    if i == 11 or i == 12:
        df.drop(df[df['Material Price'] < 130].index, inplace = True)
    if i == 13:
        df.drop(df[df['Material Price'] < 500].index, inplace = True)
    if i == 14 or i == 15:
        df.drop(df[df['Material Price'] < 2.60].index, inplace = True)
    df.drop(columns =['Manufactures Description'], inplace = True)
    df['Material Description'] = df['Common_name']
    df.drop(columns =['Common_name'], inplace = True)
    df = df.iloc[:,[3,1,2,0]]
    
    df["Formatted Datetime"] = datetime.now().strftime("%m/%d/%Y %H:%M:%S")
    
    lowest_prices.append(df.min())
    all_prices.append(df)
clean_df = pd.concat(all_prices, axis=0, ignore_index=True)
working_df = pd.DataFrame(lowest_prices)

# %%
clean_df
# Out:
#                                  Material Description  Material Price  \
# 0   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            7.22
# 1   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            5.99
# 2   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            4.73
# 3   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            5.88
# 4   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           11.91
# 5   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           10.47
# 6   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...            8.36
# 7   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...            8.90
# 8   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           33.34
# 9   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           98.99
# 10  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            3.98
# 11  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            5.99
# 12  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            2.10
# 13  3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 14  1 in. Electric Metallic Tube (EMT) Set-Screw C...            1.15
# 15  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            3.98
# 16  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 17  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 18  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            2.29
# 19     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          114.00
# 20     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          128.62
# 21     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire           87.99
# 22  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          158.00
# 23  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          159.00
# 24  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          159.00
# 25  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          227.29
# 26  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          289.00
# 27  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          289.00
# 28  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          339.09
# 29    500 ft. 4 Gauge Black Stranded Copper THHN Wire          613.64
# 30    500 ft. 4 Gauge Black Stranded Copper THHN Wire          787.00
# 31    500 ft. 4 Gauge Black Stranded Copper THHN Wire         1047.78
# 32    500 ft. 6 Gauge Black Stranded Copper THHN Wire          445.81
# 33   500 ft. 10 Gauge Black Stranded Copper THHN Wire          156.00
# 34   500 ft. 10 Gauge Black Stranded Copper THHN Wire          156.49
# 35   500 ft. 10 Gauge Black Stranded Copper THHN Wire          398.95
#
#                                       Vendor Location  \
# 0                                           homedepot
# 1                                               lowes
# 2                                gordonelectricsupply
# 3                                         supplyworks
# 4                                           homedepot
# 5                                            ebarnett
# 6                                gordonelectricsupply
# 7                                       linemen-tools
# 8                                          dkhardware
# 9                                              amazon
# 10                                          homedepot
# 11                                             amazon
# 12                                             wilmar
# 13                                          pinterest
# 14                                          homedepot
# 15                                          homedepot
# 16                                             amazon
# 17                                              lowes
# 18                                             wilmar
# 19                                             amazon
# 20                                               ebay
# 21  com/p/solid-romex-simpull-cu-nm-b-wire-0328861...
# 22                                          homedepot
# 23                                              lowes
# 24                                          homedepot
# 25                                               ebay
# 26                                          homedepot
# 27                                              lowes
# 28                                           qcsupply
# 29                                             amazon
# 30                                          homedepot
# 31                                               ebay
# 32                                               ebay
# 33                                          homedepot
# 34                                             amazon
# 35                                    cooper-electric
#
#                                                  Link   Formatted Datetime
# 0   https://www.homedepot.com/p/1-2-in-x-10-ft-Ele...  10/22/2022 20:22:06
# 1   https://www.lowes.com/pd/Common-1-2-in-Actual-...  10/22/2022 20:22:06
1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            4.73
# 1   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...            8.36
# 2   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...            8.90
# 3   1/2 in. Electric Metallic Tube (EMT) Set-Screw...            2.10
# 4   3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 5   1 in. Electric Metallic Tube (EMT) Set-Screw C...            1.15
# 6   1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            2.29
# 7                                                 NaN             NaN
# 8                                                 NaN             NaN
# 9      250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire           87.99
# 10  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          158.00
# 11  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          159.00
# 12  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          289.00
# 13    500 ft. 4 Gauge Black Stranded Copper THHN Wire          613.64
# 14    500 ft. 6 Gauge Black Stranded Copper THHN Wire          445.81
# 15   500 ft. 10 Gauge Black Stranded Copper THHN Wire          156.00
#
#          Vendor Location                                               Link  \
# 0   gordonelectricsupply  https://www.gordonelectricsupply.com/p/Allied-...
# 1               ebarnett  https://www.ebarnett.com/Sku/2487616/34-in-x-1...
# 2                 amazon  https://www.amazon.com/EMT-Conduit-10-ft-Steel...
# 3                 amazon  https://www.amazon.com/Halex-26270-STEEL-CONNE...
# 4              pinterest  https://www.pinterest.com/pin/230668812499210604/
# 5              homedepot  https://www.homedepot.com/p/Halex-1-in-Electri...
# 6                 amazon  https://www.amazon.com/Halex-26270-STEEL-CONNE...
# 7                    NaN                                                NaN
# 8                    NaN                                                NaN
# 9                 amazon  https://celebrationhardware.com/p/solid-romex-...
# 10             homedepot  https://www.homedepot.com/p/Southwire-250-ft-1...
# 11                  ebay              https://www.ebay.com/itm/313961378086
# 12             homedepot  https://www.homedepot.com/p/Southwire-250-ft-1...
# 13                amazon  https://www.amazon.com/SOUTHWIRE-COMPANY-LL-20...
# 14                  ebay              https://www.ebay.com/itm/203860011450
# 15                amazon  https://www.amazon.com/Gauge-Stranded-Copper-B...
#
#      Formatted Datetime
# 0   10/22/2022 20:22:06
# 1   10/22/2022 20:22:06
# 2   10/22/2022 20:22:06
# 3   10/22/2022 20:22:06
# 4   10/22/2022 20:22:06
# 5   10/22/2022 20:22:06
# 6   10/22/2022 20:22:06
# 7                   NaN
# 8                   NaN
# 9   10/22/2022 20:22:06
# 10  10/22/2022 20:22:06
# 11  10/22/2022 20:22:06
# 12  10/22/2022 20:22:06
# 13  10/22/2022 20:22:06
# 14  10/22/2022 20:22:06
# 15  10/22/2022 20:22:06

# %% [markdown]
# STEP 3: LOAD

# %%
# Send a CSV and Excell copies to my computer

from openpyxl import load_workbook

xlFile = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\Estimator_Worksheet.xlsx"

book = load_workbook(xlFile)
writer = pd.ExcelWriter(xlFile, engine = 'openpyxl')
writer.book = book

#with pd.ExcelWriter(xlFile) as writer:
working_df.to_excel(writer, sheet_name='Working_Table1')
clean_df.to_excel(writer, sheet_name='Cleaned_Data1')
writer.save()
writer.close()
    
clean_csv = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\clean_df3.csv"
clean_df.to_csv(clean_csv, index=False)

working_csv = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\working_df3.csv"
working_df.to_csv(working_csv, index=False)
