# %%
# Dependencies
from config import homeDepot_API
from serpapi import GoogleSearch
import pandas as pd
import numpy as np
from datetime import datetime
from openpyxl import load_workbook
import os
os.getcwd()
# Out:
# 'C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\Resources'

# %% [markdown]
# STEP 1: EXTRACT

# %%
# Created Working 'Material Description by grabbing names from Home Depot'

common_name = []

ids = ['100400409', '100400406', '100137321', '100400405', 
       '202241090', '100144234', '202077145', '202077147', 
       '202288508', '202304774', '202304649', '202304645', 
       '202019377', '202316275', '202019375', '202316276']

for i in ids:

    params = {
      "engine": "home_depot_product",
      "product_id": i,
      "api_key": homeDepot_API
    }

    search = GoogleSearch(params)
    results = search.get_dict()
    products = results['product_results']
    
    common_name.append(products['title'])
# Out:
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search

# %%
# Order and establish index_name

index_name = []

index_name.append(common_name[3])
index_name.append(common_name[1])
index_name.append(common_name[0])
index_name.append(common_name[5])
index_name.append(common_name[8])
index_name.append(common_name[4])
index_name.append(common_name[2])
index_name.append(common_name[6])
index_name.append(common_name[7])
index_name.append(common_name[12])
index_name.append(common_name[13])
index_name.append(common_name[14])
index_name.append(common_name[15])
index_name.append(common_name[9])
index_name.append(common_name[10])
index_name.append(common_name[11])

#index_name

# %%
def searcher(Q, R):
    params = {
      "engine": "google",
      "q": Q,
      "api_key": homeDepot_API
    }
    search = GoogleSearch(params)
    results = search.get_dict()
    products = results["organic_results"]
   
    for p in products[0:10]:
        try:

            title = p['title']
            link = p['link']
            price = (p['rich_snippet']['top']['detected_extensions']['price'])            
    
            result = {'Manufactures Description': title, 'Link': link, 'Material Price': price, 'VENDOR': link}
            R.append(result)
                        
        except (KeyError):
            price = 'NaN'
            result = {'Manufactures Description': title, 'Link': link, 'Material Price': price, 'VENDOR': link}
            R.append(result)

# %% [markdown]
# STEP 2: TRANSFORM

# %%
# Grab raw data

R = []
for i in range(16):
    R_i = []
   
    searcher(index_name[i], R_i)
    R.append(R_i)
# Out:
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search

# %%
# Create a data frame
all_prices = []
lowest_prices = []
for i in range(len(R)):
    df = pd.DataFrame(R[i]).assign(Common_name=index_name[i])
# Create a 'Vendor location' column    
    df['Vendor Location'] = (np.where(df['VENDOR'].str.contains('.'), df['VENDOR'].str.split('.').str[1], df['VENDOR']))
    df.drop(columns =['VENDOR'], inplace = True)
# Change data type of price to numeric and drop NaN's    
    df['Material Price'] = df['Material Price'].apply(pd.to_numeric, args=('coerce',))
    df.dropna(inplace=True)
# Filter out scaling issues
    if i == 0:
        df.drop(df[df['Material Price'] < .77].index, inplace = True)
    if i == 1 or i == 2:
        df.drop(df[df['Material Price'] > 130].index, inplace = True)
        df.drop(df[df['Material Price'] < 2.60].index, inplace = True)
    if i == 4:
        df.drop(df[df['Material Price'] > 130].index, inplace = True)
    if i == 5 or i == 8:
        df.drop(df[df['Material Price'] > 5.98].index, inplace = True)
    if i == 9:
        df.drop(df[df['Material Price'] < 75].index, inplace = True)
    if i == 11 or i == 12:
        df.drop(df[df['Material Price'] < 130].index, inplace = True)
    if i == 13:
        df.drop(df[df['Material Price'] < 500].index, inplace = True)
    if i == 14 or i == 15:
        df.drop(df[df['Material Price'] < 2.60].index, inplace = True)
    df.drop(columns =['Manufactures Description'], inplace = True)
    df['Material Description'] = df['Common_name']
    df.drop(columns =['Common_name'], inplace = True)
    df = df.iloc[:,[3,1,2,0]]
    
    df["Formatted Datetime"] = datetime.now().strftime("%m/%d/%Y %H:%M:%S")
    
    lowest_prices.append(df.min())
    all_prices.append(df)
clean_df = pd.concat(all_prices, axis=0, ignore_index=True)
working_df = pd.DataFrame(lowest_prices)

# %%
clean_df
# Out:
#                                  Material Description  Material Price  \
# 0   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            7.22
# 1   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            5.99
# 2   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            4.59
# 3   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            5.88
# 4   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           11.91
# 5   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           10.47
# 6   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...            8.12
# 7   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           98.99
# 8   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           20.62
# 9   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           17.55
# 10  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...            8.90
# 11  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           33.34
# 12  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            3.98
# 13  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            5.99
# 14  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            2.10
# 15  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            5.99
# 16  3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 17  3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 18  3/4 in. Standard Fitting Electric Metallic Tub...            3.60
# 19  1 in. Electric Metallic Tube (EMT) Set-Screw C...            1.15
# 20  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            3.98
# 21  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 22  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 23  3/4 in. Electrical Metallic Tube (EMT) Set-Scr...            4.60
# 24  3/4 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 25  3/4 in. Electrical Metallic Tube (EMT) Set-Scr...            5.69
# 26  1 in. Electrical Metallic Tube (EMT) Set-Screw...            1.60
# 27     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          114.00
# 28     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          111.07
# 29     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire           84.99
# 30     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          117.00
# 31  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          159.00
# 32  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          159.00
# 33  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          149.00
# 34  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          200.02
# 35  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          289.00
# 36  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          289.00
# 37  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          315.01
# 38    500 ft. 4 Gauge Black Stranded Copper THHN Wire          613.64
# 39    500 ft. 4 Gauge Black Stranded Copper THHN Wire         1047.78
# 40    500 ft. 6 Gauge Black Stranded Copper THHN Wire          379.00
# 41    500 ft. 6 Gauge Black Stranded Copper THHN Wire          470.43
# 42    500 ft. 6 Gauge Black Stranded Copper THHN Wire          445.81
# 43    500 ft. 6 Gauge Black Stranded Copper THHN Wire         1144.69
# 44   500 ft. 10 Gauge Black Stranded Copper THHN Wire          145.00
# 45   500 ft. 10 Gauge Black Stranded Copper THHN Wire          155.99
# 46   500 ft. 10 Gauge Black Stranded Copper THHN Wire          165.00
#
#                                       Vendor Location  \
# 0                                           homedepot
# 1                                               lowes
# 2                                gordonelectricsupply
# 3                                         supplyworks
# 4                                           homedepot
# 5                                            ebarnett
# 6                                gordonelectricsupply
# 7                                              amazon
# 8                                           homedepot
# 9                                              wilmar
# 10                                      linemen-tools
# 11                                         dkhardware
# 12                                          homedepot
# 13                                             amazon
# 14                                             wilmar
# 15                                              lowes
# 16                                          homedepot
# 17                                          pinterest
# 18                                         superarbor
# 19                                          homedepot
# 20                                          homedepot
# 21                                             amazon
# 22                                              lowes
# 23                                          homedepot
# 24                                              lowes
# 25  com/p/halex-screw-emt-conduit-connector-051411...
# 26                                          homedepot
# 27                                             amazon
# 28                                               ebay
# 29                                        landmsupply
# 30                                      socalelectric
# 31                                          homedepot
# 32                                              lowes
# 33                                          homedepot
# 34                                         dkhardware
# 35                                          homedepot
# 36                                              lowes
# 37                                               ebay
# 38                                             amazon
# 39                                               ebay
# 40                                          homedepot
# 41                                             amazon
# 42                                               ebay
# 43                                    cooper-electric
# 44                                          homedepot
# 45                                             amazon
# 46                                wireandcableyourway
#
#                                                  Link   Formatted Datetime
# 0   https://www.homedepot.com/p/1-2-in-x-10-ft-Ele...  10/27/2022 14:34:51
# 1   https://www.lowes.com/pd/Common-1-2-in-Actual-...  10/27/2022 14:34:51
# 2   https://www.gordonelectricsupply.com/p/Allied-...  10/27/2022 14:34:51
# 3   https://www.supplyworks.com/Sku/2487615/12-in-...  10/27/2022 14:34:51
1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            4.59
# 1   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...            8.12
# 2   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...            8.90
# 3   1/2 in. Electric Metallic Tube (EMT) Set-Screw...            2.10
# 4   3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 5   1 in. Electric Metallic Tube (EMT) Set-Screw C...            1.15
# 6   1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            3.98
# 7   3/4 in. Electrical Metallic Tube (EMT) Set-Scr...            4.60
# 8   1 in. Electrical Metallic Tube (EMT) Set-Screw...            1.60
# 9      250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire           84.99
# 10  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          159.00
# 11  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          149.00
# 12  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          289.00
# 13    500 ft. 4 Gauge Black Stranded Copper THHN Wire          613.64
# 14    500 ft. 6 Gauge Black Stranded Copper THHN Wire          379.00
# 15   500 ft. 10 Gauge Black Stranded Copper THHN Wire          145.00
#
#                                       Vendor Location  \
# 0                                gordonelectricsupply
# 1                                              amazon
# 2                                          dkhardware
# 3                                              amazon
# 4                                           homedepot
# 5                                           homedepot
# 6                                              amazon
# 7   com/p/halex-screw-emt-conduit-connector-051411...
# 8                                           homedepot
# 9                                              amazon
# 10                                          homedepot
# 11                                         dkhardware
# 12                                               ebay
# 13                                             amazon
# 14                                             amazon
# 15                                             amazon
#
#                                                  Link   Formatted Datetime
# 0   https://www.gordonelectricsupply.com/p/Allied-...  10/27/2022 14:34:51
# 1   https://www.amazon.com/EMT-Conduit-10-ft-Steel...  10/27/2022 14:34:51
# 2   https://www.dkhardware.com/allied-tube-and-con...  10/27/2022 14:34:51
# 3   https://www.amazon.com/Halex-26270-STEEL-CONNE...  10/27/2022 14:34:51
# 4   https://www.homedepot.com/p/Halex-3-4-in-Elect...  10/27/2022 14:34:51
# 5   https://www.homedepot.com/p/Halex-1-in-Electri...  10/27/2022 14:34:51
# 6   https://www.amazon.com/Halex-26270-STEEL-CONNE...  10/27/2022 14:34:51
# 7   https://goldbeachlumber.com/p/halex-screw-emt-...  10/27/2022 14:34:51
# 8   https://www.homedepot.com/p/Halex-1-in-Electri...  10/27/2022 14:34:51
# 9   https://www.amazon.com/SOUTHWIRE-COMPANY-28827...  10/27/2022 14:34:51
# 10  https://www.homedepot.com/p/Southwire-250-ft-1...  10/27/2022 14:34:51
# 11  https://www.dkhardware.com/southwire-250-ft-12...  10/27/2022 14:34:51
# 12  https://www.ebay.com/b/12-3-Romex/92078/bn_702...  10/27/2022 14:34:51
# 13  https://www.amazon.com/SOUTHWIRE-COMPANY-LL-20...  10/27/2022 14:34:51
# 14  https://www.amazon.com/Cerrowire-112-4201J-500...  10/27/2022 14:34:51
# 15  https://www.amazon.com/Gauge-Stranded-Copper-B...  10/27/2022 14:34:51

# %% [markdown]
# STEP 3: LOAD

# %%
# Send a CSV and Excell copies to my computer

xlFile = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\Estimator_Worksheet.xlsx"

book = load_workbook(xlFile)
writer = pd.ExcelWriter(xlFile, engine = 'openpyxl')
writer.book = book

#with pd.ExcelWriter(xlFile) as writer:
working_df.to_excel(writer, sheet_name='Working_Table5')
clean_df.to_excel(writer, sheet_name='Cleaned_Data5')
writer.save()
writer.close()
    
clean_csv = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\clean_df7.csv"
clean_df.to_csv(clean_csv, index=False)

working_csv = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\working_df7.csv"
working_df.to_csv(working_csv, index=False)
