# %%
# Dependencies
from config import homeDepot_API
from serpapi import GoogleSearch
import pandas as pd
import numpy as np
import os
os.getcwd()
# Out:
# 'C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\Resources'

# %% [markdown]
# STEP 1: EXTRACT

# %%
# Created Working 'Material Description by grabbing names from Home Depot'

common_name = []

ids = ['100400409', '100400406', '100137321', '100400405', 
       '202241090', '100144234', '202077145', '202077147', 
       '202288508', '202304774', '202304649', '202304645', 
       '202019377', '202316275', '202019375', '202316276']

for i in ids:

    params = {
      "engine": "home_depot_product",
      "product_id": i,
      "api_key": homeDepot_API
    }

    search = GoogleSearch(params)
    results = search.get_dict()
    products = results['product_results']
    
    common_name.append(products['title'])
# Out:
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search

# %%
# Order and establish index_name

index_name = []

index_name.append(common_name[3])
index_name.append(common_name[1])
index_name.append(common_name[0])
index_name.append(common_name[5])
index_name.append(common_name[8])
index_name.append(common_name[4])
index_name.append(common_name[2])
index_name.append(common_name[6])
index_name.append(common_name[7])
index_name.append(common_name[12])
index_name.append(common_name[13])
index_name.append(common_name[14])
index_name.append(common_name[15])
index_name.append(common_name[9])
index_name.append(common_name[10])
index_name.append(common_name[11])

#index_name

# %%
def searcher(Q, R):
    params = {
      "engine": "google",
      "q": Q,
      "api_key": homeDepot_API
    }
    search = GoogleSearch(params)
    results = search.get_dict()
    products = results["organic_results"]
   
    for p in products[0:10]:
        try:

            title = p['title']
            link = p['link']
            price = (p['rich_snippet']['top']['detected_extensions']['price'])
    
            result = {'Manufactures Description': title, 'link': link, 'Material Price': price, 'VENDOR': link}
            R.append(result)
                        
        except (KeyError):
            price = 'NaN'
            result = {'Manufactures Description': title, 'link': link, 'Material Price': price, 'VENDOR': link}
            R.append(result)

# %% [markdown]
# STEP 2: TRANSFORM

# %%
# Grab raw data

R = []
for i in range(16):
    R_i = []
   
    searcher(index_name[i], R_i)
    R.append(R_i)
    print(R_i)
    print('-------------------------------------------')
# Out:
# https://serpapi.com/search
# [{'Manufactures Description': '1/2 in. x 10 ft. Electric Metallic Tube (EMT) Conduit 853428', 'link': 'https://www.homedepot.com/p/1-2-in-x-10-ft-Electric-Metallic-Tube-EMT-Conduit-853428/100400405', 'Material Price': 7.22, 'VENDOR': 'https://www.homedepot.com/p/1-2-in-x-10-ft-Electric-Metallic-Tube-EMT-Conduit-853428/100400405'}, {'Manufactures Description': "1/2-in x 10-ft Metal Emt Conduit - Lowe's", 'link': 'https://www.lowes.com/pd/Common-1-2-in-Actual-50-In-Metallic-Emt-10-ft-Conduit/3129551', 'Material Price': 5.99, 'VENDOR': 'https://www.lowes.com/pd/Common-1-2-in-Actual-50-In-Metallic-Emt-10-ft-Conduit/3129551'}, {'Manufactures Description': 'ALLIED 898302 EMT CONDUIT 1/2" EMT CONDUIT X 10', 'link': 'https://www.gordonelectricsupply.com/p/Allied-898302-Emt-Conduit-1-2-Emt-Conduit-X-10/1608', 'Material Price': 4.73, 'VENDOR': 'https://www.gordonelectricsupply.com/p/Allied-898302-Emt-Conduit-1-2-Emt-Conduit-X-10/1608'}, {'Manufactures Description': '1/2 In. X 10 Ft. Electric Metallic Tube (Emt) Conduit', 'link': 'https://www.supplyworks.com/Sku/2487615/12-in-x-10-ft-electric-metallic-tube-emt-conduit-091111
black-500/048243230006/10thhncstrblax500', 'Material Price': 0.36, 'VENDOR': 'https://www.platt.com/p/0062557/10-awg-thhn-thwn-stranded-copper-black-500/048243230006/10thhncstrblax500'}, {'Manufactures Description': '10 Thhn Stranded for sale - eBay', 'link': 'https://www.ebay.com/b/10-Thhn-Stranded/92078/bn_7023220009', 'Material Price': 'NaN', 'VENDOR': 'https://www.ebay.com/b/10-Thhn-Stranded/92078/bn_7023220009'}, {'Manufactures Description': 'THHN #10 Stranded Copper BLACK Wire (500ft Spool)', 'link': 'https://www.cooper-electric.com/product/detail/23760/thhn-copper-wic-thhn-10-str-blk-500r', 'Material Price': 398.95, 'VENDOR': 'https://www.cooper-electric.com/product/detail/23760/thhn-copper-wic-thhn-10-str-blk-500r'}, {'Manufactures Description': 'Southwire 500 Ft. 10 Black Stranded Cu Thhn Wire - Wilmar', 'link': 'https://www.wilmar.com/Sku/202316335/southwire-500-ft-10-black-stranded-cu-thhn-wire-032886845659-22973257', 'Material Price': 'NaN', 'VENDOR': 'https://www.wilmar.com/Sku/202316335/southwire-500-ft-10-black-stranded-cu-thhn-wire-032886845659-22973257'}]
# -------------------------------------------

# %%
# Create a data frame
df0 = pd.DataFrame(R[0]).assign(Common_name=index_name[0])
# Create a 'Vendor location' column
df0['Vendor Location'] = (np.where(df0['VENDOR'].str.contains('.'), df0['VENDOR'].str.split('.').str[1], df0['VENDOR']))
df0.drop(columns =['VENDOR'], inplace = True)
# Change data type of price to numeric and drop NaN's
df0['Material Price'] = df0['Material Price'].apply(pd.to_numeric, args=('coerce',))
df0.dropna(inplace=True)
# Drop per foot items
df0.drop(df0[df0['Material Price'] < .77].index, inplace = True)
row0 = df0.min()
df0
# Out:
#                             Manufactures Description  \
# 0  1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...
# 1          1/2-in x 10-ft Metal Emt Conduit - Lowe's
# 2    ALLIED 898302 EMT CONDUIT 1/2" EMT CONDUIT X 10
# 3  1/2 In. X 10 Ft. Electric Metallic Tube (Emt) ...
# 9  Allied 101543 EMT Electrical Conduit 1/2 in X ...
#
#                                                 link  Material Price  \
# 0  https://www.homedepot.com/p/1-2-in-x-10-ft-Ele...            7.22
# 1  https://www.lowes.com/pd/Common-1-2-in-Actual-...            5.99
# 2  https://www.gordonelectricsupply.com/p/Allied-...            4.73
# 3  https://www.supplyworks.com/Sku/2487615/12-in-...            5.88
# 9                  https://www.ebay.com/p/1700352648            9.09
#
#                                          Common_name       Vendor Location
# 0  1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...             homedepot
# 1  1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...                 lowes
# 2  1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...  gordonelectricsupply
# 3  1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...           supplyworks
# 9  1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...                  ebay

# %%
df1 = pd.DataFrame(R[1]).assign(Common_name=index_name[1])
df1['Vendor Location'] = (np.where(df1['VENDOR'].str.contains('.'), df1['VENDOR'].str.split('.').str[1], df1['VENDOR']))
df1.drop(columns =['VENDOR'], inplace = True)
df1['Material Price'] = df1['Material Price'].apply(pd.to_numeric, args=('coerce',))
df1.dropna(inplace=True)
df1.drop(df1[df1['Material Price'] > 130].index, inplace = True)
df1.drop(df1[df1['Material Price'] < 1.38].index, inplace = True)
row1 = df1.min()
df1
# Out:
#                             Manufactures Description  \
# 0  3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...
# 2  3/4 In. X 10 Ft. Electric Metallic Tube (Emt) ...
# 3    ALLIED 898303 EMT CONDUIT 3/4" EMT CONDUIT X 10
#
#                                                 link  Material Price  \
# 0  https://www.homedepot.com/p/3-4-in-x-10-ft-Ele...           11.91
# 2  https://www.ebarnett.com/Sku/2487616/34-in-x-1...           10.47
# 3  https://www.gordonelectricsupply.com/p/Allied-...            8.36
#
#                                          Common_name       Vendor Location
# 0  3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...             homedepot
# 2  3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...              ebarnett
# 3  3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...  gordonelectricsupply

# %%
df2 = pd.DataFrame(R[2]).assign(Common_name=index_name[2])
df2['Vendor Location'] = (np.where(df2['VENDOR'].str.contains('.'), df2['VENDOR'].str.split('.').str[1], df2['VENDOR']))
df2.drop(columns =['VENDOR'], inplace = True)
df2['Material Price'] = df2['Material Price'].apply(pd.to_numeric, args=('coerce',))
df2.dropna(inplace=True)
df2.drop(df2[df2['Material Price'] > 130].index, inplace = True)
df2.drop(df2[df2['Material Price'] < 2.60].index, inplace = True)
row2 = df2.min()
df2
# Out:
#                             Manufactures Description  \
# 0  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...
# 2  Allied Tube And Conduit 1 In. X 10 Ft. Electri...
# 3  Electrical Materials Tubing (EMT) Conduit 1" x...
# 4  EMT Conduit, Steel, Thinwall, 1-In. x 10-Ft. |...
#
#                                                 link  Material Price  \
# 0  https://www.homedepot.com/p/1-in-x-10-ft-Elect...           20.62
# 2  https://www.wilmar.com/Sku/24-87610/allied-tub...           17.55
# 3  https://www.linemen-tools.com/Electrical_Mater...            8.90
# 4  https://www.truevalue.com/emt-conduit-steel-th...           24.99
#
#                                          Common_name Vendor Location
# 0  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...       homedepot
# 2  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...          wilmar
# 3  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...   linemen-tools
# 4  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...       truevalue

# %%
df3 = pd.DataFrame(R[3]).assign(Common_name=index_name[3])
df3['Vendor Location'] = (np.where(df3['VENDOR'].str.contains('.'), df3['VENDOR'].str.split('.').str[1], df3['VENDOR']))
df3.drop(columns =['VENDOR'], inplace = True)
df3['Material Price'] = df3['Material Price'].apply(pd.to_numeric, args=('coerce',))
df3.dropna(inplace=True)
row3 = df3.min()
df3
# Out:
#                             Manufactures Description  \
# 0  Halex 1/2 in. Electrical Metallic Tube (EMT) S...
# 1  Halex, 1/2 in. Electrical Metallic Tube (EMT) ...
# 2  Halex 1/2 In. Electrical Metallic Tube (Emt) S...
# 3  Halex 1/2 In. Electrical Metallic Tube (Emt) S...
# 7  Halex 1/2 in. Electrical Metallic Tube (EMT) S...
#
#                                                 link  Material Price  \
# 0  https://www.homedepot.com/p/Halex-1-2-in-Elect...            3.98
# 1  https://www.amazon.com/Halex-26270-STEEL-CONNE...            5.99
# 2  https://www.wilmar.com/Sku/202077151/halex-12-...            2.10
# 3  https://www.supplyworks.com/Sku/202077151/hale...          150.00
# 7  https://dslsupply.com/halex-1-2-in-electrical-...           50.00
#
#                                          Common_name  \
# 0  1/2 in. Electric Metallic Tube (EMT) Set-Screw...
# 1  1/2 in. Electric Metallic Tube (EMT) Set-Screw...
# 2  1/2 in. Electric Metallic Tube (EMT) Set-Screw...
# 3  1/2 in. Electric Metallic Tube (EMT) Set-Screw...
# 7  1/2 in. Electric Metallic Tube (EMT) Set-Screw...
#
#                                      Vendor Location
# 0                                          homedepot
# 1                                             amazon
# 2                                             wilmar
# 3                                        supplyworks
# 7  com/halex-1-2-in-electrical-metallic-tube-emt-...

# %%
df4 = pd.DataFrame(R[4]).assign(Common_name=index_name[4])
df4['Vendor Location'] = (np.where(df4['VENDOR'].str.contains('.'), df4['VENDOR'].str.split('.').str[1], df4['VENDOR']))
df4.drop(columns =['VENDOR'], inplace = True)
df4['Material Price'] = df4['Material Price'].apply(pd.to_numeric, args=('coerce',))
df4.dropna(inplace=True)
df4.drop(df4[df4['Material Price'] > 130].index, inplace = True)
#df4.drop(df4[df4['Manufactures Description'].filter(regex='1 in.')].index, inplace = True)
row4 = df4.min()
df4
# Out:
#                             Manufactures Description  \
# 0  3/4 in. Standard Fitting Electric Metallic Tub...
# 1  Halex 3/4 In. Electrical Metallic Tube (Emt) S...
# 5  Halex 1 in. Electrical Metallic Tube (EMT) Set...
#
#                                                 link  Material Price  \
# 0  https://www.homedepot.com/p/Halex-3-4-in-Elect...            2.98
# 1  https://www.supplyworks.com/Sku/202328185/hale...            3.66
# 5  https://www.pinterest.com/pin/230668812499210604/            2.98
#
#                                          Common_name Vendor Location
# 0  3/4 in. Standard Fitting Electric Metallic Tub...       homedepot
# 1  3/4 in. Standard Fitting Electric Metallic Tub...     supplyworks
# 5  3/4 in. Standard Fitting Electric Metallic Tub...       pinterest

# %%
df5 = pd.DataFrame(R[5]).assign(Common_name=index_name[5])
df5['Vendor Location'] = (np.where(df5['VENDOR'].str.contains('.'), df5['VENDOR'].str.split('.').str[1], df5['VENDOR']))
df5.drop(columns =['VENDOR'], inplace = True)
df5['Material Price'] = df5['Material Price'].apply(pd.to_numeric, args=('coerce',))
df5.dropna(inplace=True)
df5.drop(df5[df5['Material Price'] > 5.98].index, inplace = True)
row5 = df5.min()
df5
# Out:
#                             Manufactures Description  \
# 0  1 in. Electric Metallic Tube (EMT) Set-Screw C...
#
#                                                 link  Material Price  \
# 0  https://www.homedepot.com/p/Halex-1-in-Electri...            1.15
#
#                                          Common_name Vendor Location
# 0  1 in. Electric Metallic Tube (EMT) Set-Screw C...       homedepot

# %%
df6 = pd.DataFrame(R[6]).assign(Common_name=index_name[6])
df6['Vendor Location'] = (np.where(df6['VENDOR'].str.contains('.'), df6['VENDOR'].str.split('.').str[1], df6['VENDOR']))
df6.drop(columns =['VENDOR'], inplace = True)
df6['Material Price'] = df6['Material Price'].apply(pd.to_numeric, args=('coerce',))
df6.dropna(inplace=True)
row6 = df6.min()
df6
# Out:
#                             Manufactures Description  \
# 0  Halex 1/2 in. Electrical Metallic Tube (EMT) S...
# 1  Halex, 1/2 in. Electrical Metallic Tube (EMT) ...
# 2  Sigma ProConnex 1/2-in Zinc-plated Steel Set S...
#
#                                                 link  Material Price  \
# 0  https://www.homedepot.com/p/Halex-1-2-in-Elect...            3.98
# 1  https://www.amazon.com/Halex-26270-STEEL-CONNE...            5.99
# 2  https://www.lowes.com/pd/Sigma-Electric-ProCon...            5.99
#
#                                          Common_name Vendor Location
# 0  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...       homedepot
# 1  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...          amazon
# 2  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...           lowes

# %%
df7 = pd.DataFrame(R[7]).assign(Common_name=index_name[7])
df7['Vendor Location'] = (np.where(df7['VENDOR'].str.contains('.'), df7['VENDOR'].str.split('.').str[1], df7['VENDOR']))
df7.drop(columns =['VENDOR'], inplace = True)
df7['Material Price'] = df7['Material Price'].apply(pd.to_numeric, args=('coerce',))
df7.dropna(inplace=True)
row7 = df7.min()
df7
# Out:
#                             Manufactures Description  \
# 0  Halex 3/4 in. Electrical Metallic Tube (EMT) S...
# 2  Halex 3/4-in Steel Set Screw Connector Conduit...
#
#                                                 link  Material Price  \
# 0  https://www.homedepot.com/p/Halex-3-4-in-Elect...            4.60
# 2  https://www.lowes.com/pd/Halex-3-4-in-EMT-STEE...            5.99
#
#                                          Common_name Vendor Location
# 0  3/4 in. Electrical Metallic Tube (EMT) Set-Scr...       homedepot
# 2  3/4 in. Electrical Metallic Tube (EMT) Set-Scr...           lowes

# %%
df8 = pd.DataFrame(R[8]).assign(Common_name=index_name[8])
df8['Vendor Location'] = (np.where(df8['VENDOR'].str.contains('.'), df8['VENDOR'].str.split('.').str[1], df8['VENDOR']))
df8.drop(columns =['VENDOR'], inplace = True)
df8['Material Price'] = df8['Material Price'].apply(pd.to_numeric, args=('coerce',))
df8.dropna(inplace=True)
df8.drop(df8[df8['Material Price'] > 5.98].index, inplace = True)
row8 = df8.min()
df8
# Out:
#                             Manufactures Description  \
# 0  1 in. Electrical Metallic Tube (EMT) Set-Screw...
#
#                                                 link  Material Price  \
# 0  https://www.homedepot.com/p/Halex-1-in-Electri...             1.6
#
#                                          Common_name Vendor Location
# 0  1 in. Electrical Metallic Tube (EMT) Set-Screw...       homedepot

# %%
df9 = pd.DataFrame(R[9]).assign(Common_name=index_name[9])
df9['Vendor Location'] = (np.where(df9['VENDOR'].str.contains('.'), df9['VENDOR'].str.split('.').str[1], df9['VENDOR']))
df9.drop(columns =['VENDOR'], inplace = True)
df9['Material Price'] = df9['Material Price'].apply(pd.to_numeric, args=('coerce',))
df9.dropna(inplace=True)
df9.drop(df9[df9['Material Price'] <= 80].index, inplace = True)
row9 = df9.min()
df9
# Out:
#                             Manufactures Description  \
# 1   SOUTHWIRE COMPANY #28827455 250' 14/2 W/G NM ...
# 2  Southwire Romex SIMpull 250-ft 14/2 Solid Non-...
# 3   250 ft 14 2 Romex Wire (ACTUAL ROMEX SIMPULL ...
# 4     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire
# 7  Southwire Romex SIMpull 250-ft 14/2 Solid Non-...
#
#                                                 link  Material Price  \
# 1  https://www.amazon.com/SOUTHWIRE-COMPANY-28827...          114.00
# 2  https://www.lowes.com/pd/Southwire-Romex-SIMpu...          118.00
# 3              https://www.ebay.com/itm/363478081520          113.98
# 4  https://www.socalelectric.com/products/250-ft-...          117.00
# 7  https://denalibuildingsupply.com/products/sout...           90.00
#
#                                       Common_name  \
# 1  250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire
# 2  250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire
# 3  250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire
# 4  250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire
# 7  250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire
#
#                                      Vendor Location
# 1                                             amazon
# 2                                              lowes
# 3                                               ebay
# 4                                      socalelectric
# 7  com/products/southwire-romex-simpull-250-ft-14...

# %%
df10 = pd.DataFrame(R[10]).assign(Common_name=index_name[10])
df10['Vendor Location'] = (np.where(df10['VENDOR'].str.contains('.'), df10['VENDOR'].str.split('.').str[1], df10['VENDOR']))
df10.drop(columns =['VENDOR'], inplace = True)
df10['Material Price'] = df10['Material Price'].apply(pd.to_numeric, args=('coerce',))
df10.dropna(inplace=True)
row10 = df10.min()
df10
# Out:
#                             Manufactures Description  \
# 0  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire
# 1  Southwire Romex SIMpull 250-ft 14/3 Solid Non-...
# 4  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire
# 6  Southwire 63946855 250 ft. 14/3 Solid Romex SI...
#
#                                                 link  Material Price  \
# 0  https://www.homedepot.com/p/Southwire-250-ft-1...           158.0
# 1  https://www.lowes.com/pd/Southwire-Romex-SIMpu...           159.0
# 4  https://www.socalelectric.com/products/250-ft-...           157.0
# 6  https://www.dkhardware.com/southwire-250-ft-14...           225.3
#
#                                          Common_name Vendor Location
# 0  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire       homedepot
# 1  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire           lowes
# 4  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire   socalelectric
# 6  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire      dkhardware

# %%
df11 = pd.DataFrame(R[11]).assign(Common_name=index_name[11])
df11['Vendor Location'] = (np.where(df11['VENDOR'].str.contains('.'), df11['VENDOR'].str.split('.').str[1], df11['VENDOR']))
df11.drop(columns =['VENDOR'], inplace = True)
df11['Material Price'] = df11['Material Price'].apply(pd.to_numeric, args=('coerce',))
df11.dropna(inplace=True)
df11.drop(df11[df11['Material Price'] < 130].index, inplace = True)
row11 = df11.min()
df11
# Out:
#                             Manufactures Description  \
# 0  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire
# 7  Southwire 28828255 250 ft. 12/2 Solid Romex SI...
#
#                                                 link  Material Price  \
# 0  https://www.homedepot.com/p/Southwire-250-ft-1...          149.00
# 7  https://www.dkhardware.com/southwire-250-ft-12...          200.02
#
#                                          Common_name Vendor Location
# 0  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire       homedepot
# 7  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire      dkhardware

# %%
df12 = pd.DataFrame(R[12]).assign(Common_name=index_name[12])
df12['Vendor Location'] = (np.where(df12['VENDOR'].str.contains('.'), df12['VENDOR'].str.split('.').str[1], df12['VENDOR']))
df12.drop(columns =['VENDOR'], inplace = True)
df12['Material Price'] = df12['Material Price'].apply(pd.to_numeric, args=('coerce',))
df12.dropna(inplace=True)
df12.drop(df12[df12['Material Price'] <= 130].index, inplace = True)
row12 = df12.min()
df12
# Out:
#                             Manufactures Description  \
# 0  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire
# 1  Southwire Romex SIMpull 250-ft 12/3 Solid Non-...
# 4  250 ft. 12/3 Romex® SIMpull® NM-B W/G Wire - Q...
#
#                                                 link  Material Price  \
# 0  https://www.homedepot.com/p/Southwire-250-ft-1...          289.00
# 1  https://www.lowes.com/pd/Southwire-Romex-SIMpu...          289.00
# 4  https://www.qcsupply.com/12-3-romex-simpull-wi...          339.09
#
#                                          Common_name Vendor Location
# 0  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire       homedepot
# 1  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire           lowes
# 4  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire        qcsupply

# %%
df13 = pd.DataFrame(R[13]).assign(Common_name=index_name[13])
df13['Vendor Location'] = (np.where(df13['VENDOR'].str.contains('.'), df13['VENDOR'].str.split('.').str[1], df13['VENDOR']))
df13.drop(columns =['VENDOR'], inplace = True)
df13['Material Price'] = df13['Material Price'].apply(pd.to_numeric, args=('coerce',))
df13.dropna(inplace=True)
df13.drop(df13[df13['Material Price'] <= 500].index, inplace = True)
row13 = df13.min()
df13
# Out:
#                             Manufactures Description  \
# 0      500 ft. 4 Black Stranded CU SIMpull THHN Wire
# 2  SOUTHWIRE COMPANY LL 20499001 4 Gauge Stranded...
# 3  Southwire THHN Wire Stranded CU SIMPULL 4 Gaug...
#
#                                                 link  Material Price  \
# 0  https://www.homedepot.com/p/Southwire-500-ft-4...          765.00
# 2  https://www.amazon.com/SOUTHWIRE-COMPANY-LL-20...          613.64
# 3                 https://www.ebay.com/p/17040228268         1047.78
#
#                                        Common_name Vendor Location
# 0  500 ft. 4 Gauge Black Stranded Copper THHN Wire       homedepot
# 2  500 ft. 4 Gauge Black Stranded Copper THHN Wire          amazon
# 3  500 ft. 4 Gauge Black Stranded Copper THHN Wire            ebay

# %%
df14 = pd.DataFrame(R[14]).assign(Common_name=index_name[14])
df14['Vendor Location'] = (np.where(df14['VENDOR'].str.contains('.'), df14['VENDOR'].str.split('.').str[1], df14['VENDOR']))
df14.drop(columns =['VENDOR'], inplace = True)
df14['Material Price'] = df14['Material Price'].apply(pd.to_numeric, args=('coerce',))
df14.dropna(inplace=True)
row14 = df14.min()
df14
# Out:
#                             Manufactures Description  \
# 0  Southwire SIMpull 500-ft 6-AWG Stranded Black ...
# 1      500 ft. 6 Black Stranded CU SIMpull THHN Wire
# 2  Cerrowire 112-4201J 500-Feet 6 Stranded THHN, ...
# 4  Gauge 500 ft. 6 Black Stranded CU THHN Wire Co...
#
#                                                 link  Material Price  \
# 0  https://www.lowes.com/pd/Southwire-SIMpull-500...          355.50
# 1  https://www.homedepot.com/p/Southwire-500-ft-6...          425.00
# 2  https://www.amazon.com/Cerrowire-112-4201J-500...          460.00
# 4              https://www.ebay.com/itm/203860011450          445.81
#
#                                        Common_name Vendor Location
# 0  500 ft. 6 Gauge Black Stranded Copper THHN Wire           lowes
# 1  500 ft. 6 Gauge Black Stranded Copper THHN Wire       homedepot
# 2  500 ft. 6 Gauge Black Stranded Copper THHN Wire          amazon
# 4  500 ft. 6 Gauge Black Stranded Copper THHN Wire            ebay

# %%
df15 = pd.DataFrame(R[15]).assign(Common_name=index_name[15])
df15['Vendor Location'] = (np.where(df15['VENDOR'].str.contains('.'), df15['VENDOR'].str.split('.').str[1], df15['VENDOR']))
df15.drop(columns =['VENDOR'], inplace = True)
df15['Material Price'] = df15['Material Price'].apply(pd.to_numeric, args=('coerce',))
df15.dropna(inplace=True)
df15.drop(df15[df15['Material Price'] <= .98].index, inplace = True)
row15 = df15.min()
df15
# Out:
#                             Manufactures Description  \
# 0  500 ft. 10 Black Stranded CU THHN Wire - The H...
# 2  10 Gauge THHN Stranded Copper Building Wire (5...
# 6  THHN #10 Stranded Copper BLACK Wire (500ft Spool)
#
#                                                 link  Material Price  \
# 0  https://www.homedepot.com/p/Southwire-500-ft-1...          145.00
# 2  https://www.amazon.com/Gauge-Stranded-Copper-B...          171.50
# 6  https://www.cooper-electric.com/product/detail...          398.95
#
#                                         Common_name  Vendor Location
# 0  500 ft. 10 Gauge Black Stranded Copper THHN Wire        homedepot
# 2  500 ft. 10 Gauge Black Stranded Copper THHN Wire           amazon
# 6  500 ft. 10 Gauge Black Stranded Copper THHN Wire  cooper-electric

# %% [markdown]
# STEP 3: LOAD

# %%
working_df = pd.DataFrame([row0, row1, row2, row3, row4, row5, row6, row7, row8, 
                           row9, row10, row11, row12, row13, row14, row15])
working_df.drop(columns =['Manufactures Description'], inplace = True)
working_df['Material Description'] = working_df['Common_name']
working_df.drop(columns =['Common_name'], inplace = True)
working_df = working_df.iloc[:,[3,1,2,0]]
working_df
working_df
# Out:
#                                  Material Description  Material Price  \
# 0   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            4.73
# 1   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...            8.36
# 2   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...            8.90
# 3   1/2 in. Electric Metallic Tube (EMT) Set-Screw...            2.10
# 4   3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 5   1 in. Electric Metallic Tube (EMT) Set-Screw C...            1.15
# 6   1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            3.98
# 7   3/4 in. Electrical Metallic Tube (EMT) Set-Scr...            4.60
# 8   1 in. Electrical Metallic Tube (EMT) Set-Screw...            1.60
# 9      250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire           90.00
# 10  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          157.00
# 11  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          149.00
# 12  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          289.00
# 13    500 ft. 4 Gauge Black Stranded Copper THHN Wire          613.64
# 14    500 ft. 6 Gauge Black Stranded Copper THHN Wire          355.50
# 15   500 ft. 10 Gauge Black Stranded Copper THHN Wire          145.00
#
#    Vendor Location                                               link
# 0             ebay                  https://www.ebay.com/p/1700352648
# 1         ebarnett  https://www.ebarnett.com/Sku/2487616/34-in-x-1...
# 2        homedepot  https://www.homedepot.com/p/1-in-x-10-ft-Elect...
# 3           amazon  https://dslsupply.com/halex-1-2-in-electrical-...
# 4        homedepot  https://www.homedepot.com/p/Halex-3-4-in-Elect...
# 5        homedepot  https://www.homedepot.com/p/Halex-1-in-Electri...
# 6           amazon  https://www.amazon.com/Halex-26270-STEEL-CONNE...
# 7        homedepot  https://www.homedepot.com/p/Halex-3-4-in-Elect...
# 8        homedepot  https://www.homedepot.com/p/Halex-1-in-Electri...
# 9           amazon  https://denalibuildingsupply.com/products/sout...
# 10      dkhardware  https://www.dkhardware.com/southwire-250-ft-14...
# 11      dkhardware  https://www.dkhardware.com/southwire-250-ft-12...
# 12       homedepot  https://www.homedepot.com/p/Southwire-250-ft-1...
# 13          amazon  https://www.amazon.com/SOUTHWIRE-COMPANY-LL-20...
# 14          amazon  https://www.amazon.com/Cerrowire-112-4201J-500...
# 15          amazon  https://www.amazon.com/Gauge-Stranded-Copper-B...

# %%
data = [df0, df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15]
clean_df = pd.concat(data, axis=0, ignore_index=True)
clean_df.drop(columns =['Manufactures Description'], inplace = True)
clean_df['Material Description'] = clean_df['Common_name']
clean_df.drop(columns =['Common_name'], inplace = True)
clean_df = clean_df.iloc[:,[3,1,2,0]]
clean_df
# Out:
#                                  Material Description  Material Price  \
# 0   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            7.22
# 1   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            5.99
# 2   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            4.73
# 3   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            5.88
# 4   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            9.09
# 5   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           11.91
# 6   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           10.47
# 7   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...            8.36
# 8   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           20.62
# 9   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           17.55
# 10  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...            8.90
# 11  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           24.99
# 12  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            3.98
# 13  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            5.99
# 14  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            2.10
# 15  1/2 in. Electric Metallic Tube (EMT) Set-Screw...          150.00
# 16  1/2 in. Electric Metallic Tube (EMT) Set-Screw...           50.00
# 17  3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 18  3/4 in. Standard Fitting Electric Metallic Tub...            3.66
# 19  3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 20  1 in. Electric Metallic Tube (EMT) Set-Screw C...            1.15
# 21  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            3.98
# 22  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 23  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 24  3/4 in. Electrical Metallic Tube (EMT) Set-Scr...            4.60
# 25  3/4 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 26  1 in. Electrical Metallic Tube (EMT) Set-Screw...            1.60
# 27     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          114.00
# 28     250 ft. 14/2 Romex SIMpull Solid NM-B W/G W