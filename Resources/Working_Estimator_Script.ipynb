# %%
# Dependencies
from config import homeDepot_API
from serpapi import GoogleSearch
import pandas as pd
import numpy as np
from datetime import datetime
from openpyxl import load_workbook
import os
os.getcwd()
# Out:
# 'C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\Resources'

# %% [markdown]
# STEP 1: EXTRACT

# %%
# Created Working 'Material Description by grabbing names from Home Depot'

common_name = []

ids = ['100400409', '100400406', '100137321', '100400405', 
       '202241090', '100144234', '202077145', '202077147', 
       '202288508', '202304774', '202304649', '202304645', 
       '202019377', '202316275', '202019375', '202316276']

for i in ids:

    params = {
      "engine": "home_depot_product",
      "product_id": i,
      "api_key": homeDepot_API
    }

    search = GoogleSearch(params)
    results = search.get_dict()
    products = results['product_results']
    
    common_name.append(products['title'])
# Out:
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search

# %%
# Order and establish index_name

index_name = []

index_name.append(common_name[3])
index_name.append(common_name[1])
index_name.append(common_name[0])
index_name.append(common_name[5])
index_name.append(common_name[8])
index_name.append(common_name[4])
index_name.append(common_name[2])
index_name.append(common_name[6])
index_name.append(common_name[7])
index_name.append(common_name[12])
index_name.append(common_name[13])
index_name.append(common_name[14])
index_name.append(common_name[15])
index_name.append(common_name[9])
index_name.append(common_name[10])
index_name.append(common_name[11])

#index_name

# %%
def searcher(Q, R):
    params = {
      "engine": "google",
      "q": Q,
      "api_key": homeDepot_API
    }
    search = GoogleSearch(params)
    results = search.get_dict()
    products = results["organic_results"]
   
    for p in products[0:10]:
        try:

            title = p['title']
            link = p['link']
            price = (p['rich_snippet']['top']['detected_extensions']['price'])            
    
            result = {'Manufactures Description': title, 'Link': link, 'Material Price': price, 'VENDOR': link}
            R.append(result)
                        
        except (KeyError):
            price = 'NaN'
            result = {'Manufactures Description': title, 'Link': link, 'Material Price': price, 'VENDOR': link}
            R.append(result)

# %% [markdown]
# STEP 2: TRANSFORM

# %%
# Grab raw data

R = []
for i in range(16):
    R_i = []
   
    searcher(index_name[i], R_i)
    R.append(R_i)
# Out:
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search

# %%
# Create a data frame
all_prices = []
lowest_prices = []
for i in range(len(R)):
    df = pd.DataFrame(R[i]).assign(Common_name=index_name[i])
# Create a 'Vendor location' column    
    df['Vendor Location'] = (np.where(df['VENDOR'].str.contains('.'), df['VENDOR'].str.split('.').str[1], df['VENDOR']))
    df.drop(columns =['VENDOR'], inplace = True)
# Change data type of price to numeric and drop NaN's    
    df['Material Price'] = df['Material Price'].apply(pd.to_numeric, args=('coerce',))
    df.dropna(inplace=True)
# Filter out scaling issues
    if i == 0:
        df.drop(df[df['Material Price'] < .77].index, inplace = True)
    if i == 1 or i == 2:
        df.drop(df[df['Material Price'] > 130].index, inplace = True)
        df.drop(df[df['Material Price'] < 2.60].index, inplace = True)
    if i == 4:
        df.drop(df[df['Material Price'] > 130].index, inplace = True)
    if i == 5 or i == 8:
        df.drop(df[df['Material Price'] > 5.98].index, inplace = True)
    if i == 9:
        df.drop(df[df['Material Price'] < 75].index, inplace = True)
    if i == 11 or i == 12:
        df.drop(df[df['Material Price'] < 130].index, inplace = True)
    if i == 13:
        df.drop(df[df['Material Price'] < 500].index, inplace = True)
    if i == 14 or i == 15:
        df.drop(df[df['Material Price'] < 2.60].index, inplace = True)
    df.drop(columns =['Manufactures Description'], inplace = True)
    df['Material Description'] = df['Common_name']
    df.drop(columns =['Common_name'], inplace = True)
    df = df.iloc[:,[3,1,2,0]]
    
    df["Formatted Datetime"] = datetime.now().strftime("%m/%d/%Y %H:%M:%S")
    
    lowest_prices.append(df.min())
    all_prices.append(df)
clean_df = pd.concat(all_prices, axis=0, ignore_index=True)
working_df = pd.DataFrame(lowest_prices)

# %%
clean_df
# Out:
#                                  Material Description  Material Price  \
# 0   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            7.22
# 1   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            5.99
# 2   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            4.59
# 3   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            5.88
# 4   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           11.91
# 5   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           10.47
# 6   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...            8.36
# 7   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           98.99
# 8   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           20.62
# 9   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           17.55
# 10  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...            8.90
# 11  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           33.34
# 12  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           24.99
# 13  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...          100.00
# 14  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            3.98
# 15  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            5.99
# 16  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            2.10
# 17  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            5.99
# 18  3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 19  3/4 in. Standard Fitting Electric Metallic Tub...            3.66
# 20  3/4 in. Standard Fitting Electric Metallic Tub...            5.99
# 21  3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 22  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            3.98
# 23  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 24  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 25  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...          150.00
# 26  3/4 in. Electrical Metallic Tube (EMT) Set-Scr...            4.60
# 27  3/4 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 28  1 in. Electrical Metallic Tube (EMT) Set-Screw...            1.60
# 29     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          114.00
# 30     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          111.07
# 31     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          117.00
# 32     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire           84.99
# 33  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          159.00
# 34  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          159.00
# 35  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          149.00
# 36  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          289.00
# 37  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          289.00
# 38  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          315.01
# 39    500 ft. 4 Gauge Black Stranded Copper THHN Wire          613.64
# 40    500 ft. 4 Gauge Black Stranded Copper THHN Wire         1047.78
# 41   500 ft. 10 Gauge Black Stranded Copper THHN Wire          145.00
# 42   500 ft. 10 Gauge Black Stranded Copper THHN Wire          145.00
# 43   500 ft. 10 Gauge Black Stranded Copper THHN Wire          155.99
# 44   500 ft. 10 Gauge Black Stranded Copper THHN Wire          165.00
#
#          Vendor Location                                               Link  \
# 0              homedepot  https://www.homedepot.com/p/1-2-in-x-10-ft-Ele...
# 1                  lowes  https://www.lowes.com/pd/Common-1-2-in-Actual-...
# 2   gordonelectricsupply  https://www.gordonelectricsupply.com/p/Allied-...
# 3            supplyworks  https://www.supplyworks.com/Sku/2487615/12-in-...
# 4              homedepot  https://www.homedepot.com/p/3-4-in-x-10-ft-Ele...
# 5               ebarnett  https://www.ebarnett.com/Sku/2487616/34-in-x-1...
# 6   gordonelectricsupply  https://www.gordonelectricsupply.com/p/Allied-...
# 7                 amazon  https://www.amazon.com/EMT-Conduit-10-ft-Steel...
# 8              homedepot  https://www.homedepot.com/p/1-in-x-10-ft-Elect...
# 9                 wilmar  https://www.wilmar.com/Sku/24-87610/allied-tub...
# 10         linemen-tools  https://www.linemen-tools.com/Electrical_Mater...
# 11            dkhardware  https://www.dkhardware.com/allied-tube-and-con...
# 12             truevalue  https://www.truevalue.com/emt-conduit-steel-th...
# 13            mecampbell  https://www.mecampbell.com/1-x-10-ft-emt-condu...
# 14             homedepot  https://www.homedepot.com/p/Halex-1-2-in-Elect...
# 15                amazon  https://www.amazon.com/Halex-26270-STEEL-CONNE...
# 16                wilmar  https://www.wilmar.com/Sku/202077151/halex-12-...
# 17                 lowes  https://www.lowes.com/pd/Sigma-Electric-ProCon...
# 18             homedepot  https://www.homedepot.com/p/Halex-3-4-in-Elect...
# 19           supplyworks  https://www.supplyworks.com/Sku/202328185/hale...
# 20                 lowes  https://www.lowes.com/pd/Sigma-Electric-ProCon...
# 21             pinterest  https://www.pinterest.com/pin/230668812499210604/
# 22             homedepot  https://www.homedepot.com/p/Halex-1-2-in-Elect...
# 23                amazon  https://www.amazon.com/Halex-26270-STEEL-CONNE...
# 24                 lowes  https://www.lowes.com/pd/Sigma-Electric-ProCon...
# 25           supplyworks  https://www.supplyworks.com/Sku/202077144/hale...
# 26             homedepot  https://www.homedepot.com/p/Halex-3-4-in-Elect...
# 27                 lowes  https://www.lowes.com/pd/Halex-3-4-in-EMT-STEE...
# 28             homedepot  https://www.homedepot.com/p/Halex-1-in-Electri...
# 29                amazon  https://www.amazon.com/SOUTHWIRE-COMPANY-28827...
# 30                  ebay  https://www.ebay.com/b/14-2-Romex-Indiana-OTHE...
# 31         socalelectric  https://www.socalelectric.com/products/250-ft-...
# 32           landmsupply  https://www.landmsupply.com/southwire-romex-si...
# 33             homedepot  https://www.homedepot.com/p/Southwire-250-ft-1...
# 34                 lowes  https://www.lowes.com/pd/Southwire-Romex-SIMpu...
# 35             homedepot  https://www.homedepot.com/p/Southwire-250-ft-1...
# 36             homedepot  https://www.homedepot.com/p/Southwire-250-ft-1...
# 37                 lowes  https://www.lowes.com/pd/Southwire-Romex-SIMpu...
# 38                  ebay  https://www.ebay.com/b/12-3-Romex/92078/bn_702...
# 39                amazon  https://www.amazon.com/SOUTHWIRE-COMPANY-LL-20...
# 40                  ebay                 https://www.ebay.com/p/17040228268
# 41             homedepot  https://www.homedepot.com/p/Southwire-500-ft-1...
# 42             homedepot  https://www.homedepot.com/p/Cerrowire-500-ft-1...
# 43                amazon  https://www.amazon.com/Gauge-Stranded-Copper-B...
# 44   wireandcableyourway  https://www.wireandcableyourway.com/10-awg-thh...
#
#      Formatted Datetime
# 0   10/26/2022 13:58:13
# 1   10/26/2022 13:58:13
# 2   10/26/2022 13:58:13
# 3   10/26/2022 13:58:13
# 4   10/26/2022 13:58:13
# 5   10/26/2022 13:58:13
# 6   10/26/2022 13:58:13
# 7   10/26/2022 13:58:13
# 8   10/26/2022 13:58:13
# 9   10/26/2022 13:58:13
# 10  10/26/2022 13:58:13
# 11  10/26/2022 13:58:13
# 12  10/26/2022 13:58:13
# 13  10/26/2022 13:58:13
# 14  10/26/2022 13:58:13
# 15  10/26/2022 13:58:13
# 16  10/26/2022 13:58:13
# 17  10/26/2022 13:58:13
# 18  10/26/2022 13:58:13
# 19  10/26/2022 13:58:13
# 20  10/26/2022 13:58:13
# 21  10/26/2022 13:58:13
# 22  10/26/2022 13:58:13
# 23  10/26/2022 13:58:13
# 24  10/26/2022 13:58:13
# 25  10/26/2022 13:58:13
# 26  10/26/2022 13:58:13
# 27  10/26/2022 13:58:13
# 28  10/26/2022 13:58:13
# 29  10/26/2022 13:58:13
# 30  10/26/2022 13:58:13
# 31  10/26/2022 13:58:13
# 32  10/26/2022 13:58:13
# 33  10/26/2022 13:58:13
# 34  10/26/2022 13:58:13
# 35  10/26/2022 13:58:13
# 36  10/26/2022 13:58:13
# 37  10/26/2022 13:58:13
# 38  10/26/2022 13:58:13
# 39  10/26/2022 13:58:13
# 40  10/26/2022 13:58:13
# 41  10/26/2022 13:58:13
# 42  10/26/2022 13:58:13
# 43  10/26/2022 13:58:13
# 44  10/26/2022 13:58:13

# %%
working_df
# Out:
#                                  Material Description  Material Price  \
# 0   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            4.59
# 1   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...            8.36
# 2   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...            8.90
# 3   1/2 in. Electric Metallic Tube (EMT) Set-Screw...            2.10
# 4   3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 5                                                 NaN             NaN
# 6   1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            3.98
# 7   3/4 in. Electrical Metallic Tube (EMT) Set-Scr...            4.60
# 8   1 in. Electrical Metallic Tube (EMT) Set-Screw...            1.60
# 9      250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire           84.99
# 10  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          159.00
# 11  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          149.00
# 12  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          289.00
# 13    500 ft. 4 Gauge Black Stranded Copper THHN Wire          613.64
# 14                                                NaN             NaN
# 15   500 ft. 10 Gauge Black Stranded Copper THHN Wire          145.00
#
#          Vendor Location                                               Link  \
# 0   gordonelectricsupply  https://www.gordonelectricsupply.com/p/Allied-...
# 1                 amazon  https://www.amazon.com/EMT-Conduit-10-ft-Steel...
# 2             dkhardware  https://www.dkhardware.com/allied-tube-and-con...
# 3                 amazon  https://www.amazon.com/Halex-26270-STEEL-CONNE...
# 4              homedepot  https://www.homedepot.com/p/Halex-3-4-in-Elect...
# 5                    NaN                                                NaN
# 6                 amazon  https://www.amazon.com/Halex-26270-STEEL-CONNE...
# 7              homedepot  https://www.homedepot.com/p/Halex-3-4-in-Elect...
# 8              homedepot  https://www.homedepot.com/p/Halex-1-in-Electri...
# 9                 amazon  https://www.amazon.com/SOUTHWIRE-COMPANY-28827...
# 10             homedepot  https://www.homedepot.com/p/Southwire-250-ft-1...
# 11             homedepot  https://www.homedepot.com/p/Southwire-250-ft-1...
# 12                  ebay  https://www.ebay.com/b/12-3-Romex/92078/bn_702...
# 13                amazon  https://www.amazon.com/SOUTHWIRE-COMPANY-LL-20...
# 14                   NaN                                                NaN
# 15                amazon  https://www.amazon.com/Gauge-Stranded-Copper-B...
#
#      Formatted Datetime
# 0   10/26/2022 13:58:13
# 1   10/26/2022 13:58:13
# 2   10/26/2022 13:58:13
# 3   10/26/2022 13:58:13
# 4   10/26/2022 13:58:13
# 5                   NaN
# 6   10/26/2022 13:58:13
# 7   10/26/2022 13:58:13
# 8   10/26/2022 13:58:13
# 9   10/26/2022 13:58:13
# 10  10/26/2022 13:58:13
# 11  10/26/2022 13:58:13
# 12  10/26/2022 13:58:13
# 13  10/26/2022 13:58:13
# 14                  NaN
# 15  10/26/2022 13:58:13

# %% [markdown]
# STEP 3: LOAD

# %%
# Send a CSV and Excell copies to my computer

xlFile = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\Estimator_Worksheet.xlsx"

book = load_workbook(xlFile)
writer = pd.ExcelWriter(xlFile, engine = 'openpyxl')
writer.book = book

#with pd.ExcelWriter(xlFile) as writer:
working_df.to_excel(writer, sheet_name='Working_Table4')
clean_df.to_excel(writer, sheet_name='Cleaned_Data4')
writer.save()
writer.close()
    
clean_csv = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\clean_df6.csv"
clean_df.to_csv(clean_csv, index=False)

working_csv = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\working_df6.csv"
working_df.to_csv(working_csv, index=False)
