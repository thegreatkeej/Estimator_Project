# %%
# Dependencies
from config import homeDepot_API
from serpapi import GoogleSearch
import pandas as pd
import numpy as np
from datetime import datetime
from openpyxl import load_workbook
import os
os.getcwd()
# Out:
# 'C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\Resources'

# %% [markdown]
# STEP 1: EXTRACT

# %%
# Created Working 'Material Description by grabbing names from Home Depot'

common_name = []

ids = ['100400409', '100400406', '100137321', '100400405', 
       '202241090', '100144234', '202077145', '202077147', 
       '202288508', '202304774', '202304649', '202304645', 
       '202019377', '202316275', '202019375', '202316276']

for i in ids:

    params = {
      "engine": "home_depot_product",
      "product_id": i,
      "api_key": homeDepot_API
    }

    search = GoogleSearch(params)
    results = search.get_dict()
    products = results['product_results']
    
    common_name.append(products['title'])
# Out:
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search

# %%
# Order and establish index_name

index_name = []

index_name.append(common_name[3])
index_name.append(common_name[1])
index_name.append(common_name[0])
index_name.append(common_name[5])
index_name.append(common_name[8])
index_name.append(common_name[4])
index_name.append(common_name[2])
index_name.append(common_name[6])
index_name.append(common_name[7])
index_name.append(common_name[12])
index_name.append(common_name[13])
index_name.append(common_name[14])
index_name.append(common_name[15])
index_name.append(common_name[9])
index_name.append(common_name[10])
index_name.append(common_name[11])

#index_name

# %%
def searcher(Q, R):
    params = {
      "engine": "google",
      "q": Q,
      "api_key": homeDepot_API
    }
    search = GoogleSearch(params)
    results = search.get_dict()
    products = results["organic_results"]
   
    for p in products[0:10]:
        try:

            title = p['title']
            link = p['link']
            price = (p['rich_snippet']['top']['detected_extensions']['price'])            
    
            result = {'Manufactures Description': title, 'Link': link, 'Material Price': price, 'VENDOR': link}
            R.append(result)
                        
        except (KeyError):
            price = 'NaN'
            result = {'Manufactures Description': title, 'Link': link, 'Material Price': price, 'VENDOR': link}
            R.append(result)

# %% [markdown]
# STEP 2: TRANSFORM

# %%
# Grab raw data

R = []
for i in range(16):
    R_i = []
   
    searcher(index_name[i], R_i)
    R.append(R_i)
# Out:
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search

# %%
# Create a data frame
all_prices = []
lowest_prices = []
for i in range(len(R)):
    df = pd.DataFrame(R[i]).assign(Common_name=index_name[i])
# Create a 'Vendor location' column    
    df['Vendor Location'] = (np.where(df['VENDOR'].str.contains('.'), df['VENDOR'].str.split('.').str[1], df['VENDOR']))
    df.drop(columns =['VENDOR'], inplace = True)
# Change data type of price to numeric and drop NaN's    
    df['Material Price'] = df['Material Price'].apply(pd.to_numeric, args=('coerce',))
    df.dropna(inplace=True)
# Filter out scaling issues
    if i == 0:
        df.drop(df[df['Material Price'] < .77].index, inplace = True)
    if i == 1 or i == 2:
        df.drop(df[df['Material Price'] > 130].index, inplace = True)
        df.drop(df[df['Material Price'] < 2.60].index, inplace = True)
    if i == 4:
        df.drop(df[df['Material Price'] > 130].index, inplace = True)
    if i == 5 or i == 8:
        df.drop(df[df['Material Price'] > 5.98].index, inplace = True)
    if i == 9:
        df.drop(df[df['Material Price'] < 75].index, inplace = True)
    if i == 11 or i == 12:
        df.drop(df[df['Material Price'] < 130].index, inplace = True)
    if i == 13:
        df.drop(df[df['Material Price'] < 500].index, inplace = True)
    if i == 14 or i == 15:
        df.drop(df[df['Material Price'] < 2.60].index, inplace = True)
    df.drop(columns =['Manufactures Description'], inplace = True)
    df['Material Description'] = df['Common_name']
    df.drop(columns =['Common_name'], inplace = True)
    df = df.iloc[:,[3,1,2,0]]
    
    df["Formatted Datetime"] = datetime.now().strftime("%m/%d/%Y %H:%M:%S")
    
    lowest_prices.append(df.min())
    all_prices.append(df)
clean_df = pd.concat(all_prices, axis=0, ignore_index=True)
working_df = pd.DataFrame(lowest_prices)

# %%
clean_df
# Out:
#                                  Material Description  Material Price  \
# 0   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            7.22
# 1   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            7.68
# 2   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            5.88
# 3   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            9.09
# 4   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           11.91
# 5   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           10.47
# 6   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...            8.36
# 7   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           98.99
# 8   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           20.62
# 9   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           17.55
# 10  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...            8.90
# 11  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           24.99
# 12  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            3.98
# 13  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            5.99
# 14  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            2.10
# 15  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            5.99
# 16  3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 17  3/4 in. Standard Fitting Electric Metallic Tub...            3.66
# 18  3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 19  3/4 in. Standard Fitting Electric Metallic Tub...            3.60
# 20  1 in. Electric Metallic Tube (EMT) Set-Screw C...            1.15
# 21  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            3.98
# 22  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 23  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 24  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            2.29
# 25  3/4 in. Electrical Metallic Tube (EMT) Set-Scr...            4.60
# 26  3/4 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 27  1 in. Electrical Metallic Tube (EMT) Set-Screw...            1.60
# 28     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          118.00
# 29     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          114.00
# 30     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          111.99
# 31     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire           84.99
# 32  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          158.00
# 33  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          158.00
# 34  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          149.00
# 35  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          149.00
# 36  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          200.02
# 37  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          289.00
# 38  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          279.00
# 39  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          315.01
# 40  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          339.09
# 41    500 ft. 4 Gauge Black Stranded Copper THHN Wire          765.00
# 42    500 ft. 4 Gauge Black Stranded Copper THHN Wire          613.64
# 43    500 ft. 4 Gauge Black Stranded Copper THHN Wire         1047.78
# 44    500 ft. 6 Gauge Black Stranded Copper THHN Wire          379.00
# 45    500 ft. 6 Gauge Black Stranded Copper THHN Wire          470.43
# 46    500 ft. 6 Gauge Black Stranded Copper THHN Wire          445.81
# 47   500 ft. 10 Gauge Black Stranded Copper THHN Wire          145.00
# 48   500 ft. 10 Gauge Black Stranded Copper THHN Wire          155.99
# 49   500 ft. 10 Gauge Black Stranded Copper THHN Wire          398.95
#
#          Vendor Location                                               Link  \
# 0              homedepot  https://www.homedepot.com/p/1-2-in-x-10-ft-Ele...
# 1                  lowes  https://www.lowes.com/pd/Common-1-2-in-Actual-...
# 2            supplyworks  https://www.supplyworks.com/Sku/2487615/12-in-...
# 3                   ebay                  https://www.ebay.com/p/1700352648
# 4              homedepot  https://www.homedepot.com/p/3-4-in-x-10-ft-Ele...
# 5               ebarnett  https://www.ebarnett.com/Sku/2487616/34-in-x-1...
# 6   gordonelectricsupply  https://www.gordonelectricsupply.com/p/Allied-...
# 7                 amazon  https://www.amazon.com/EMT-Conduit-10-ft-Steel...
# 8              homedepot  https://www.homedepot.com/p/1-in-x-10-ft-Elect...
# 9                 wilmar  https://www.wilmar.com/Sku/24-87610/allied-tub...
# 10         linemen-tools  https://www.linemen-tools.com/Electrical_Mater...
# 11             truevalue  https://www.truevalue.com/emt-conduit-steel-th...
# 12             homedepot  https://www.homedepot.com/p/Halex-1-2-in-Elect...
# 13                amazon  https://www.amazon.com/Halex-26270-STEEL-CONNE...
# 14                wilmar  https://www.wilmar.com/Sku/202077151/halex-12-...
# 15                 lowes  https://www.lowes.com/pd/Sigma-Electric-ProCon...
# 16             homedepot  https://www.homedepot.com/p/Halex-3-4-in-Elect...
# 17           supplyworks  https://www.supplyworks.com/Sku/202328185/hale...
# 18             pinterest  https://www.pinterest.com/pin/230668812499210604/
# 19            superarbor  https://www.superarbor.io/products/100163157-3...
# 20             homedepot  https://www.homedepot.com/p/Halex-1-in-Electri...
# 21             homedepot  https://www.homedepot.com/p/Halex-1-2-in-Elect...
# 22                amazon  https://www.amazon.com/Halex-26270-STEEL-CONNE...
# 23                 lowes  https://www.lowes.com/pd/Sigma-Electric-ProCon...
# 24                wilmar  https://www.wilmar.com/Sku/202077151/halex-12-...
# 25             homedepot  https://www.homedepot.com/p/Halex-3-4-in-Elect...
# 26                 lowes  https://www.lowes.com/pd/Halex-3-4-in-EMT-STEE...
# 27             homedepot  https://www.homedepot.com/p/Halex-1-in-Electri...
# 28             homedepot  https://www.homedepot.com/p/Southwire-250-ft-1...
# 29                amazon  https://www.amazon.com/SOUTHWIRE-COMPANY-28827...
# 30                  ebay              https://www.ebay.com/itm/363478081520
# 31           landmsupply  https://www.landmsupply.com/southwire-romex-si...
# 32             homedepot  https://www.homedepot.com/p/Southwire-250-ft-1...
# 33                 lowes  https://www.lowes.com/pd/Southwire-Romex-SIMpu...
# 34             homedepot  https://www.homedepot.com/p/Southwire-250-ft-1...
# 35                 lowes  https://www.lowes.com/pd/Southwire-Romex-SIMpu...
# 36            dkhardware  https://www.dkhardware.com/southwire-250-ft-12...
# 37             homedepot  https://www.homedepot.com/p/Southwire-250-ft-1...
# 38                 lowes  https://www.lowes.com/pd/Southwire-Romex-SIMpu...
# 39                  ebay  https://www.ebay.com/b/12-3-Romex/92078/bn_702...
# 40              qcsupply  https://www.qcsupply.com/12-3-romex-simpull-wi...
# 41             homedepot  https://www.homedepot.com/p/Southwire-500-ft-4...
# 42                amazon  https://www.amazon.com/SOUTHWIRE-COMPANY-LL-20...
# 43                  ebay                 https://www.ebay.com/p/17040228268
# 44             homedepot  https://www.homedepot.com/p/Southwire-500-ft-6...
# 45                amazon  https://www.amazon.com/Cerrowire-112-4201J-500...
# 46                  ebay              https://www.ebay.com/itm/203860011450
# 47             homedepot  https://www.homedepot.com/p/Southwire-500-ft-1...
# 48                amazon  https://www.amazon.com/Gauge-Stranded-Copper-B...
# 49       cooper-electric  https://www.cooper-electric.com/product/detail...
#
#      Formatted Datetime
# 0   10/24/2022 14:10:34
# 1   10/24/2022 14:10:34
# 2   10/24/2022 14:10:34
# 3   10/24/2022 14:10:34
# 4   10/24/2022 14:10:34
# 5   10/24/2022 14:10:34
# 6   10/24/2022 14:10:34
# 7   10/24/2022 14:10:34
# 8   10/24/2022 14:10:34
# 9   10/24/2022 14:10:34
# 10  10/24/2022 14:10:34
# 11  10/24/2022 14:10:34
# 12  10/24/2022 14:10:34
# 13  10/24/2022 14:10:34
# 14  10/24/2022 14:10:34
# 15  10/24/2022 14:10:34
# 16  10/24/2022 14:10:34
# 17  10/24/2022 14:10:34
# 18  10/24/2022 14:10:34
# 19  10/24/2022 14:10:34
# 20  10/24/2022 14:10:34
# 21  10/24/2022 14:10:34
# 22  10/24/2022 14:10:34
# 23  10/24/2022 14:10:34
# 24  10/24/2022 14:10:34
# 25  10/24/2022 14:10:34
# 26  10/24/2022 14:10:34
# 27  10/24/2022 14:10:34
# 28  10/24/2022 14:10:34
# 29  10/24/2022 14:10:34
# 30  10/24/2022 14:10:34
# 31  10/24/2022 14:10:34
# 32  10/24/2022 14:10:34
# 33  10/24/2022 14:10:34
# 34  10/24/2022 14:10:34
# 35  10/24/2022 14:10:34
# 36  10/24/2022 14:10:34
# 37  10/24/2022 14:10:34
# 38  10/24/2022 14:10:34
# 39  10/24/2022 14:10:34
# 40  10/24/2022 14:10:34
# 41  10/24/2022 14:10:34
# 42  10/24/2022 14:10:34
# 43  10/24/2022 14:10:34
# 44  10/24/2022 14:10:34
# 45  10/24/2022 14:10:34
# 46  10/24/2022 14:10:34
# 47  10/24/2022 14:10:34
# 48  10/24/2022 14:10:34
# 49  10/24/2022 14:10:34

# %%
working_df
# Out:
#                                  Material Description  Material Price  \
# 0   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            5.88
# 1   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...            8.36
# 2   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...            8.90
# 3   1/2 in. Electric Metallic Tube (EMT) Set-Screw...            2.10
# 4   3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 5   1 in. Electric Metallic Tube (EMT) Set-Screw C...            1.15
# 6   1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            2.29
# 7   3/4 in. Electrical Metallic Tube (EMT) Set-Scr...            4.60
# 8   1 in. Electrical Metallic Tube (EMT) Set-Screw...            1.60
# 9      250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire           84.99
# 10  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          158.00
# 11  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          149.00
# 12  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          279.00
# 13    500 ft. 4 Gauge Black Stranded Copper THHN Wire          613.64
# 14    500 ft. 6 Gauge Black Stranded Copper THHN Wire          379.00
# 15   500 ft. 10 Gauge Black Stranded Copper THHN Wire          145.00
#
#    Vendor Location                                               Link  \
# 0             ebay                  https://www.ebay.com/p/1700352648
# 1           amazon  https://www.amazon.com/EMT-Conduit-10-ft-Steel...
# 2        homedepot  https://www.homedepot.com/p/1-in-x-10-ft-Elect...
# 3           amazon  https://www.amazon.com/Halex-26270-STEEL-CONNE...
# 4        homedepot  https://www.homedepot.com/p/Halex-3-4-in-Elect...
# 5        homedepot  https://www.homedepot.com/p/Halex-1-in-Electri...
# 6           amazon  https://www.amazon.com/Halex-26270-STEEL-CONNE...
# 7        homedepot  https://www.homedepot.com/p/Halex-3-4-in-Elect...
# 8        homedepot  https://www.homedepot.com/p/Halex-1-in-Electri...
# 9           amazon  https://www.amazon.com/SOUTHWIRE-COMPANY-28827...
# 10       homedepot  https://www.homedepot.com/p/Southwire-250-ft-1...
# 11      dkhardware  https://www.dkhardware.com/southwire-250-ft-12...
# 12            ebay  https://www.ebay.com/b/12-3-Romex/92078/bn_702...
# 13          amazon  https://www.amazon.com/SOUTHWIRE-COMPANY-LL-20...
# 14          amazon  https://www.amazon.com/Cerrowire-112-4201J-500...
# 15          amazon  https://www.amazon.com/Gauge-Stranded-Copper-B...
#
#      Formatted Datetime
# 0   10/24/2022 14:10:34
# 1   10/24/2022 14:10:34
# 2   10/24/2022 14:10:34
# 3   10/24/2022 14:10:34
# 4   10/24/2022 14:10:34
# 5   10/24/2022 14:10:34
# 6   10/24/2022 14:10:34
# 7   10/24/2022 14:10:34
# 8   10/24/2022 14:10:34
# 9   10/24/2022 14:10:34
# 10  10/24/2022 14:10:34
# 11  10/24/2022 14:10:34
# 12  10/24/2022 14:10:34
# 13  10/24/2022 14:10:34
# 14  10/24/2022 14:10:34
# 15  10/24/2022 14:10:34

# %% [markdown]
# STEP 3: LOAD

# %%
# Send a CSV and Excell copies to my computer

xlFile = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\Estimator_Worksheet.xlsx"

book = load_workbook(xlFile)
writer = pd.ExcelWriter(xlFile, engine = 'openpyxl')
writer.book = book

#with pd.ExcelWriter(xlFile) as writer:
working_df.to_excel(writer, sheet_name='Working_Table2')
clean_df.to_excel(writer, sheet_name='Cleaned_Data2')
writer.save()
writer.close()
    
clean_csv = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\clean_df4.csv"
clean_df.to_csv(clean_csv, index=False)

working_csv = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\working_df4.csv"
working_df.to_csv(working_csv, index=False)
