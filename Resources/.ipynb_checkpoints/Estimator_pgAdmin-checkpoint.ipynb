# %% [markdown]
# THIS SCRIPT CREATES SEPERATE TABLES FOR PGADMIN

# %%
# Dependencies
from config import homeDepot_API
from config import db_password
import psycopg2
from serpapi import GoogleSearch
import pandas as pd
import numpy as np
from datetime import datetime
from sqlalchemy import create_engine
import os

# %% [markdown]
# STEP 1: EXTRACT

# %%
# Creating 'material_description' and 'product_id' by extracting from Home Depot. The 'product_id is what is used to query.'
material_name = []
product_id = []

ids = ['100400409', '100400406', '100137321', '100400405', 
       '202241090', '100144234', '202077145', '202077147', 
       '202288508', '202304774', '202304649', '202304645', 
       '202019377', '202316275', '202019375', '202316276']

for i in ids:

    params = {
      "engine": "home_depot_product",
      "product_id": i,
      "api_key": homeDepot_API
    }

    search = GoogleSearch(params)
    results = search.get_dict()
    products = results['product_results']
    
    material_name.append(products['title'])
    product_id.append(products['product_id'])
# Out:
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search

# %%
# Creating 'material_description_table'
material_description_table = pd.DataFrame(data={'product_id': product_id, 'material_description': material_name}).assign(formatted_datetime=datetime.now().strftime("%m/%d/%Y %H:%M:%S"))
material_description_table = material_description_table.iloc[[3,1,0,5,8,4,2,6,7,12,13,14,15,9,10,11],:]
material_description_table = material_description_table.reset_index(drop=True).set_index('product_id')

material_description_table
# Out:
#                                          material_description  \
# product_id
# 100400405   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...
# 100400406   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...
# 100400409   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...
# 100144234   1/2 in. Electric Metallic Tube (EMT) Set-Screw...
# 202288508   3/4 in. Standard Fitting Electric Metallic Tub...
# 202241090   1 in. Electric Metallic Tube (EMT) Set-Screw C...
# 100137321   1/2 in. Electrical Metallic Tube (EMT) Set-Scr...
# 202077145   3/4 in. Electrical Metallic Tube (EMT) Set-Scr...
# 202077147   1 in. Electrical Metallic Tube (EMT) Set-Screw...
# 202019377      250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire
# 202316275   250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire
# 202019375   250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire
# 202316276   250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire
# 202304774     500 ft. 4 Gauge Black Stranded Copper THHN Wire
# 202304649     500 ft. 6 Gauge Black Stranded Copper THHN Wire
# 202304645    500 ft. 10 Gauge Black Stranded Copper THHN Wire
#
#              formatted_datetime
# product_id
# 100400405   11/02/2022 18:33:29
# 100400406   11/02/2022 18:33:29
# 100400409   11/02/2022 18:33:29
# 100144234   11/02/2022 18:33:29
# 202288508   11/02/2022 18:33:29
# 202241090   11/02/2022 18:33:29
# 100137321   11/02/2022 18:33:29
# 202077145   11/02/2022 18:33:29
# 202077147   11/02/2022 18:33:29
# 202019377   11/02/2022 18:33:29
# 202316275   11/02/2022 18:33:29
# 202019375   11/02/2022 18:33:29
# 202316276   11/02/2022 18:33:29
# 202304774   11/02/2022 18:33:29
# 202304649   11/02/2022 18:33:29
# 202304645   11/02/2022 18:33:29

# %%
# This function uses the material names extracted from Home Depot as query (Q) and returns results (R)
def searcher(Q, R):
    params = {
      "engine": "google",
      "q": Q,
      "api_key": homeDepot_API
    }
    search = GoogleSearch(params)
    results = search.get_dict()
    products = results["organic_results"]
    
# It will grab up to 10 prices per result but some suppliers don't list their prices online so it 
# appends 'NaN' in place of missing prices 
    for p in products[0:10]:
        try:

            title = p['title']
            link = p['link']
            price = (p['rich_snippet']['top']['detected_extensions']['price'])            
    
            result = {'Manufactures Description': title,'material_price': price, 'VENDOR': link, 'link': link}
            R.append(result)
                        
        except (KeyError):
            price = 'NaN'
            result = {'Manufactures Description': title, 'link': link, 'material_price': price, 'VENDOR': link}
            R.append(result)

# %%
# Extracts raw data to create remaining tables

R = []
for i in range(16):
    R_i = []
   
    searcher(material_name[i], R_i)
    R.append(R_i)
# Out:
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search

# %% [markdown]
# STEP 2: TRANSFORM

# %%
# Creates cleaned data frames from raw data
all_prices = []
lowest_prices = []

for i in range(len(R)):
    df = pd.DataFrame(R[i]).assign(material_description=material_name[i])
    df['product_id'] = product_id[i]
# Create a 'Vendor location' column    
    df['vendor_location'] = (np.where(df['VENDOR'].str.contains('.'), df['VENDOR'].str.split('.').str[1], df['VENDOR']))
    df.drop(columns =['VENDOR'], inplace = True)
# Change data type of price to numeric and drop NaN's    
    df['material_price'] = df['material_price'].apply(pd.to_numeric, args=('coerce',))
    df.dropna(inplace=True)
    
# Filter out scaling issues
    if i == 0:
        df.drop(df[df['material_price'] < 2.60].index, inplace = True)
        df.drop(df[df['material_price'] > 75].index, inplace = True)
    if i == 1 or i ==3:
        df.drop(df[df['material_price'] < 1.30].index, inplace = True)
        df.drop(df[df['material_price'] > 75].index, inplace = True)  
    if i == 4 or i == 7:
        df.drop(df[df['material_price'] > 5].index, inplace = True) 
    if i == 9 or i == 10:
        df.drop(df[df['material_price'] < 260].index, inplace = True)
    if i == 11 or i == 12:
        df.drop(df[df['material_price'] < 75].index, inplace = True)   
    if i == 13 or i == 14 or i == 15:
        df.drop(df[df['material_price'] < 130].index, inplace = True)
        
    df.drop(columns =['Manufactures Description'], inplace = True)
    df = df.iloc[:,[2,0,3,4,1]]    
    df["formatted_datetime"] = datetime.now().strftime("%m/%d/%Y %H:%M:%S")
    
    lowest_prices.append(df.min())
    all_prices.append(df)
clean_df = pd.concat(all_prices, axis=0, ignore_index=True)
working_df = pd.DataFrame(lowest_prices)
working_df = working_df.iloc[[3,1,0,5,8,4,2,6,7,12,13,14,15,9,10,11],:]
working_df = working_df.reset_index(drop=True)

# %%
clean_df
# Out:
#                                  material_description  material_price  \
# 0   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           20.62
# 1   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           17.55
# 2   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           11.91
# 3   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           10.47
# 4   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...            8.60
# 5   1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            3.98
# 6   1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 7   1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 8   1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            2.10
# 9   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            7.22
# 10  1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            5.99
# 11  1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            4.86
# 12  1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            5.88
# 13  1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            7.24
# 14  1 in. Electric Metallic Tube (EMT) Set-Screw C...            1.15
# 15  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            3.98
# 16  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            8.54
# 17  3/4 in. Electrical Metallic Tube (EMT) Set-Scr...            4.60
# 18  3/4 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 19  3/4 in. Electrical Metallic Tube (EMT) Set-Scr...           20.00
# 20  1 in. Electrical Metallic Tube (EMT) Set-Screw...            1.60
# 21  1 in. Electrical Metallic Tube (EMT) Set-Screw...            1.99
# 22  3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 23  3/4 in. Standard Fitting Electric Metallic Tub...            5.99
# 24  3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 25    500 ft. 4 Gauge Black Stranded Copper THHN Wire          709.00
# 26    500 ft. 4 Gauge Black Stranded Copper THHN Wire          613.64
# 27    500 ft. 4 Gauge Black Stranded Copper THHN Wire         1047.78
# 28    500 ft. 6 Gauge Black Stranded Copper THHN Wire          379.00
# 29    500 ft. 6 Gauge Black Stranded Copper THHN Wire          470.43
# 30    500 ft. 6 Gauge Black Stranded Copper THHN Wire          445.81
# 31   500 ft. 10 Gauge Black Stranded Copper THHN Wire          145.00
# 32   500 ft. 10 Gauge Black Stranded Copper THHN Wire          155.99
# 33   500 ft. 10 Gauge Black Stranded Copper THHN Wire          165.00
# 34     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          114.00
# 35     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          118.00
# 36     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          111.07
# 37     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire           84.99
# 38  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          159.00
# 39  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          159.00
# 40  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          172.22
# 41  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          215.00
# 42  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          149.00
# 43  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          149.00
# 44  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          279.00
# 45  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          289.00
#
#    product_id                                    vendor_location  \
# 0   100400409                                          homedepot
# 1   100400409                                             wilmar
# 2   100400406                                          homedepot
# 3   100400406                                           ebarnett
# 4   100400406                               gordonelectricsupply
# 5   100137321                                          homedepot
# 6   100137321                                             amazon
# 7   100137321                                              lowes
# 8   100137321                                             wilmar
# 9   100400405                                          homedepot
# 10  100400405                                              lowes
# 11  100400405                               gordonelectricsupply
# 12  100400405                                           ebarnett
# 13  100400405                                            menards
# 14  202241090                                          homedepot
# 15  100144234                                          homedepot
# 16  100144234                                             amazon
# 17  202077145                                          homedepot
# 18  202077145                                              lowes
# 19  202077145                                             amazon
# 20  202077147                                          homedepot
# 21  202077147  com/p/steel-city-emt-conduit-connector-7859911...
# 22  202288508                                          homedepot
# 23  202288508                                              lowes
# 24  202288508                                          pinterest
# 25  202304774                                          homedepot
# 26  202304774                                             amazon
# 27  202304774                                               ebay
# 9   202019377                                             amazon
# 10  202316275                                               ebay
# 11  202019375                                          homedepot
# 12  202316276                                          homedepot
# 13  202304774                                             amazon
# 14  202304649                                             amazon
# 15  202304645                                             amazon
#
#                                                  link   formatted_datetime
# 0   https://www.ebarnett.com/Sku/2487615/12-in-x-1...  11/02/2022 18:35:04
# 1   https://www.ebarnett.com/Sku/2487616/34-in-x-1...  11/02/2022 18:35:04
# 2   https://www.homedepot.com/p/1-in-x-10-ft-Elect...  11/02/2022 18:35:04
# 3   https://www.amazon.com/Halex-26270-STEEL-CONNE...  11/02/2022 18:35:04
# 4   https://www.homedepot.com/p/Halex-3-4-in-Stand...  11/02/2022 18:35:04
# 5   https://www.homedepot.com/p/Halex-1-in-Electri...  11/02/2022 18:35:04
# 6   https://www.amazon.com/Halex-26270-STEEL-CONNE...  11/02/2022 18:35:04
# 7   https://www.amazon.com/Halex-Electrical-Set-Sc...  11/02/2022 18:35:04
# 8   https://killingworthtruevalue.com/p/steel-city...  11/02/2022 18:35:04
# 9   https://www.amazon.com/SOUTHWIRE-COMPANY-28827...  11/02/2022 18:35:04
# 10              https://www.ebay.com/itm/203704802084  11/02/2022 18:35:04
# 11  https://www.homedepot.com/p/Southwire-250-ft-1...  11/02/2022 18:35:04
# 12  https://www.homedepot.com/p/Southwire-250-ft-1...  11/02/2022 18:35:04
# 13  https://www.amazon.com/SOUTHWIRE-COMPANY-LL-20...  11/02/2022 18:35:04
# 14  https://www.amazon.com/Cerrowire-112-4201J-500...  11/02/2022 18:35:04
# 15  https://www.amazon.com/Gauge-Stranded-Copper-B...  11/02/2022 18:35:04

# %%
# Creates 'all_vendor_table' by extracting from clean_df

all_vendor_table = clean_df.drop_duplicates('vendor_location')
all_vendor_table = all_vendor_table.iloc[:,[3,5]].reset_index(drop=True)
all_vendor_table['vendor_id'] = all_vendor_table.index
all_vendor_table = all_vendor_table.iloc[:,[2,0,1]].set_index('vendor_id')
all_vendor_table
# Out:
#                                              vendor_location  \
# vendor_id
# 0                                                  homedepot
# 1                                                     wilmar
# 2                                                   ebarnett
# 3                                       gordonelectricsupply
# 4                                                     amazon
# 5                                                      lowes
# 6                                                    menards
# 7          com/p/steel-city-emt-conduit-connector-7859911...
# 8                                                  pinterest
# 9                                                       ebay
# 10                                       wireandcableyourway
# 11                                               landmsupply
# 12                                                   walmart
#
#             formatted_datetime
# vendor_id
# 0          11/02/2022 18:35:04
# 1          11/02/2022 18:35:04
# 2          11/02/2022 18:35:04
# 3          11/02/2022 18:35:04
# 4          11/02/2022 18:35:04
# 5          11/02/2022 18:35:04
# 6          11/02/2022 18:35:04
# 7          11/02/2022 18:35:04
# 8          11/02/2022 18:35:04
# 9          11/02/2022 18:35:04
# 10         11/02/2022 18:35:04
# 11         11/02/2022 18:35:04
# 12         11/02/2022 18:35:04

# %%
locations = all_vendor_table["vendor_location"].values.tolist()

headquarters = []

for location in locations:
    params = {
      "q": f"where is {location} headquarters",
      "location": "United States",
      "hl": "en",
      "gl": "us",
      "api_key": homeDepot_API
    }
    search = GoogleSearch(params)
    results = search.get_dict()
    location_results = results["organic_results"]
    headquarters.append(location_results[1]['snippet_highlighted_words'])
    print(location_results[1]['snippet_highlighted_words'])
# Out:
# https://serpapi.com/search
# ['2455 Paces Ferry Rd SE, Atlanta, GA 30339']
# https://serpapi.com/search
# ['28 Biopolis Road Singapore 138568']
# https://serpapi.com/search
# ['Jacksonville, Florida']
# https://serpapi.com/search
# ['Kankakee, 1290 N Hobbie Ave. HQ']
# https://serpapi.com/search
# ['the National Landing neighborhood of Arlington']
# https://serpapi.com/search
# ["1000 Lowe's Blvd. Mooresville NC 28117"]
# https://serpapi.com/search
# ['4777 Menard Drive Eau Claire, Wisconsin 54703 USA']
# https://serpapi.com/search
# ['Steel City', 'connector', 'EMT conduit', 'Connector', 'steel']
# https://serpapi.com/search
# ['San Francisco, CA']
# https://serpapi.com/search
# ['San Jose, CA. 2025 Hamilton Avenue San Jose, California 95125 USA']
# https://serpapi.com/search
# ['1431 7th St Ste 204, Santa Monica, California, 90401']
# https://serpapi.com/search
# ['Grand Rapids, Minnesota, United States']
# https://serpapi.com/search
# ['Bentonville, Arkansas']

# %%
# Creates 'all_price_table' by extracting from clean_df

all_link_table = clean_df
all_link_table['link_id'] = all_link_table.index
all_link_table = all_link_table.iloc[:,[6,4,0,1,2,3,5]].reset_index(drop=True).set_index('link_id')
all_link_table
# Out:
#                                                       link  \
# link_id
# 0        https://www.homedepot.com/p/1-in-x-10-ft-Elect...
# 1        https://www.wilmar.com/Sku/24-87610/allied-tub...
# 2        https://www.homedepot.com/p/3-4-in-x-10-ft-Ele...
# 3        https://www.ebarnett.com/Sku/2487616/34-in-x-1...
# 4        https://www.gordonelectricsupply.com/p/Allied-...
# 5        https://www.homedepot.com/p/Halex-1-2-in-Elect...
# 6        https://www.amazon.com/Halex-26270-STEEL-CONNE...
# 7        https://www.lowes.com/pd/Sigma-Electric-ProCon...
# 8        https://www.wilmar.com/Sku/202077151/halex-12-...
# 9        https://www.homedepot.com/p/1-2-in-x-10-ft-Ele...
# 10       https://www.lowes.com/pd/Common-1-2-in-Actual-...
# 11       https://www.gordonelectricsupply.com/p/Allied-...
# 12       https://www.ebarnett.com/Sku/2487615/12-in-x-1...
# 13       https://www.menards.com/main/electrical/condui...
# 14       https://www.homedepot.com/p/Halex-1-in-Electri...
# 15       https://www.homedepot.com/p/Halex-1-2-in-Elect...
# 16       https://www.amazon.com/Halex-26270-STEEL-CONNE...
# 17       https://www.homedepot.com/p/Halex-3-4-in-Elect...
# 18       https://www.lowes.com/pd/Halex-3-4-in-EMT-STEE...
# 19       https://www.amazon.com/Halex-Electrical-Set-Sc...
# 20       https://www.homedepot.com/p/Halex-1-in-Electri...
# 21       https://killingworthtruevalue.com/p/steel-city...
# 26         500 ft. 4 Gauge Black Stranded Copper THHN Wire          613.64
# 27         500 ft. 4 Gauge Black Stranded Copper THHN Wire         1047.78
# 28         500 ft. 6 Gauge Black Stranded Copper THHN Wire          379.00
# 29         500 ft. 6 Gauge Black Stranded Copper THHN Wire          470.43
# 30         500 ft. 6 Gauge Black Stranded Copper THHN Wire          445.81
# 31        500 ft. 10 Gauge Black Stranded Copper THHN Wire          145.00
# 32        500 ft. 10 Gauge Black Stranded Copper THHN Wire          155.99
# 33        500 ft. 10 Gauge Black Stranded Copper THHN Wire          165.00
# 34          250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          114.00
# 35          250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          118.00
# 36          250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          111.07
# 37          250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire           84.99
# 38       250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          159.00
# 39       250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          159.00
# 40       250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          172.22
# 41       250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          215.00
# 42       250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          149.00
# 43       250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          149.00
# 44       250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          279.00
# 45       250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          289.00
#
#         product_id                                    vendor_location  \
# link_id
# 0        100400409                                          homedepot
# 1        100400409                                             wilmar
# 2        100400406                                          homedepot
# 3        100400406                                           ebarnett
# 4        100400406                               gordonelectricsupply
# 5        100137321                                          homedepot
# 6        100137321                                             amazon
# 7        100137321                                              lowes
# 8        100137321                                             wilmar
# 9        100400405                                          homedepot
# 10       100400405                                              lowes
# 11       100400405                               gordonelectricsupply
# 12       100400405                                           ebarnett
# 13       100400405                                            menards
# 14       202241090                                          homedepot
# 15       100144234                                          homedepot
# 16       100144234                                             amazon
# 17       202077145                                          homedepot
# 18       202077145                                              lowes
# 19       202077145                                             amazon
# 20       202077147                                          homedepot
# 21       202077147  com/p/steel-city-emt-conduit-connector-7859911...
# 22       202288508                                          homedepot
# 23       202288508                                              lowes
# 24       202288508                                          pinterest
# 25       202304774                                          homedepot
# 26       202304774                                             amazon
# 27       202304774                                               ebay
# 28       202304649                                          homedepot
# 29       202304649                                             amazon
# 30       202304649                                               ebay
# 31       202304645                                          homedepot
# 32       202304645                                             amazon
# 33       202304645                                wireandcableyourway
# 34       202019377                                             amazon
# 35       202019377                                              lowes
# 36       202019377                                               ebay
# 37       202019377                                        landmsupply
# 38       202316275                                          homedepot
# 39       202316275                                              lowes
# 40       202316275                                               ebay
# 41       202316275                                            walmart
# 42       202019375                                          homedepot
# 43       202019375                                              lowes
# 44       202316276                                          homedepot
# 45       202316276                                              lowes
#
#           formatted_datetime
# link_id
# 0        11/02/2022 18:35:04
# 1        11/02/2022 18:35:04
# 2        11/02/2022 18:35:04
# 3        11/02/2022 18:35:04
# 4        11/02/2022 18:35:04
# 5        11/02/2022 18:35:04
# 6        11/02/2022 18:35:04
# 7        11/02/2022 18:35:04
# 8        11/02/2022 18:35:04
# 9        11/02/2022 18:35:04
# 10       11/02/2022 18:35:04
# 11       11/02/2022 18:35:04
# 12       11/02/2022 18:35:04
# 13       11/02/2022 18:35:04
# 14       11/02/2022 18:35:04
# 15       11/02/2022 18:35:04
# 16       11/02/2022 18:35:04
# 17       11/02/2022 18:35:04
# 18       11/02/2022 18:35:04
# 19       11/02/2022 18:35:04
# 20       11/02/2022 18:35:04
# 21       11/02/2022 18:35:04
# 22       11/02/2022 18:35:04
# 23       11/02/2022 18:35:04
# 24       11/02/2022 18:35:04
# 25       11/02/2022 18:35:04
# 26       11/02/2022 18:35:04
# 27       11/02/2022 18:35:04
# 28       11/02/2022 18:35:04
# 29       11/02/2022 18:35:04
# 30       11/02/2022 18:35:04
# 31       11/02/2022 18:35:04
# 32       11/02/2022 18:35:04
# 33       11/02/2022 18:35:04
# 34       11/02/2022 18:35:04
# 35       11/02/2022 18:35:04
# 36       11/02/2022 18:35:04
# 37       11/02/2022 18:35:04
# 38       11/02/2022 18:35:04
# 39       11/02/2022 18:35:04
# 40       11/02/2022 18:35:04
# 41       11/02/2022 18:35:04
# 42       11/02/2022 18:35:04
# 43       11/02/2022 18:35:04
# 44       11/02/2022 18:35:04
# 45       11/02/2022 18:35:04

# %%
# Creates 'lowest_price_table' by extracting from Working_df

lowest_price_table = working_df
lowest_price_table = lowest_price_table.iloc[:,[2,0,1,3,4,5]].reset_index(drop=True).set_index('product_id')
lowest_price_table
# Out:
#                                          material_description  material_price  \
# product_id
# 100400405   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            4.86
# 100400406   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...            8.60
# 100400409   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           17.55
# 100144234   1/2 in. Electric Metallic Tube (EMT) Set-Screw...            3.98
# 202288508   3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 202241090   1 in. Electric Metallic Tube (EMT) Set-Screw C...            1.15
# 100137321   1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            2.10
# 202077145   3/4 in. Electrical Metallic Tube (EMT) Set-Scr...            4.60
# 202077147   1 in. Electrical Metallic Tube (EMT) Set-Screw...            1.60
# 202019377      250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire           84.99
# 202316275   250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          159.00
# 202019375   250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          149.00
# 202316276   250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          279.00
# 202304774     500 ft. 4 Gauge Black Stranded Copper THHN Wire          613.64
# 202304649     500 ft. 6 Gauge Black Stranded Copper THHN Wire          379.00
# 202304645    500 ft. 10 Gauge Black Stranded Copper THHN Wire          145.00
#
#                                               vendor_location  \
# product_id
# 100400405                                            ebarnett
# 100400406                                            ebarnett
# 100400409                                           homedepot
# 100144234                                              amazon
# 202288508                                           homedepot
# 202241090                                           homedepot
# 100137321                                              amazon
# 202077145                                              amazon
# 202077147   com/p/steel-city-emt-conduit-connector-7859911...
# 202019377                                              amazon
# 202316275                                                ebay
# 202019375                                           homedepot
# 202316276                                           homedepot
# 202304774                                              amazon
# 202304649                                              amazon
# 202304645                                              amazon
#
#                                                          link  \
# product_id
# 100400405   https://www.ebarnett.com/Sku/2487615/12-in-x-1...
# 100400406   https://www.ebarnett.com/Sku/2487616/34-in-x-1...
# 100400409   https://www.homedepot.com/p/1-in-x-10-ft-Elect...
# 100144234   https://www.amazon.com/Halex-26270-STEEL-CONNE...
# 202288508   https://www.homedepot.com/p/Halex-3-4-in-Stand...
# 202241090   https://www.homedepot.com/p/Halex-1-in-Electri...
# 100137321   https://www.amazon.com/Halex-26270-STEEL-CONNE...
# 202077145   https://www.amazon.com/Halex-Electrical-Set-Sc...
# 202077147   https://killingworthtruevalue.com/p/steel-city...
# 202019377   https://www.amazon.com/SOUTHWIRE-COMPANY-28827...
# 202316275               https://www.ebay.com/itm/203704802084
# 202019375   https://www.homedepot.com/p/Southwire-250-ft-1...
# 202316276   https://www.homedepot.com/p/Southwire-250-ft-1...
# 202304774   https://www.amazon.com/SOUTHWIRE-COMPANY-LL-20...
# 202304649   https://www.amazon.com/Cerrowire-112-4201J-500...
# 202304645   https://www.amazon.com/Gauge-Stranded-Copper-B...
#
#              formatted_datetime
# product_id
# 100400405   11/02/2022 18:35:04
# 100400406   11/02/2022 18:35:04
# 100400409   11/02/2022 18:35:04
# 100144234   11/02/2022 18:35:04
# 202288508   11/02/2022 18:35:04
# 202241090   11/02/2022 18:35:04
# 100137321   11/02/2022 18:35:04
# 202077145   11/02/2022 18:35:04
# 202077147   11/02/2022 18:35:04
# 202019377   11/02/2022 18:35:04
# 202316275   11/02/2022 18:35:04
# 202019375   11/02/2022 18:35:04
# 202316276   11/02/2022 18:35:04
# 202304774   11/02/2022 18:35:04
# 202304649   11/02/2022 18:35:04
# 202304645   11/02/2022 18:35:04

# %% [markdown]
# STEP 3A: LOAD TO PGAdmin

# %%
# Load to PGAdmin

Estimator_Project = f"postgresql://postgres:{db_password}@127.0.0.1:5432/kijahre"
engine = create_engine(Estimator_Project)

# material_description_table.to_sql(name='material_description_table', con=engine, if_exists='replace')
# clean_df.to_sql(name='cleaned_data_example', con=engine)

lowest_price_table.to_sql(name='lowest_price_table2', con=engine)
all_vendor_table.to_sql(name='all_vendor_table2', con=engine, if_exists='replace')
all_link_table.to_sql(name='all_link_table2', con=engine, if_exists='replace')

# %%
# Send a CSV to my computer

lowest_price_db = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\NewDataBases\\lowest_price_db2.csv"
lowest_price_table.to_csv(lowest_price_db, index=False)

all_vendor_db = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\NewDataBases\\all_vendor_db2.csv"
all_vendor_table.to_csv(all_vendor_db, index=False)

all_link_db = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\NewDataBases\\all_link_db2.csv"
all_link_table.to_csv(all_link_db, index=False)
