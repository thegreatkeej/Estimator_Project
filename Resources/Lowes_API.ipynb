# %%
from config import homeDepot_API
from serpapi import GoogleSearch
import pandas as pd
import os
os.getcwd()

params = {
  "engine": "google",
  "q": "3/4 in. x 10 ft. Electric Metallic Tube (EMT) Conduit",
  "api_key": homeDepot_API
}

search = GoogleSearch(params)
results = search.get_dict()
products = results["organic_results"]
# Out:
# https://serpapi.com/search

# %%
items = []
links = []
richSnip = []

def querry(querrys):

    params = {
      "engine": "google",
      "q": querrys,
      "api_key": homeDepot_API
    }

    search = GoogleSearch(params)
    results = search.get_dict()
    products = results["organic_results"]
    
    items.append(products['title'])
    links.append(products['links'])
    richSnip.append(products['rich_snippet'])
    
    return
for p in products[0:5]:
    print(p['title'])
    print(p['link'])
    print(p['rich_snippet'])
    print('-------------------------------------------')
# Out:
# 1/2 in. x 10 ft. Electric Metallic Tube (EMT) Conduit 853428
# https://www.homedepot.com/p/1-2-in-x-10-ft-Electric-Metallic-Tube-EMT-Conduit-853428/100400405
# {'top': {'detected_extensions': {'rating': 4.6, 'reviews': 619, 'price': 7.63, 'currency': '$'}, 'extensions': ['Rating: 4.6', '\u200e619 reviews', '\u200e$7.63']}}
# -------------------------------------------
# 1/2-in x 10-ft Metal Emt Conduit - Lowe's
# https://www.lowes.com/pd/Common-1-2-in-Actual-50-In-Metallic-Emt-10-ft-Conduit/3129551
# {'top': {'detected_extensions': {'rating': 4.5, 'reviews': 79, 'price': 7.68, 'currency': '$'}, 'extensions': ['Rating: 4.5', '\u200e79 reviews', '\u200e$7.68', '\u200eOut of stock']}}
# -------------------------------------------
# 1/2 In. X 10 Ft. Electric Metallic Tube (Emt) Conduit
# https://www.supplyworks.com/Sku/2487615/12-in-x-10-ft-electric-metallic-tube-emt-conduit-091111020018-853428
# {'top': {'detected_extensions': {'price': 5.88, 'currency': '$'}, 'extensions': ['$5.88']}, 'bottom': {'extensions': ['Material: Galvanized Steel', 'Trade Size: 0.5 in', 'Color: Satinless Steel', 'Product Weight (lb.): 3'], 'detected_extensions': {'trade_size_in': 0.5, 'product_weight_lb': None}}}
# -------------------------------------------
# ALLIED 898302 EMT CONDUIT 1/2" EMT CONDUIT X 10
# https://www.gordonelectricsupply.com/p/Allied-898302-Emt-Conduit-1-2-Emt-Conduit-X-10/1608
# {'top': {'detected_extensions': {'price': 4.73, 'currency': '$'}, 'extensions': ['$4.73', '\u200eIn stock']}}
# -------------------------------------------
# EMT Electrical Metallic Tubing 1/2 in Conduit 10 ft
# https://www.steinerelectric.com/Product/EMT-Electrical-Metallic-Tubing-1-2-in-Conduit-10-ft-39288
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15368\278452441.py in <module>
#      23     print(p['title'])
#      24     print(p['link'])
# ---> 25     print(p['rich_snippet'])
#      26     print('-------------------------------------------')
#
# KeyError: 'rich_snippet'

# %%
querrys = ['1/2 in. x 10 ft. Electric Metallic Tube (EMT) Conduit', '3/4 in. x 10 ft. Electric Metallic Tube (EMT) Conduit',
          '1 in. x 10 ft. Electric Metallic Tube (EMT) Conduit', '1/2 in. emt set-screw connectors (5-pack)', 
          '3/4 in. emt set-screw connectors (5-pack)', '1 in. emt set-screw connectors',
          '1/2 in. emt set-screw coupling (5-pack)', '3/4 in. emt set-screw coupling (5-pack)',
          '1 in. emt set-screw coupling', '500 ft. #4 black stranded cu simpull thhn wire',
          '500 ft. #6 black stranded cu simpull thhn wire', '500 ft. #10 black stranded cu simpull thhn wire',
          '250 ft. 14/2 romex', '250 ft. 14/3 romex', '250 ft. 12/2 romex', '250 ft. 12/3 romex',]
          
for q in querrys:
    querry(q)
# Out:
# https://serpapi.com/search
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15368\2826938604.py in <module>
#       8
#       9 for q in querrys:
# ---> 10     querry(q)
#
# ~\AppData\Local\Temp\ipykernel_15368\278452441.py in querry(querrys)
#      15     products = results["organic_results"]
#      16
# ---> 17     items.append(products['title'])
#      18     links.append(products['links'])
#      19     richSnip.append(products['rich_snippet'])
#
# TypeError: list indices must be integers or slices, not str

# %%
for p in products[0:5]:
    print(p['title'])
    print(p['link'])
    print(p['rich_snippet'])
    print('-------------------------------------------')
# Out:
# 3/4 in. x 10 ft. Electric Metallic Tube (EMT) Conduit 853429
# https://www.homedepot.com/p/3-4-in-x-10-ft-Electric-Metallic-Tube-EMT-Conduit-853429/100400406
# {'top': {'detected_extensions': {'rating': 4.6, 'reviews': 552, 'price': 11.91, 'currency': '$'}, 'extensions': ['Rating: 4.6', '\u200e552 reviews', '\u200e$11.91']}}
# -------------------------------------------
# 3/4-in x 10-ft Metal Emt Conduit - Lowe's
# https://www.lowes.com/pd/Common-3-4-in-Actual-75-In-Metallic-Emt-10-ft-Conduit/3129553
# {'top': {'detected_extensions': {'rating': 4.8, 'reviews': 170, 'price': 12.68, 'currency': '$'}, 'extensions': ['Rating: 4.8', '\u200e170 reviews', '\u200e$12.68', '\u200eOut of stock']}, 'bottom': {'detected_extensions': {'conduit_wall_thickness_schedule_size': 80, 'diameter_in': 3}, 'extensions': ['Conduit Wall Thickness: Schedule 80Size', 'Diameter: 3/4-in']}}
# -------------------------------------------
# 3/4 In. X 10 Ft. Electric Metallic Tube (Emt) Conduit
# https://www.ebarnett.com/Sku/2487616/34-in-x-10-ft-electric-metallic-tube-emt-conduit-091111020025-853429
# {'top': {'detected_extensions': {'price': 10.47, 'currency': '$'}, 'extensions': ['$10.47']}, 'bottom': {'extensions': ['Material: Galvanized Steel', 'Product Weight (lb.): 4.6', 'Color: Satinless Steel', 'Trade Size: 0.75 in'], 'detected_extensions': {'product_weight_lb': None, 'trade_size_in': 0.75}}}
# -------------------------------------------
# 3/4" x 10 Ft EMT Conduit Color Silver, Galvanized Steel ...
# https://www.mecampbell.com/3-4-x-10-ft-emt-conduit-color-silver-galvanized-steel-electrical-metallic-tubing.html
# {'top': {'detected_extensions': {'price': 132, 'currency': '$ (typically $)', 'free': 2}, 'extensions': ['$132 (typically $157)', '\u200eFree 2', 'day delivery', '\u200eIn stock']}, 'bottom': {'detected_extensions': {'length': 10, 'wall_thickness': 0.049}, 'extensions': ["Length: 10'", 'Wall Thickness: 0.049"', 'End Style: Color Coded']}}
# -------------------------------------------
# 34E :: EMT Conduit, 3/4", Steel, 10 - Platt Electric Supply
# https://www.platt.com/p/0065970/emt-conduit-3-4-steel-10/091111020025/34e
# {'top': {'detected_extensions': {'price': 1.37, 'currency': '$'}, 'extensions': ['$1.37', '\u200eIn stock']}}
# -------------------------------------------

# %%
organic_results
# Out:
# [{'position': 1,
#   'title': '1/2 in. x 10 ft. Electric Metallic Tube (EMT) Conduit 853428',
#   'link': 'https://www.homedepot.com/p/1-2-in-x-10-ft-Electric-Metallic-Tube-EMT-Conduit-853428/100400405',
#   'displayed_link': 'https://www.homedepot.com › ... › Conduit',
#   'thumbnail': 'https://serpapi.com/searches/6349f55d37b24a276db0efbc/images/236f05ca2626abbbd34b0acc9f01e1e83fde25ee3bb35984281101c3d0679e28.jpeg',
#   'snippet': 'Electric Metallic Tube Conduit protects your cables from magnetic fields, impact damage and crushing. The heavy-duty steel conduit resists splitting, kinking ...',
#   'snippet_highlighted_words': ['Electric Metallic Tube Conduit', 'conduit'],
#   'rich_snippet': {'top': {'detected_extensions': {'rating': 4.6,
#      'reviews': 619,
#      'price': 7.22,
#      'currency': '$'},
#     'extensions': ['Rating: 4.6', '\u200e619 reviews', '\u200e$7.22']}},
#   'about_this_result': {'source': {'description': 'The Home Depot, Inc., is an American multinational home improvement retail corporation that sells tools, construction products, appliances, and services. Home Depot is the largest home improvement retailer in the United States. In 2021, the company had 490,600 employees and more than $151 billion in revenue.',
#     'source_info_link': 'https://www.homedepot.com/p/1-2-in-x-10-ft-Electric-Metallic-Tube-EMT-Conduit-853428/100400405',
#     'security': 'secure',
#     'icon': 'https://serpapi.com/searches/6349f55d37b24a276db0efbc/images/236f05ca2626abbbd34b0acc9f01e1e8bf536c78df6e9ceb9e9d200dbe088026d3d484c1d34bf8d434cb140d4d40ff83.png'}},
#   'about_page_link': 'https://www.google.com/search?q=About+https://www.homedepot.com/p/1-2-in-x-10-ft-Electric-Metallic-Tube-EMT-Conduit-853428/100400405&tbm=ilp&ilps=ADNMCi2oOcaF9BgaXXxWx1JX6aXF_PKE3g',
#   'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&ilps=ADNMCi2oOcaF9BgaXXxWx1JX6aXF_PKE3g&q=About+https%3A%2F%2Fwww.homedepot.com%2Fp%2F1-2-in-x-10-ft-Electric-Metallic-Tube-EMT-Conduit-853428%2F100400405',
#   'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:dUZ5bTkNRtcJ:https://www.homedepot.com/p/1-2-in-x-10-ft-Electric-Metallic-Tube-EMT-Conduit-853428/100400405&cd=1&hl=en&ct=clnk&gl=us'},
#  {'position': 2,
#   'title': "1/2-in x 10-ft Metal Emt Conduit - Lowe's",
#   'link': 'https://www.lowes.com/pd/Common-1-2-in-Actual-50-In-Metallic-Emt-10-ft-Conduit/3129551',
#   'displayed_link': 'https://www.lowes.com › ... › Conduit',
#   'thumbnail': 'https://serpapi.com/searches/6349f55d37b24a276db0efbc/images/236f05ca2626abbbd34b0acc9f01e1e8b7deeb1eae5da1c799024be40e1ecfeb.jpeg',
#   'snippet': 'High grade, durable and ductile steel for long lfe. Listed to UL Standard 797 Electrical Metal Tubing - Steel and manufactured in accordance with ANSI C80.3 ...',
#   'snippet_highlighted_words': ['Electrical', 'Tubing'],
#   'rich_snippet': {'top': {'detected_extensions': {'rating': 4.5,
#      'reviews': 79,
#      'price': 7.68,
#      'currency': '$'},
#     'extensions': ['Rating: 4.5',
#      '\u200e79 reviews',
#      '\u200e$7.68',
#      '\u200eOut of stock']}},
#   'about_this_result': {'source': {'description': "Lowe's Companies, Inc., often shortened to Lowe's, is an American retail company specializing in home improvement. Headquartered in Mooresville, North Carolina, the company operates a chain of retail stores in the United States and Canada.",
#     'source_info_link': 'https://www.lowes.com/pd/Common-1-2-in-Actual-50-In-Metallic-Emt-10-ft-Conduit/3129551',
#     'security': 'secure',
#     'icon': 'https://serpapi.com/searches/6349f55d37b24a276db0efbc/images/236f05ca2626abbbd34b0acc9f01e1e8dce7167a5eff56b0494ee2c2488eda38207ed37ecdef43e776bd5479c0041aa1.png'}},
#   'about_page_link': 'https://www.google.com/search?q=About+https://www.lowes.com/pd/Common-1-2-in-Actual-50-In-Metallic-Emt-10-ft-Conduit/3129551&tbm=ilp&ilps=ADNMCi1AyRsLRrt7ORXdaEfHcmlcELfIhg',
#   'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&ilps=ADNMCi1AyRsLRrt7ORXdaEfHcmlcELfIhg&q=About+https%3A%2F%2Fwww.lowes.com%2Fpd%2FCommon-1-2-in-Actual-50-In-Metallic-Emt-10-ft-Conduit%2F3129551',
#   'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:v_EHYbUGHBIJ:https://www.lowes.com/pd/Common-1-2-in-Actual-50-In-Metallic-Emt-10-ft-Conduit/3129551&cd=2&hl=en&ct=clnk&gl=us'},
#  {'position': 3,
#   'title': '1/2 In. X 10 Ft. Electric Metallic Tube (Emt) Conduit',
#   'link': 'https://www.supplyworks.com/Sku/2487615/12-in-x-10-ft-electric-metallic-tube-emt-conduit-091111020018-853428',
#   'displayed_link': 'https://www.supplyworks.com › Sku › 12-in-x-10-ft-el...',
#   'thumbnail': 'https://serpapi.com/searches/6349f55d37b24a276db0efbc/images/236f05ca2626abbbd34b0acc9f01e1e88aad23575a3b909608944bd92ebbbc97.jpeg',
#   'snippet': 'This 1/2 in. x 10 ft. Electric Metallic Tube Conduit protects your cables from magnetic fields, impact damage and crushing. The heavy-duty steel conduit ...',
#   'snippet_highlighted_words': ['1/2 in. x 10 ft',
#    'Electric Metallic Tube Conduit',
#    'conduit'],
#   'rich_snippet': {'top': {'detected_extensions': {'price': 5.88,
#      'currency': '$'},
#     'extensions': ['$5.88']},
#    'bottom': {'extensions': ['Material: Galvanized Steel',
#      'Trade Size: 0.5 in',
#      'Color: Satinless Steel',
#      'Product Weight (lb.): 3'],
#     'detected_extensions': {'trade_size_in': 0.5, 'product_weight_lb': None}}},
#   'about_this_result': {'source': {'description': 'supplyworks.com was first indexed by Google more than 10 years ago',
#     'source_info_link': 'https://www.supplyworks.com/Sku/2487615/12-in-x-10-ft-electric-metallic-tube-emt-conduit-091111020018-853428',
#     'security': 'secure',
#     'icon': 'https://serpapi.com/searches/6349f55d37b24a276db0efbc/images/236f05ca2626abbbd34b0acc9f01e1e885b97debe22e8926e8128e6506141abe37a1d29457cf72287edf7629d91c9281.png'}},
#   'about_page_link': 'https://www.google.com/search?q=About+https://www.supplyworks.com/Sku/2487615/12-in-x-10-ft-electric-metallic-tube-emt-conduit-091111020018-853428&tbm=ilp&ilps=ADNMCi2TlooLVjiUdQwZnVb0wiVWCYH6hA',
#   'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&ilps=ADNMCi2TlooLVjiUdQwZnVb0wiVWCYH6hA&q=About+https%3A%2F%2Fwww.supplyworks.com%2FSku%2F2487615%2F12-in-x-10-ft-electric-metallic-tube-emt-conduit-091111020018-853428',
#   'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:6BHNFtLALnkJ:https://www.supplyworks.com/Sku/2487615/12-in-x-10-ft-electric-metallic-tube-emt-conduit-091111020018-853428&cd=3&hl=en&ct=clnk&gl=us'},
#  {'position': 4,
#   'title': 'ALLIED 898302 EMT CONDUIT 1/2" EMT CONDUIT X 10',
#   'link': 'https://www.gordonelectricsupply.com/p/Allied-898302-Emt-Conduit-1-2-Emt-Conduit-X-10/1608',
#   'displayed_link': 'https://www.gordonelectricsupply.com › Allied-898302...',
#   'thumbnail': 'https://serpapi.com/searches/6349f55d37b24a276db0efbc/images/236f05ca2626abbbd34b0acc9f01e1e8133901a9c630f0223eb2529b4abb5e1e.jpeg',
#   'snippet': 'ALLIED 1/2"x10\' EMT ELECTRICAL METALLIC TUBING. Technical Description: Steel Material; Hot Galvanized Finish; 10 Foot; 0.706 Inch Outer Diameter; UL 797, ...',
#   'snippet_highlighted_words': ['1/2',
#    'x10',
#    'EMT ELECTRICAL METALLIC TUBING',
#    '10'],
#   'rich_snippet': {'top': {'detected_extensions': {'price': 4.73,
#      'currency': '$'},
#     'extensions': ['$4.73', '\u200eIn stock']}},
#   'about_this_result': {'source': {'description': 'gordonelectricsupply.com was first indexed by Google more than 10 years ago',
#     'source_info_link': 'https://www.gordonelectricsupply.com/p/Allied-898302-Emt-Conduit-1-2-Emt-Conduit-X-10/1608',
#     'security': 'secure',
#     'icon': 'https://serpapi.com/searches/6349f55d37b24a276db0efbc/images/236f05ca2626abbbd34b0acc9f01e1e863a7feacad6ecfd9f6e5ac072b185e80331372c9bd407ebe4929bc3d7bda584a.png'}},
#   'about_page_link': 'https://www.google.com/search?q=About+https://www.gordonelectricsupply.com/p/Allied-898302-Emt-Conduit-1-2-Emt-Conduit-X-10/1608&tbm=ilp&ilps=ADNMCi2ytwk-QRtCQyapEnP5q43No6WhHw',
#   'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&ilps=ADNMCi2ytwk-QRtCQyapEnP5q43No6WhHw&q=About+https%3A%2F%2Fwww.gordonelectricsupply.com%2Fp%2FAllied-898302-Emt-Conduit-1-2-Emt-Conduit-X-10%2F1608',
#   'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:LjU6c9w7-50J:https://www.gordonelectricsupply.com/p/Allied-898302-Emt-Conduit-1-2-Emt-Conduit-X-10/1608&cd=4&hl=en&ct=clnk&gl=us'},
#  {'position': 5,
#   'title': 'EMT Electrical Metallic Tubing 1/2 in Conduit 10 ft',
#   'link': 'https://www.steinerelectric.com/Product/EMT-Electrical-Metallic-Tubing-1-2-in-Conduit-10-ft-39288',
#   'displayed_link': 'https://www.steinerelectric.com › Product › EMT-Electr...',
#   'snippet': 'EMT Electrical Metallic Tubing 1/2 in Conduit 10 ft. Conduit - EMT / Thinwall. 39288 MFG #: B00023. Commodity - Pipe. 57.89000 / ft.',
#   'snippet_highlighted_words': ['EMT Electrical Metallic Tubing 1/2',
#    'Conduit 10 ft',
#    'Conduit',
#    'EMT',
#    'Pipe'],
#   'rich_snippet': {'top': {'detected_extensions': {'price': 5.21,
#      'currency': '$'},
#     'extensions': ['$57.89 (typically $68.06)',
#      '\u200e$5.21 6',
#      'day delivery',
#      '\u200eIn stock']}},
#   'about_this_result': {'source': {'description': 'steinerelectric.com was first indexed by Google more than 10 years ago',
#     'source_info_link': 'https://www.steinerelectric.com/Product/EMT-Electrical-Metallic-Tubing-1-2-in-Conduit-10-ft-39288',
#     'security': 'secure',
#     'icon': 'https://serpapi.com/searches/6349f55d37b24a276db0efbc/images/236f05ca2626abbbd34b0acc9f01e1e80656b4e05e23ad3861d786a888ff1f0394e834d52234363b2ca016ae31606559.png'}},
#   'about_page_link': 'https://www.google.com/search?q=About+https://www.steinerelectric.com/Product/EMT-Electrical-Metallic-Tubing-1-2-in-Conduit-10-ft-39288&tbm=ilp&ilps=ADNMCi2Ca6m2Q6zsfyelHuNzQrj0_ED0Qg',
#   'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&ilps=ADNMCi2Ca6m2Q6zsfyelHuNzQrj0_ED0Qg&q=About+https%3A%2F%2Fwww.steinerelectric.com%2FProduct%2FEMT-Electrical-Metallic-Tubing-1-2-in-Conduit-10-ft-39288',
#   'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:I6Yy7_E_MbYJ:https://www.steinerelectric.com/Product/EMT-Electrical-Metallic-Tubing-1-2-in-Conduit-10-ft-39288&cd=8&hl=en&ct=clnk&gl=us'},
#  {'position': 6,
#   'title': '1/2 " x 10 Ft EMT Conduit Color Silver, Galvanized Steel ...',
#   'link': 'https://www.mecampbell.com/1-2-x-10-ft-emt-conduit-color-silver-galvanized-steel-electrical-metallic-tubing.html',
#   'displayed_link': 'https://www.mecampbell.com › ... › EMT Conduit',
#   'snippet': '1/2 " x 10 Ft EMT Conduit Color Silver, Galvanized Steel Electrical Metallic Tubing. 10\' 0.622" 0.706" 0.42" Color Coded Steel Galvanized 7000\' per Lift ...',
#   'snippet_highlighted_words': ['1/2',
#    'x 10 Ft EMT Conduit',
#    'Electrical Metallic Tubing'],
#   'rich_snippet': {'bottom': {'extensions': ['End Style: Color Coded',
#      'Wall Thickness: 0.42"'],
#     'detected_extensions': {'wall_thickness': 0.42}}},
#   'about_this_result': {'source': {'description': 'mecampbell.com was first indexed by Google more than 10 years ago',
#     'source_info_link': 'https://www.mecampbell.com/1-2-x-10-ft-emt-conduit-color-silver-galvanized-steel-electrical-metallic-tubing.html',
#     'security': 'secure',
#     'icon': 'https://serpapi.com/searches/6349f55d37b24a276db0efbc/images/236f05ca2626abbbd34b0acc9f01e1e8027a3b263b2b69b8555f8d8c45a806dc92764f820f2d966658a1e4974b53bda3.png'}},
#   'about_page_link': 'https://www.google.com/search?q=About+https://www.mecampbell.com/1-2-x-10-ft-emt-conduit-color-silver-galvanized-steel-electrical-metallic-tubing.html&tbm=ilp&ilps=ADNMCi3Q3mcafC5xHJzwAth5au16dfB0Jg',
#   'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&ilps=ADNMCi3Q3mcafC5xHJzwAth5au16dfB0Jg&q=About+https%3A%2F%2Fwww.mecampbell.com%2F1-2-x-10-ft-emt-conduit-color-silver-galvanized-steel-electrical-metallic-tubing.html',
#   'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:mGjIEXLyRQEJ:https://www.mecampbell.com/1-2-x-10-ft-emt-conduit-color-silver-galvanized-steel-electrical-metallic-tubing.html&cd=42&hl=en&ct=clnk&gl=us'},
#  {'position': 7,
#   'title': '1/2 Conduit - Amazon.com',
#   'link': 'https://www.amazon.com/1-2-conduit/s?k=1%2F2+conduit',
#   'displayed_link': 'https://www.amazon.com › 1-2-conduit › 2+conduit',
#   'snippet': 'Alex Tech 25ft – 1/2 inch Split Wire Loom Tubing Wire Conduit – Black ... Liquid-Tight Conduit and Connector Kit,Flexible Non Metallic Liquid Tight Electrical ...',
#   'snippet_highlighted_words': ['1/2',
#    'Tubing',
#    'Conduit',
#    'Conduit',
#    'Metallic',
#    'Electrical'],
#   'about_this_result': {'source': {'description': 'Amazon.com, Inc. is an American multinational technology company that focuses on e-commerce, cloud computing, online advertising, digital streaming, and artificial intelligence.',
#     'source_info_link': 'https://www.amazon.com/1-2-conduit/s?k=1%2F2+conduit',
#     'security': 'secure',
#     'icon': 'https://serpapi.com/searches/6349f55d37b24a276db0efbc/images/236f05ca2626abbbd34b0acc9f01e1e8e12a530361621943e4151962f499c97315af719a9d93c1a7b9baa72434c39895.png'}},
#   'about_page_link': 'https://www.google.com/search?q=About+https://www.amazon.com/1-2-conduit/s?k%3D1%252F2%2Bconduit&tbm=ilp&ilps=ADNMCi3R8eOKNZAKEgE4yozmPjFfPFeQVQ',
#   'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&ilps=ADNMCi3R8eOKNZAKEgE4yozmPjFfPFeQVQ&q=About+https%3A%2F%2Fwww.amazon.com%2F1-2-conduit%2Fs%3Fk%3D1%252F2%2Bconduit',
#   'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:cg1-wfjGRzQJ:https://www.amazon.com/1-2-conduit/s%3Fk%3D1%252F2%2Bconduit&cd=43&hl=en&ct=clnk&gl=us'},
#  {'position': 8,
#   'title': '1-1/2 In. X 10 Ft. Electric Metallic Tube (Emt) Conduit',
#   'link': 'https://www.ebarnett.com/Sku/2487611/1-12-in-x-10-ft-electric-metallic-tube-emt-conduit-091111020056-101584',
#   'displayed_link': 'https://www.ebarnett.com › Sku › 1-12-in-x-10-ft-elect...',
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQvdWnQR-j0CAj6S4keRj-ocjNnePsHbZyDrlmlSIDh9nSu8IOwpqti&usqp=CAE&s',
#   'snippet': '1-1/2 in. x 10 ft. Electric Metallic Tube Conduit offers protection from magnetic fields, impact damage and crushing when pulling electrical cable. This steel ...',
#   'snippet_highlighted_words': ['1/2 in. x 10 ft',
#    'Electric Metallic Tube Conduit'],
#   'rich_snippet': {'bottom': {'extensions': ['Material: Galvanized Steel',
#      'Trade Size: 1.5 in',
#      'Color: Satinless Steel',
#      'Product Weight (lb.): 11.6'],
#     'detected_extensions': {'trade_size_in': 1.5, 'product_weight_lb': None}}},
#   'about_this_result': {'source': {'description': 'ebarnett.com was first indexed by Google more than 10 years ago',
#     'source_info_link': 'https://www.ebarnett.com/Sku/2487611/1-12-in-x-10-ft-electric-metallic-tube-emt-conduit-091111020056-101584',
#     'security': 'secure',
#     'icon': 'https://serpapi.com/searches/6349f55d37b24a276db0efbc/images/236f05ca2626abbbd34b0acc9f01e1e8b43644243c23fbbd1f667f624488d17999252916277233f6ac6cc7631a8aad3e.png'}},
#   'about_page_link': 'https://www.google.com/search?q=About+https://www.ebarnett.com/Sku/2487611/1-12-in-x-10-ft-electric-metallic-tube-emt-conduit-091111020056-101584&tbm=ilp&ilps=ADNMCi13SAJscDTZnO_wc5wlZAQ4cApT0Q',
#   'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&ilps=ADNMCi13SAJscDTZnO_wc5wlZAQ4cApT0Q&q=About+https%3A%2F%2Fwww.ebarnett.com%2FSku%2F2487611%2F1-12-in-x-10-ft-electric-metallic-tube-emt-conduit-091111020056-101584',
#   'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:TXWWiRwFgtIJ:https://www.ebarnett.com/Sku/2487611/1-12-in-x-10-ft-electric-metallic-tube-emt-conduit-091111020056-101584&cd=44&hl=en&ct=clnk&gl=us'},
#  {'position': 9,
#   'title': 'Wheatland Tube Company 1/2" x 20\' EMT Conduit - Menards',
#   'link': 'https://www.menards.com/main/electrical/conduit-conduit-fittings-raceways/conduit/wheatland-tube-company-emt-conduit/3651321/p-1444446524964-c-6423.htm',
#   'displayed_link': 'https://www.menards.com › main › electrical › wheatla...',
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRKY1vu9KNpAM0eOUZo1Sn18YrWvdF3oOCL46UFBENQ8ZeQdNWYE3yg&usqp=CAE&s',
#   'snippet': 'Wheatland Tube Company 1/2" x 20\' EMT Conduit. ... Everyday Low Price, $15.20. 11% Mail-In Rebate Good Through 10/16/22, $1.67 ...',
#   'snippet_highlighted_words': ['Tube', '1/2', 'x', 'EMT Conduit', '10'],
#   'about_this_result': {'source': {'description': 'Menards is an American home improvement retail company headquartered in Eau Claire, Wisconsin. Menards is owned by founder John Menard Jr. through his privately held company, Menard, Inc.',
#     'source_info_link': 'https://www.menards.com/main/electrical/conduit-conduit-fittings-raceways/conduit/wheatland-tube-company-emt-conduit/3651321/p-1444446524964-c-6423.htm',
#     'security': 'secure',
#     'icon': 'https://serpapi.com/searches/6349f55d37b24a276db0efbc/images/236f05ca2626abbbd34b0acc9f01e1e851a100400b91ada48c39a6d71e0e7b50799859daab3ab110ab542c87cf795321.png'}},
#   'about_page_link': 'https://www.google.com/search?q=About+https://www.menards.com/main/electrical/conduit-conduit-fittings-raceways/conduit/wheatland-tube-company-emt-conduit/3651321/p-1444446524964-c-6423.htm&tbm=ilp&ilps=ADNMCi3a3_1VuogZ6g-1204jVjlM9EiyLg',
#   'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&ilps=ADNMCi3a3_1VuogZ6g-1204jVjlM9EiyLg&q=About+https%3A%2F%2Fwww.menards.com%2Fmain%2Felectrical%2Fconduit-conduit-fittings-raceways%2Fconduit%2Fwheatland-tube-company-emt-conduit%2F3651321%2Fp-1444446524964-c-6423.htm',
#   'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:LD7DPM8KGRMJ:https://www.menards.com/main/electrical/conduit-conduit-fittings-raceways/conduit/wheatland-tube-company-emt-conduit/3651321/p-1444446524964-c-6423.htm&cd=45&hl=en&ct=clnk&gl=us'},
#  {'position': 10,
#   'title': '12E :: EMT Conduit, 1/2", Steel, 10 - Platt Electric Supply',
#   'link': 'https://www.platt.com/p/0065867/emt-conduit-1-2-steel-10/091111020018/12e',
#   'displayed_link': 'https://www.platt.com › ... › Steel EMT',
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQIfk7J6JoSdtaggfAAQsGfs02LIAzgaChRCqOP84IHalzGNU9HtFTs&usqp=CAE&s',
#   'snippet': '1/2 Inch EMT Conduit, Steel, 10 foot Length, Cat #: 12E, Mfr: Multiple. ... emt, tunnel conduit, 1/2 stick. , Metal pipe, Electrical Metalic Tubing, ...',
#   'snippet_highlighted_words': ['1/2',
#    'EMT Conduit',
#    '10',
#    'emt',
#    'conduit',
#    '1/2',
#    'pipe',
#    'Electrical',
#    'Tubing'],
#   'rich_snippet': {'top': {'detected_extensions': {'price': 0.76,
#      'currency': '$'},
#     'extensions': ['$0.76', '\u200eIn stock']}},
#   'about_this_result': {'source': {'description': 'platt.com was first indexed by Google more than 10 years ago',
#     'source_info_link': 'https://www.platt.com/p/0065867/emt-conduit-1-2-steel-10/091111020018/12e',
#     'security': 'secure',
#     'icon': 'https://serpapi.com/searches/6349f55d37b24a276db0efbc/images/236f05ca2626abbbd34b0acc9f01e1e8676098650c780d72be9033d8b7a79df9ef8d6a7b4599903eae9a4d3b6d6e0235.png'}},
#   'about_page_link': 'https://www.google.com/search?q=About+https://www.platt.com/p/0065867/emt-conduit-1-2-steel-10/091111020018/12e&tbm=ilp&ilps=ADNMCi19-2AZyrJx3VgHs4a_axZ8mMEfSA',
#   'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&ilps=ADNMCi19-2AZyrJx3VgHs4a_axZ8mMEfSA&q=About+https%3A%2F%2Fwww.platt.com%2Fp%2F0065867%2Femt-conduit-1-2-steel-10%2F091111020018%2F12e',
#   'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:Oa4V30p9PfAJ:https://www.platt.com/p/0065867/emt-conduit-1-2-steel-10/091111020018/12e&cd=57&hl=en&ct=clnk&gl=us'}]

# %%
for p in products[0:5]:
    print(p['title'])
    print(p['link'])
    print(p['rich_snippet'])
    print('-------------------------------------------')
# Out:
# 1/2 in. x 10 ft. Electric Metallic Tube (EMT) Conduit 853428
# https://www.homedepot.com/p/1-2-in-x-10-ft-Electric-Metallic-Tube-EMT-Conduit-853428/100400405
# {'top': {'detected_extensions': {'rating': 4.6, 'reviews': 619, 'price': 7.22, 'currency': '$'}, 'extensions': ['Rating: 4.6', '\u200e619 reviews', '\u200e$7.22']}}
# -------------------------------------------
# 1/2-in x 10-ft Metal Emt Conduit - Lowe's
# https://www.lowes.com/pd/Common-1-2-in-Actual-50-In-Metallic-Emt-10-ft-Conduit/3129551
# {'top': {'detected_extensions': {'rating': 4.5, 'reviews': 79, 'price': 7.68, 'currency': '$'}, 'extensions': ['Rating: 4.5', '\u200e79 reviews', '\u200e$7.68', '\u200eOut of stock']}}
# -------------------------------------------
# 1/2 In. X 10 Ft. Electric Metallic Tube (Emt) Conduit
# https://www.supplyworks.com/Sku/2487615/12-in-x-10-ft-electric-metallic-tube-emt-conduit-091111020018-853428
# {'top': {'detected_extensions': {'price': 5.88, 'currency': '$'}, 'extensions': ['$5.88']}, 'bottom': {'extensions': ['Material: Galvanized Steel', 'Trade Size: 0.5 in', 'Color: Satinless Steel', 'Product Weight (lb.): 3'], 'detected_extensions': {'trade_size_in': 0.5, 'product_weight_lb': None}}}
# -------------------------------------------
# ALLIED 898302 EMT CONDUIT 1/2" EMT CONDUIT X 10
# https://www.gordonelectricsupply.com/p/Allied-898302-Emt-Conduit-1-2-Emt-Conduit-X-10/1608
# {'top': {'detected_extensions': {'price': 4.73, 'currency': '$'}, 'extensions': ['$4.73', '\u200eIn stock']}}
# -------------------------------------------
# EMT Electrical Metallic Tubing 1/2 in Conduit 10 ft
# https://www.steinerelectric.com/Product/EMT-Electrical-Metallic-Tubing-1-2-in-Conduit-10-ft-39288
# {'top': {'detected_extensions': {'price': 5.21, 'currency': '$'}, 'extensions': ['$57.89 (typically $68.06)', '\u200e$5.21 6', 'day delivery', '\u200eIn stock']}}
# -------------------------------------------
