# %%
# Dependencies
from config import homeDepot_API
from serpapi import GoogleSearch
import pandas as pd
import numpy as np
from datetime import datetime
from openpyxl import load_workbook
import os
os.getcwd()
# Out:
# 'C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\Resources'

# %% [markdown]
# STEP 1: EXTRACT

# %%
# Created Working 'Material Description by grabbing names from Home Depot'

common_name = []

ids = ['100400409', '100400406', '100137321', '100400405', 
       '202241090', '100144234', '202077145', '202077147', 
       '202288508', '202304774', '202304649', '202304645', 
       '202019377', '202316275', '202019375', '202316276']

for i in ids:

    params = {
      "engine": "home_depot_product",
      "product_id": i,
      "api_key": homeDepot_API
    }

    search = GoogleSearch(params)
    results = search.get_dict()
    products = results['product_results']
    
    common_name.append(products['title'])
# Out:
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search

# %%
# Order and establish index_name

index_name = []

index_name.append(common_name[3])
index_name.append(common_name[1])
index_name.append(common_name[0])
index_name.append(common_name[5])
index_name.append(common_name[8])
index_name.append(common_name[4])
index_name.append(common_name[2])
index_name.append(common_name[6])
index_name.append(common_name[7])
index_name.append(common_name[12])
index_name.append(common_name[13])
index_name.append(common_name[14])
index_name.append(common_name[15])
index_name.append(common_name[9])
index_name.append(common_name[10])
index_name.append(common_name[11])

#index_name

# %%
def searcher(Q, R):
    params = {
      "engine": "google",
      "q": Q,
      "api_key": homeDepot_API
    }
    search = GoogleSearch(params)
    results = search.get_dict()
    products = results["organic_results"]
   
    for p in products[0:10]:
        try:

            title = p['title']
            link = p['link']
            price = (p['rich_snippet']['top']['detected_extensions']['price'])            
    
            result = {'Manufactures Description': title, 'Link': link, 'Material Price': price, 'VENDOR': link}
            R.append(result)
                        
        except (KeyError):
            price = 'NaN'
            result = {'Manufactures Description': title, 'Link': link, 'Material Price': price, 'VENDOR': link}
            R.append(result)

# %% [markdown]
# STEP 2: TRANSFORM

# %%
# Grab raw data

R = []
for i in range(16):
    R_i = []
   
    searcher(index_name[i], R_i)
    R.append(R_i)
# Out:
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search

# %%
# Create a data frame
all_prices = []
lowest_prices = []
for i in range(len(R)):
    df = pd.DataFrame(R[i]).assign(Common_name=index_name[i])
# Create a 'Vendor location' column    
    df['Vendor Location'] = (np.where(df['VENDOR'].str.contains('.'), df['VENDOR'].str.split('.').str[1], df['VENDOR']))
    df.drop(columns =['VENDOR'], inplace = True)
# Change data type of price to numeric and drop NaN's    
    df['Material Price'] = df['Material Price'].apply(pd.to_numeric, args=('coerce',))
    df.dropna(inplace=True)
# Filter out scaling issues
    if i == 0:
        df.drop(df[df['Material Price'] < .77].index, inplace = True)
    if i == 1 or i == 2:
        df.drop(df[df['Material Price'] > 130].index, inplace = True)
        df.drop(df[df['Material Price'] < 2.60].index, inplace = True)
    if i == 4:
        df.drop(df[df['Material Price'] > 130].index, inplace = True)
    if i == 5 or i == 8:
        df.drop(df[df['Material Price'] > 5.98].index, inplace = True)
    if i == 9:
        df.drop(df[df['Material Price'] < 75].index, inplace = True)
    if i == 11 or i == 12:
        df.drop(df[df['Material Price'] < 130].index, inplace = True)
    if i == 13:
        df.drop(df[df['Material Price'] < 500].index, inplace = True)
    if i == 14 or i == 15:
        df.drop(df[df['Material Price'] < 2.60].index, inplace = True)
    df.drop(columns =['Manufactures Description'], inplace = True)
    df['Material Description'] = df['Common_name']
    df.drop(columns =['Common_name'], inplace = True)
    df = df.iloc[:,[3,1,2,0]]
    
    df["Formatted Datetime"] = datetime.now().strftime("%m/%d/%Y %H:%M:%S")
    
    lowest_prices.append(df.min())
    all_prices.append(df)
clean_df = pd.concat(all_prices, axis=0, ignore_index=True)
working_df = pd.DataFrame(lowest_prices)

# %%
clean_df
# Out:
#                                  Material Description  Material Price  \
# 0   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            7.22
# 1   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            5.99
# 2   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            4.86
# 3   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            5.88
# 4   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            7.24
# 5   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           11.91
# 6   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           10.47
# 7   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...            8.12
# 8   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           98.99
# 9   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           20.62
# 10  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           17.55
# 11  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            3.98
# 12  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            5.99
# 13  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            2.10
# 14  3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 15  3/4 in. Standard Fitting Electric Metallic Tub...            5.99
# 16  3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 17  1 in. Electric Metallic Tube (EMT) Set-Screw C...            1.15
# 18  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            3.98
# 19  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 20  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 21  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            2.10
# 22  3/4 in. Electrical Metallic Tube (EMT) Set-Scr...            4.60
# 23  3/4 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 24  3/4 in. Electrical Metallic Tube (EMT) Set-Scr...           20.00
# 25  1 in. Electrical Metallic Tube (EMT) Set-Screw...            1.60
# 26  1 in. Electrical Metallic Tube (EMT) Set-Screw...            1.99
# 27     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          114.00
# 28     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          118.00
# 29     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          111.07
# 30     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire           84.99
# 31  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          158.00
# 32  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          162.74
# 33  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          172.22
# 34  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          215.00
# 35  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          149.00
# 36  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          149.00
# 37  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          150.00
# 38  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          339.09
# 39    500 ft. 4 Gauge Black Stranded Copper THHN Wire          709.00
# 40    500 ft. 4 Gauge Black Stranded Copper THHN Wire          613.64
# 41    500 ft. 4 Gauge Black Stranded Copper THHN Wire         1047.78
# 42    500 ft. 6 Gauge Black Stranded Copper THHN Wire          470.43
# 43    500 ft. 6 Gauge Black Stranded Copper THHN Wire          445.81
# 44   500 ft. 10 Gauge Black Stranded Copper THHN Wire          145.00
# 45   500 ft. 10 Gauge Black Stranded Copper THHN Wire          155.99
# 46   500 ft. 10 Gauge Black Stranded Copper THHN Wire          165.00
#
#                                       Vendor Location  \
# 0                                           homedepot
# 1                                               lowes
# 2                                gordonelectricsupply
# 3                                         supplyworks
# 4                                             menards
# 5                                           homedepot
# 6                                            ebarnett
# 7                                gordonelectricsupply
# 8                                              amazon
# 9                                           homedepot
# 10                                             wilmar
# 11                                          homedepot
# 12                                             amazon
# 13                                             wilmar
# 14                                          homedepot
# 15                                              lowes
# 16                                          pinterest
# 17                                          homedepot
# 18                                          homedepot
# 19                                             amazon
# 20                                              lowes
# 21                                             wilmar
# 22                                          homedepot
# 23                                              lowes
# 24                                             amazon
# 25                                          homedepot
# 26  com/p/steel-city-emt-conduit-connector-7859911...
# 27                                             amazon
# 28                                              lowes
# 29                                               ebay
# 30                                        landmsupply
# 31                                          homedepot
# 32                                              lowes
# 33                                               ebay
# 34                                            walmart
# 35                                          homedepot
# 36                                              lowes
# 37                                        supplyworks
# 38                                           qcsupply
# 39                                          homedepot
# 40                                             amazon
# 41                                               ebay
# 42                                             amazon
# 43                                               ebay
# 44                                          homedepot
# 45                                             amazon
# 46                                wireandcableyourway
#
#                                                  Link   Formatted Datetime
# 0   https://www.homedepot.com/p/1-2-in-x-10-ft-Ele...  11/02/2022 15:57:29
# 1   https://www.lowes.com/pd/Common-1-2-in-Actual-...  11/02/2022 15:57:29
# 2   https://www.gordonelectricsupply.com/p/Allied-...  11/02/2022 15:57:29
# 3   https://www.supplyworks.com/Sku/2487615/12-in-...  11/02/2022 15:57:29
# 4   https://www.menards.com/main/electrical/condui...  11/02/2022 15:57:29
1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            4.86
# 1   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...            8.12
# 2   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           17.55
# 3   1/2 in. Electric Metallic Tube (EMT) Set-Screw...            2.10
# 4   3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 5   1 in. Electric Metallic Tube (EMT) Set-Screw C...            1.15
# 6   1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            2.10
# 7   3/4 in. Electrical Metallic Tube (EMT) Set-Scr...            4.60
# 8   1 in. Electrical Metallic Tube (EMT) Set-Screw...            1.60
# 9      250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire           84.99
# 10  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          158.00
# 11  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          149.00
# 12  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          339.09
# 13    500 ft. 4 Gauge Black Stranded Copper THHN Wire          613.64
# 14    500 ft. 6 Gauge Black Stranded Copper THHN Wire          445.81
# 15   500 ft. 10 Gauge Black Stranded Copper THHN Wire          145.00
#
#                                       Vendor Location  \
# 0                                gordonelectricsupply
# 1                                              amazon
# 2                                           homedepot
# 3                                              amazon
# 4                                           homedepot
# 5                                           homedepot
# 6                                              amazon
# 7                                              amazon
# 8   com/p/steel-city-emt-conduit-connector-7859911...
# 9                                              amazon
# 10                                               ebay
# 11                                          homedepot
# 12                                           qcsupply
# 13                                             amazon
# 14                                             amazon
# 15                                             amazon
#
#                                                  Link   Formatted Datetime
# 0   https://www.gordonelectricsupply.com/p/Allied-...  11/02/2022 15:57:29
# 1   https://www.amazon.com/EMT-Conduit-10-ft-Steel...  11/02/2022 15:57:29
# 2   https://www.homedepot.com/p/1-in-x-10-ft-Elect...  11/02/2022 15:57:30
# 3   https://www.amazon.com/Halex-26270-STEEL-CONNE...  11/02/2022 15:57:30
# 4   https://www.homedepot.com/p/Halex-3-4-in-Stand...  11/02/2022 15:57:30
# 5   https://www.homedepot.com/p/Halex-1-in-Electri...  11/02/2022 15:57:30
# 6   https://www.amazon.com/Halex-26270-STEEL-CONNE...  11/02/2022 15:57:30
# 7   https://www.amazon.com/Halex-Electrical-Set-Sc...  11/02/2022 15:57:30
# 8   https://killingworthtruevalue.com/p/steel-city...  11/02/2022 15:57:30
# 9   https://www.amazon.com/SOUTHWIRE-COMPANY-28827...  11/02/2022 15:57:30
# 10              https://www.ebay.com/itm/203704802084  11/02/2022 15:57:30
# 11  https://www.homedepot.com/p/Southwire-250-ft-1...  11/02/2022 15:57:30
# 12  https://www.qcsupply.com/12-3-romex-simpull-wi...  11/02/2022 15:57:30
# 13  https://www.amazon.com/SOUTHWIRE-COMPANY-LL-20...  11/02/2022 15:57:30
# 14  https://www.amazon.com/Cerrowire-112-4201J-500...  11/02/2022 15:57:30
# 15  https://www.amazon.com/Gauge-Stranded-Copper-B...  11/02/2022 15:57:30

# %% [markdown]
# STEP 3: LOAD

# %%
# Send a CSV and Excell copies to my computer

xlFile = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\Consolidated_Estimator_Worksheet.xlsx"

book = load_workbook(xlFile)
writer = pd.ExcelWriter(xlFile, engine = 'openpyxl')
writer.book = book

#with pd.ExcelWriter(xlFile) as writer:
working_df.to_excel(writer, sheet_name='Working_Table11')
clean_df.to_excel(writer, sheet_name='Cleaned_Data11')
writer.save()
writer.close()
    
clean_csv = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\OldDataFrames\\clean_df13.csv"
clean_df.to_csv(clean_csv, index=False)

working_csv = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\OldDataFrames\\working_df13.csv"
working_df.to_csv(working_csv, index=False)
