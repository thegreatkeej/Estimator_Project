# %%
# Dependencies
from config import homeDepot_API
from serpapi import GoogleSearch
import pandas as pd
import numpy as np
from datetime import datetime
from openpyxl import load_workbook
import os
os.getcwd()
# Out:
# 'C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\Resources'

# %% [markdown]
# STEP 1: EXTRACT

# %%
# Created Working 'Material Description by grabbing names from Home Depot'

common_name = []

ids = ['100400409', '100400406', '100137321', '100400405', 
       '202241090', '100144234', '202077145', '202077147', 
       '202288508', '202304774', '202304649', '202304645', 
       '202019377', '202316275', '202019375', '202316276']

for i in ids:

    params = {
      "engine": "home_depot_product",
      "product_id": i,
      "api_key": homeDepot_API
    }

    search = GoogleSearch(params)
    results = search.get_dict()
    products = results['product_results']
    
    common_name.append(products['title'])
# Out:
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search

# %%
# Order and establish index_name

index_name = []

index_name.append(common_name[3])
index_name.append(common_name[1])
index_name.append(common_name[0])
index_name.append(common_name[5])
index_name.append(common_name[8])
index_name.append(common_name[4])
index_name.append(common_name[2])
index_name.append(common_name[6])
index_name.append(common_name[7])
index_name.append(common_name[12])
index_name.append(common_name[13])
index_name.append(common_name[14])
index_name.append(common_name[15])
index_name.append(common_name[9])
index_name.append(common_name[10])
index_name.append(common_name[11])

#index_name

# %%
def searcher(Q, R):
    params = {
      "engine": "google",
      "q": Q,
      "api_key": homeDepot_API
    }
    search = GoogleSearch(params)
    results = search.get_dict()
    products = results["organic_results"]
   
    for p in products[0:10]:
        try:

            title = p['title']
            link = p['link']
            price = (p['rich_snippet']['top']['detected_extensions']['price'])            
    
            result = {'Manufactures Description': title, 'Link': link, 'Material Price': price, 'VENDOR': link}
            R.append(result)
                        
        except (KeyError):
            price = 'NaN'
            result = {'Manufactures Description': title, 'Link': link, 'Material Price': price, 'VENDOR': link}
            R.append(result)

# %%
params = {
      "q": 'where is menards headquarters',
      "location": "United States",
      "hl": "en",
      "gl": "us",
      "api_key": homeDepot_API
    }
search = GoogleSearch(params)
results = search.get_dict()
shopping_results = results["organic_results"]
    
print(shopping_results[1]['snippet_highlighted_words'])
# Out:
# https://serpapi.com/search
# ['4777 Menard Drive Eau Claire, Wisconsin 54703 USA']

# %%
params = {
      "q": 'where is homedepot headquarters',
      "location": "United States",
      "hl": "en",
      "gl": "us",
      "api_key": homeDepot_API
    }
search = GoogleSearch(params)
results = search.get_dict()
shopping_results = results["organic_results"]
    
print(shopping_results[1]['snippet_highlighted_words'])
# Out:
# https://serpapi.com/search
# ['2455 Paces Ferry Rd SE, Atlanta, GA 30339']

# %%
params = {
      "q": 'where is gordonelectricsupply headquarters',
      "location": "United States",
      "hl": "en",
      "gl": "us",
      "api_key": homeDepot_API
    }
search = GoogleSearch(params)
results = search.get_dict()
shopping_results = results["organic_results"]
    
print(shopping_results[1]['snippet_highlighted_words'])
# Out:
# https://serpapi.com/search
# ['Kankakee, 1290 N Hobbie Ave. HQ']

# %%
locations = all_vendor_table["vendor_locations"].values.tolist()

headquarters = []

for location in locations

params = {
      "q": f"where is {location} headquarters",
      "location": "United States",
      "hl": "en",
      "gl": "us",
      "api_key": homeDepot_API
    }
search = GoogleSearch(params)
results = search.get_dict()
location_results = results["organic_results"]
    
print(location_results[1]['snippet_highlighted_words'])

# %% [markdown]
# STEP 2: TRANSFORM

# %%
# Grab raw data

R = []
for i in range(16):
    R_i = []
   
    searcher(index_name[i], R_i)
    R.append(R_i)
# Out:
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search

# %%
# Create a data frame
all_prices = []
lowest_prices = []
for i in range(len(R)):
    df = pd.DataFrame(R[i]).assign(Common_name=index_name[i])
# Create a 'Vendor location' column    
    df['Vendor Location'] = (np.where(df['VENDOR'].str.contains('.'), df['VENDOR'].str.split('.').str[1], df['VENDOR']))
    df.drop(columns =['VENDOR'], inplace = True)
# Change data type of price to numeric and drop NaN's    
    df['Material Price'] = df['Material Price'].apply(pd.to_numeric, args=('coerce',))
    df.dropna(inplace=True)
# Filter out scaling issues
    if i == 0:
        df.drop(df[df['Material Price'] < .77].index, inplace = True)
    if i == 1 or i == 2:
        df.drop(df[df['Material Price'] > 130].index, inplace = True)
        df.drop(df[df['Material Price'] < 2.60].index, inplace = True)
    if i == 4:
        df.drop(df[df['Material Price'] > 130].index, inplace = True)
    if i == 5 or i == 8:
        df.drop(df[df['Material Price'] > 5.98].index, inplace = True)
    if i == 9:
        df.drop(df[df['Material Price'] < 75].index, inplace = True)
    if i == 11 or i == 12:
        df.drop(df[df['Material Price'] < 130].index, inplace = True)
    if i == 13:
        df.drop(df[df['Material Price'] < 500].index, inplace = True)
    if i == 14 or i == 15:
        df.drop(df[df['Material Price'] < 2.60].index, inplace = True)
    df.drop(columns =['Manufactures Description'], inplace = True)
    df['Material Description'] = df['Common_name']
    df.drop(columns =['Common_name'], inplace = True)
    df = df.iloc[:,[3,1,2,0]]
    
    df["Formatted Datetime"] = datetime.now().strftime("%m/%d/%Y %H:%M:%S")
    
    lowest_prices.append(df.min())
    all_prices.append(df)
clean_df = pd.concat(all_prices, axis=0, ignore_index=True)
working_df = pd.DataFrame(lowest_prices)

# %%
clean_df
# Out:
#                                  Material Description  Material Price  \
# 0   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            7.22
# 1   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            5.99
# 2   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            4.59
# 3   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...          150.00
# 4   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            7.24
# 5   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...          100.00
# 6   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           11.91
# 7   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           12.68
# 8   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           10.47
# 9   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...            8.12
# 10  3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...           98.99
# 11  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           20.62
# 12  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           17.55
# 13  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           33.34
# 14  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            3.98
# 15  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            8.54
# 16  1/2 in. Electric Metallic Tube (EMT) Set-Screw...            2.10
# 17  3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 18  3/4 in. Standard Fitting Electric Metallic Tub...            3.66
# 19  3/4 in. Standard Fitting Electric Metallic Tub...            5.99
# 20  3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 21  1 in. Electric Metallic Tube (EMT) Set-Screw C...            1.15
# 22  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            3.98
# 23  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            8.41
# 24  1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            5.99
# 25  1 in. Electrical Metallic Tube (EMT) Set-Screw...            1.60
# 26  1 in. Electrical Metallic Tube (EMT) Set-Screw...            1.99
# 27     250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          111.07
# 28  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          159.00
# 29  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          172.22
# 30  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          149.00
# 31  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          149.00
# 32  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          200.02
# 33  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          289.00
# 34  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          339.09
# 35    500 ft. 4 Gauge Black Stranded Copper THHN Wire          613.64
# 36    500 ft. 4 Gauge Black Stranded Copper THHN Wire          877.38
# 37    500 ft. 6 Gauge Black Stranded Copper THHN Wire          379.00
# 38    500 ft. 6 Gauge Black Stranded Copper THHN Wire          470.43
# 39    500 ft. 6 Gauge Black Stranded Copper THHN Wire          445.81
# 40   500 ft. 10 Gauge Black Stranded Copper THHN Wire          145.00
# 41   500 ft. 10 Gauge Black Stranded Copper THHN Wire          155.99
#
#                                       Vendor Location  \
# 0                                           homedepot
# 1                                               lowes
# 2                                gordonelectricsupply
# 3                                         supplyworks
# 4                                             menards
# 5                                          mecampbell
# 6                                           homedepot
# 7                                               lowes
# 8                                            ebarnett
# 9                                gordonelectricsupply
# 10                                             amazon
# 11                                          homedepot
# 12                                             wilmar
# 13                                         dkhardware
# 14                                          homedepot
# 15                                             amazon
# 16                                             wilmar
# 17                                          homedepot
# 18                                        supplyworks
# 19                                              lowes
# 20                                          pinterest
# 21                                          homedepot
# 22                                          homedepot
# 23                                             amazon
# 24                                              lowes
# 25                                          homedepot
# 26  com/p/steel-city-emt-conduit-connector-7859911...
# 27                                               ebay
# 28                                          homedepot
# 29                                               ebay
# 30                                          homedepot
# 31                                              lowes
# 32                                         dkhardware
# 33                                          homedepot
# 34                                           qcsupply
# 35                                             amazon
# 36                                               ebay
# 37                                          homedepot
# 38                                             amazon
# 39                                               ebay
# 40                                          homedepot
# 41                                             amazon
#
#                                                  Link   Formatted Datetime
# 0   https://www.homedepot.com/p/1-2-in-x-10-ft-Ele...  11/01/2022 16:34:26
# 1   https://www.lowes.com/pd/Common-1-2-in-Actual-...  11/01/2022 16:34:26
# 2   https://www.gordonelectricsupply.com/p/Allied-...  11/01/2022 16:34:26
# 3   https://www.supplyworks.com/Sku/2487615/12-in-...  11/01/2022 16:34:26
# 4   https://www.menards.com/main/electrical/condui...  11/01/2022 16:34:26
# 5   https://www.mecampbell.com/1-2-x-10-ft-emt-con...  11/01/2022 16:34:26
# 6   https://www.homedepot.com/p/3-4-in-x-10-ft-Ele...  11/01/2022 16:34:26
# 7   https://www.lowes.com/pd/Common-3-4-in-Actual-...  11/01/2022 16:34:26
# 8   https://www.ebarnett.com/Sku/2487616/34-in-x-1...  11/01/2022 16:34:26
# 9   https://www.gordonelectricsupply.com/p/Allied-...  11/01/2022 16:34:26
# 10  https://www.amazon.com/EMT-Conduit-10-ft-Steel...  11/01/2022 16:34:26
# 11  https://www.homedepot.com/p/1-in-x-10-ft-Elect...  11/01/2022 16:34:26
# 12  https://www.wilmar.com/Sku/24-87610/1-in-x-10-...  11/01/2022 16:34:26
# 13  https://www.dkhardware.com/allied-tube-and-con...  11/01/2022 16:34:26
# 14  https://www.homedepot.com/p/Halex-1-2-in-Elect...  11/01/2022 16:34:26
# 15  https://www.amazon.com/Halex-26270-STEEL-CONNE...  11/01/2022 16:34:26
# 16  https://www.wilmar.com/Sku/202077151/halex-12-...  11/01/2022 16:34:26
# 17  https://www.homedepot.com/p/Halex-3-4-in-Stand...  11/01/2022 16:34:26
# 18  https://www.supplyworks.com/Sku/202328185/hale...  11/01/2022 16:34:26
# 19  https://www.lowes.com/pd/Sigma-Electric-ProCon...  11/01/2022 16:34:26
# 20  https://www.pinterest.com/pin/230668812499210604/  11/01/2022 16:34:26
# 21  https://www.homedepot.com/p/Halex-1-in-Electri...  11/01/2022 16:34:26
# 22  https://www.homedepot.com/p/Halex-1-2-in-Elect...  11/01/2022 16:34:26
# 23  https://www.amazon.com/Halex-26270-STEEL-CONNE...  11/01/2022 16:34:26
# 24  https://www.lowes.com/pd/Sigma-Electric-ProCon...  11/01/2022 16:34:26
# 25  https://www.homedepot.com/p/Halex-1-in-Electri...  11/01/2022 16:34:26
# 26  https://killingworthtruevalue.com/p/steel-city...  11/01/2022 16:34:26
# 27              https://www.ebay.com/itm/363478081520  11/01/2022 16:34:26
# 28  https://www.homedepot.com/p/Southwire-250-ft-1...  11/01/2022 16:34:26
# 29              https://www.ebay.com/itm/203704802084  11/01/2022 16:34:26
# 30  https://www.homedepot.com/p/Southwire-250-ft-1...  11/01/2022 16:34:26
# 31  https://www.lowes.com/pd/Southwire-Romex-SIMpu...  11/01/2022 16:34:26
# 32  https://www.dkhardware.com/southwire-250-ft-12...  11/01/2022 16:34:26
# 33  https://www.homedepot.com/p/Southwire-250-ft-1...  11/01/2022 16:34:26
# 34  https://www.qcsupply.com/12-3-romex-simpull-wi...  11/01/2022 16:34:26
# 35  https://www.amazon.com/SOUTHWIRE-COMPANY-LL-20...  11/01/2022 16:34:26
# 36              https://www.ebay.com/itm/225134643467  11/01/2022 16:34:26
# 37  https://www.homedepot.com/p/Southwire-500-ft-6...  11/01/2022 16:34:26
# 38  https://www.amazon.com/Cerrowire-112-4201J-500...  11/01/2022 16:34:26
# 39              https://www.ebay.com/itm/203860011450  11/01/2022 16:34:26
# 40  https://www.homedepot.com/p/Southwire-500-ft-1...  11/01/2022 16:34:26
# 41  https://www.amazon.com/Gauge-Stranded-Copper-B...  11/01/2022 16:34:26

# %%
working_df
# Out:
#                                  Material Description  Material Price  \
# 0   1/2 in. x 10 ft. Electric Metallic Tube (EMT) ...            4.59
# 1   3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...            8.12
# 2   1 in. x 10 ft. Electric Metallic Tube (EMT) Co...           17.55
# 3   1/2 in. Electric Metallic Tube (EMT) Set-Screw...            2.10
# 4   3/4 in. Standard Fitting Electric Metallic Tub...            2.98
# 5   1 in. Electric Metallic Tube (EMT) Set-Screw C...            1.15
# 6   1/2 in. Electrical Metallic Tube (EMT) Set-Scr...            3.98
# 7                                                 NaN             NaN
# 8   1 in. Electrical Metallic Tube (EMT) Set-Screw...            1.60
# 9      250 ft. 14/2 Romex SIMpull Solid NM-B W/G Wire          111.07
# 10  250 ft. 14/3 Solid Romex SIMpull CU NM-B W/G Wire          159.00
# 11  250 ft. 12/2 Solid Romex SIMpull CU NM-B W/G Wire          149.00
# 12  250 ft. 12/3 Solid Romex SIMpull CU NM-B W/G Wire          289.00
# 13    500 ft. 4 Gauge Black Stranded Copper THHN Wire          613.64
# 14    500 ft. 6 Gauge Black Stranded Copper THHN Wire          379.00
# 15   500 ft. 10 Gauge Black Stranded Copper THHN Wire          145.00
#
#                                       Vendor Location  \
# 0                                gordonelectricsupply
# 1                                              amazon
# 2                                          dkhardware
# 3                                              amazon
# 4                                           homedepot
# 5                                           homedepot
# 6                                              amazon
# 7                                                 NaN
# 8   com/p/steel-city-emt-conduit-connector-7859911...
# 9                                                ebay
# 10                                               ebay
# 11                                         dkhardware
# 12                                          homedepot
# 13                                             amazon
# 14                                             amazon
# 15                                             amazon
#
#                                                  Link   Formatted Datetime
# 0   https://www.gordonelectricsupply.com/p/Allied-...  11/01/2022 16:34:26
# 1   https://www.amazon.com/EMT-Conduit-10-ft-Steel...  11/01/2022 16:34:26
# 2   https://www.dkhardware.com/allied-tube-and-con...  11/01/2022 16:34:26
# 3   https://www.amazon.com/Halex-26270-STEEL-CONNE...  11/01/2022 16:34:26
# 4   https://www.homedepot.com/p/Halex-3-4-in-Stand...  11/01/2022 16:34:26
# 5   https://www.homedepot.com/p/Halex-1-in-Electri...  11/01/2022 16:34:26
# 6   https://www.amazon.com/Halex-26270-STEEL-CONNE...  11/01/2022 16:34:26
# 7                                                 NaN                  NaN
# 8   https://killingworthtruevalue.com/p/steel-city...  11/01/2022 16:34:26
# 9               https://www.ebay.com/itm/363478081520  11/01/2022 16:34:26
# 10              https://www.ebay.com/itm/203704802084  11/01/2022 16:34:26
# 11  https://www.dkhardware.com/southwire-250-ft-12...  11/01/2022 16:34:26
# 12  https://www.homedepot.com/p/Southwire-250-ft-1...  11/01/2022 16:34:26
# 13  https://www.amazon.com/SOUTHWIRE-COMPANY-LL-20...  11/01/2022 16:34:26
# 14  https://www.amazon.com/Cerrowire-112-4201J-500...  11/01/2022 16:34:26
# 15  https://www.amazon.com/Gauge-Stranded-Copper-B...  11/01/2022 16:34:26

# %% [markdown]
# STEP 3: LOAD

# %%
# Send a CSV and Excell copies to my computer

xlFile = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\Consolidated_Estimator_Worksheet.xlsx"

book = load_workbook(xlFile)
writer = pd.ExcelWriter(xlFile, engine = 'openpyxl')
writer.book = book

#with pd.ExcelWriter(xlFile) as writer:
working_df.to_excel(writer, sheet_name='Working_Table11')
clean_df.to_excel(writer, sheet_name='Cleaned_Data11')
writer.save()
writer.close()
    
clean_csv = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\OldDataFrames\\clean_df13.csv"
clean_df.to_csv(clean_csv, index=False)

working_csv = "C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\OldDataFrames\\working_df13.csv"
working_df.to_csv(working_csv, index=False)
