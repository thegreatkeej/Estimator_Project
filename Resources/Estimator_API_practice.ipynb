# %%
from serpapi import GoogleSearch

from config import homeDepot_API
params = {
  "engine": "home_depot",
  "q": "EMT",
  "api_key": homeDepot_API
}

search = GoogleSearch(params)
results = search.get_dict()
products = results["products"]
products
# Out:
# https://serpapi.com/search
# [{'position': 1,
#   'product_id': '100400409',
#   'title': '1 in. x 10 ft. Electric Metallic Tube (EMT) Conduit',
#   'thumbnails': [['https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101568-64_65.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101568-64_100.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101568-64_145.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101568-64_300.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101568-64_400.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101568-64_600.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101568-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/1-in-x-10-ft-Electric-Metallic-Tube-EMT-Conduit-101568/100400409',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100400409&store_id=2414',
#   'model_number': '101568',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 1401,
#   'rating': 4.6354,
#   'reviews': 181,
#   'price': 20.62,
#   'badges': ['top rated'],
#   'delivery': {'schedule_delivery': True},
#   'pickup': {'quantity': 34, 'store_name': 'Bangor', 'distance': 0}},
#  {'position': 2,
#   'product_id': '100400406',
#   'title': '3/4 in. x 10 ft. Electric Metallic Tube (EMT) Conduit',
#   'thumbnails': [['https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-853429-64_65.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-853429-64_100.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-853429-64_145.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-853429-64_300.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-853429-64_400.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-853429-64_600.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-853429-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/3-4-in-x-10-ft-Electric-Metallic-Tube-EMT-Conduit-853429/100400406',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100400406&store_id=2414',
#   'model_number': '853429',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 2360,
#   'rating': 4.6232,
#   'reviews': 552,
#   'price': 11.91,
#   'delivery': {'schedule_delivery': True},
#   'pickup': {'quantity': 229, 'store_name': 'Bangor', 'distance': 0}},
#  {'position': 3,
#   'product_id': '100172548',
#   'title': '1/2 in. Electrical Metallic Tube (EMT) 1-Hole Straps (25-Pack)',
#   'thumbnails': [['https://images.thdstatic.com/productImages/ce4a5178-d938-4acd-8bd4-3945e0b2d231/svn/halex-conduit-fittings-26151-64_65.jpg',
#     'https://images.thdstatic.com/productImages/ce4a5178-d938-4acd-8bd4-3945e0b2d231/svn/halex-conduit-fittings-26151-64_100.jpg',
#     'https://images.thdstatic.com/productImages/ce4a5178-d938-4acd-8bd4-3945e0b2d231/svn/halex-conduit-fittings-26151-64_145.jpg',
#     'https://images.thdstatic.com/productImages/ce4a5178-d938-4acd-8bd4-3945e0b2d231/svn/halex-conduit-fittings-26151-64_300.jpg',
#     'https://images.thdstatic.com/productImages/ce4a5178-d938-4acd-8bd4-3945e0b2d231/svn/halex-conduit-fittings-26151-64_400.jpg',
#     'https://images.thdstatic.com/productImages/ce4a5178-d938-4acd-8bd4-3945e0b2d231/svn/halex-conduit-fittings-26151-64_600.jpg',
#     'https://images.thdstatic.com/productImages/ce4a5178-d938-4acd-8bd4-3945e0b2d231/svn/halex-conduit-fittings-26151-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/Halex-1-2-in-Electrical-Metallic-Tube-EMT-1-Hole-Straps-25-Pack-26151/100172548',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100172548&store_id=2414',
#   'model_number': '26151',
#   'brand': 'Halex',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 2850,
#   'rating': 4.6377,
#   'reviews': 207,
#   'price': 5.57,
#   'delivery': {'free': True, 'free_delivery_threshold': False},
#   'pickup': {'quantity': 5, 'store_name': 'Bangor', 'distance': 0}},
#  {'position': 4,
#   'product_id': '100400412',
#   'title': '1-1/2 in. x 10 ft. Electric Metallic Tube (EMT) Conduit',
#   'thumbnails': [['https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101584-64_65.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101584-64_100.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101584-64_145.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101584-64_300.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101584-64_400.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101584-64_600.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101584-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/1-1-2-in-x-10-ft-Electric-Metallic-Tube-EMT-Conduit-101584/100400412',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100400412&store_id=2414',
#   'model_number': '101584',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 569,
#   'rating': 4.5106,
#   'reviews': 47,
#   'price': 40.0,
#   'delivery': {'schedule_delivery': True},
#   'pickup': {'quantity': 12, 'store_name': 'Bangor', 'distance': 0}},
#  {'position': 5,
#   'product_id': '100120544',
#   'title': '1/2 in. Electrical Metallic Tube (EMT) EMT-to-Box Offset Set-Screw Connector',
#   'thumbnails': [['https://images.thdstatic.com/productImages/d49a89cb-6526-46ca-ba87-1e63ced65591/svn/halex-conduit-fittings-90371-64_65.jpg',
#     'https://images.thdstatic.com/productImages/d49a89cb-6526-46ca-ba87-1e63ced65591/svn/halex-conduit-fittings-90371-64_100.jpg',
#     'https://images.thdstatic.com/productImages/d49a89cb-6526-46ca-ba87-1e63ced65591/svn/halex-conduit-fittings-90371-64_145.jpg',
#     'https://images.thdstatic.com/productImages/d49a89cb-6526-46ca-ba87-1e63ced65591/svn/halex-conduit-fittings-90371-64_300.jpg',
#     'https://images.thdstatic.com/productImages/d49a89cb-6526-46ca-ba87-1e63ced65591/svn/halex-conduit-fittings-90371-64_400.jpg',
#     'https://images.thdstatic.com/productImages/d49a89cb-6526-46ca-ba87-1e63ced65591/svn/halex-conduit-fittings-90371-64_600.jpg',
#     'https://images.thdstatic.com/productImages/d49a89cb-6526-46ca-ba87-1e63ced65591/svn/halex-conduit-fittings-90371-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/Halex-1-2-in-Electrical-Metallic-Tube-EMT-EMT-to-Box-Offset-Set-Screw-Connector-90371/100120544',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100120544&store_id=2414',
#   'model_number': '90371',
#   'brand': 'Halex',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 292,
#   'rating': 4.8667,
#   'reviews': 15,
#   'price': 2.36,
#   'delivery': {'free': True, 'free_delivery_threshold': False},
#   'pickup': {'quantity': 37, 'store_name': 'Bangor', 'distance': 0}},
#  {'position': 6,
#   'product_id': '100137321',
#   'title': '1/2 in. Electrical Metallic Tube (EMT) Set-Screw Connectors (5-Pack)',
#   'thumbnails': [['https://images.thdstatic.com/productImages/08040d2c-c344-4e67-82ac-17611ccbe29a/svn/halex-conduit-fittings-26270-64_65.jpg',
#     'https://images.thdstatic.com/productImages/08040d2c-c344-4e67-82ac-17611ccbe29a/svn/halex-conduit-fittings-26270-64_100.jpg',
#     'https://images.thdstatic.com/productImages/08040d2c-c344-4e67-82ac-17611ccbe29a/svn/halex-conduit-fittings-26270-64_145.jpg',
#     'https://images.thdstatic.com/productImages/08040d2c-c344-4e67-82ac-17611ccbe29a/svn/halex-conduit-fittings-26270-64_300.jpg',
#     'https://images.thdstatic.com/productImages/08040d2c-c344-4e67-82ac-17611ccbe29a/svn/halex-conduit-fittings-26270-64_400.jpg',
#     'https://images.thdstatic.com/productImages/08040d2c-c344-4e67-82ac-17611ccbe29a/svn/halex-conduit-fittings-26270-64_600.jpg',
#     'https://images.thdstatic.com/productImages/08040d2c-c344-4e67-82ac-17611ccbe29a/svn/halex-conduit-fittings-26270-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/Halex-1-2-in-Electrical-Metallic-Tube-EMT-Set-Screw-Connectors-5-Pack-26270/100137321',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100137321&store_id=2414',
#   'model_number': '26270',
#   'brand': 'Halex',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 1871,
#   'rating': 4.5882,
#   'reviews': 34,
#   'price': 3.98,
#   'delivery': {'free': True, 'free_delivery_threshold': False},
#   'pickup': {'quantity': 14, 'store_name': 'Bangor', 'distance': 0}},
#  {'position': 7,
#   'product_id': '100581713',
#   'title': '1/2 in. Electrical Metallic Tube (EMT) Rain Tight Connector (5-Pack)',
#   'thumbnails': [['https://images.thdstatic.com/productImages/99753052-87a1-40bf-bfac-d8565ff7ae23/svn/conduit-fittings-26250-64_65.jpg',
#     'https://images.thdstatic.com/productImages/99753052-87a1-40bf-bfac-d8565ff7ae23/svn/conduit-fittings-26250-64_100.jpg',
#     'https://images.thdstatic.com/productImages/99753052-87a1-40bf-bfac-d8565ff7ae23/svn/conduit-fittings-26250-64_145.jpg',
#     'https://images.thdstatic.com/productImages/99753052-87a1-40bf-bfac-d8565ff7ae23/svn/conduit-fittings-26250-64_300.jpg',
#     'https://images.thdstatic.com/productImages/99753052-87a1-40bf-bfac-d8565ff7ae23/svn/conduit-fittings-26250-64_400.jpg',
#     'https://images.thdstatic.com/productImages/99753052-87a1-40bf-bfac-d8565ff7ae23/svn/conduit-fittings-26250-64_600.jpg',
#     'https://images.thdstatic.com/productImages/99753052-87a1-40bf-bfac-d8565ff7ae23/svn/conduit-fittings-26250-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/1-2-in-Electrical-Metallic-Tube-EMT-Rain-Tight-Connector-5-Pack-26250/100581713',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100581713&store_id=2414',
#   'model_number': '26250',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 446,
#   'rating': 4.4429,
#   'reviews': 70,
#   'price': 5.97,
#   'delivery': {'free': True, 'free_delivery_threshold': False},
#   'pickup': {'quantity': 11, 'store_name': 'Waterville', 'distance': 47}},
#  {'position': 8,
#   'product_id': '100400411',
#   'title': '2 in. x 10 ft. Electric Metallic Tube (EMT) Conduit',
#   'thumbnails': [['https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101592-64_65.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101592-64_100.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101592-64_145.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101592-64_300.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101592-64_400.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101592-64_600.jpg',
#     'https://images.thdstatic.com/productImages/220abc74-08c7-434a-a84a-d870aacca4e5/svn/conduit-101592-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/2-in-x-10-ft-Electric-Metallic-Tube-EMT-Conduit-101592/100400411',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100400411&store_id=2414',
#   'model_number': '101592',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 772,
#   'rating': 4.7674,
#   'reviews': 43,
#   'price': 47.5,
#   'delivery': {'schedule_delivery': True},
#   'pickup': {'quantity': 71, 'store_name': 'Bangor', 'distance': 0}},
#  {'position': 9,
#   'product_id': '100160823',
#   'title': '1/2 in. Standard Fitting Electrical Metallic Tube (EMT) 2-Hole Straps (25-Pack)',
#   'thumbnails': [['https://images.thdstatic.com/productImages/6d69a963-1bad-46b4-9bae-3eb78f723e45/svn/halex-conduit-fittings-26161-64_65.jpg',
#     'https://images.thdstatic.com/productImages/6d69a963-1bad-46b4-9bae-3eb78f723e45/svn/halex-conduit-fittings-26161-64_100.jpg',
#     'https://images.thdstatic.com/productImages/6d69a963-1bad-46b4-9bae-3eb78f723e45/svn/halex-conduit-fittings-26161-64_145.jpg',
#     'https://images.thdstatic.com/productImages/6d69a963-1bad-46b4-9bae-3eb78f723e45/svn/halex-conduit-fittings-26161-64_300.jpg',
#     'https://images.thdstatic.com/productImages/6d69a963-1bad-46b4-9bae-3eb78f723e45/svn/halex-conduit-fittings-26161-64_400.jpg',
#     'https://images.thdstatic.com/productImages/6d69a963-1bad-46b4-9bae-3eb78f723e45/svn/halex-conduit-fittings-26161-64_600.jpg',
#     'https://images.thdstatic.com/productImages/6d69a963-1bad-46b4-9bae-3eb78f723e45/svn/halex-conduit-fittings-26161-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/Halex-1-2-in-Standard-Fitting-Electrical-Metallic-Tube-EMT-2-Hole-Straps-25-Pack-26161/100160823',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100160823&store_id=2414',
#   'model_number': '26161',
#   'brand': 'Halex',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 559,
#   'rating': 4.6559,
#   'reviews': 186,
#   'price': 6.43,
#   'unit': 'bag',
#   'delivery': {'free': True, 'free_delivery_threshold': False},
#   'pickup': {'quantity': 11, 'store_name': 'Bangor', 'distance': 0}},
#  {'position': 10,
#   'product_id': '100210850',
#   'title': '3/4 in. Electrical Metallic Tube (EMT) Inside Corner Pull Elbow',
#   'thumbnails': [['https://images.thdstatic.com/productImages/007365b2-71d2-44f5-a139-d3171b8b7073/svn/halex-conduit-fittings-14607-64_65.jpg',
#     'https://images.thdstatic.com/productImages/007365b2-71d2-44f5-a139-d3171b8b7073/svn/halex-conduit-fittings-14607-64_100.jpg',
#     'https://images.thdstatic.com/productImages/007365b2-71d2-44f5-a139-d3171b8b7073/svn/halex-conduit-fittings-14607-64_145.jpg',
#     'https://images.thdstatic.com/productImages/007365b2-71d2-44f5-a139-d3171b8b7073/svn/halex-conduit-fittings-14607-64_300.jpg',
#     'https://images.thdstatic.com/productImages/007365b2-71d2-44f5-a139-d3171b8b7073/svn/halex-conduit-fittings-14607-64_400.jpg',
#     'https://images.thdstatic.com/productImages/007365b2-71d2-44f5-a139-d3171b8b7073/svn/halex-conduit-fittings-14607-64_600.jpg',
#     'https://images.thdstatic.com/productImages/007365b2-71d2-44f5-a139-d3171b8b7073/svn/halex-conduit-fittings-14607-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/Halex-3-4-in-Electrical-Metallic-Tube-EMT-Inside-Corner-Pull-Elbow-14607/100210850',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100210850&store_id=2414',
#   'model_number': '14607',
#   'brand': 'Halex',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 189,
#   'rating': 4.2727,
#   'reviews': 66,
#   'price': 8.72,
#   'delivery': {'free': True, 'free_delivery_threshold': False},
#   'pickup': {'quantity': 2, 'store_name': 'Bangor', 'distance': 0}},
#  {'position': 11,
#   'product_id': '100180512',
#   'title': '3/4 in. Electrical Metallic Tube (EMT) Type LB Set-Screw Conduit Body',
#   'thumbnails': [['https://images.thdstatic.com/productImages/ef954a38-e511-434d-9b56-3912a17b7a70/svn/halex-conduit-fittings-58707-64_65.jpg',
#     'https://images.thdstatic.com/productImages/ef954a38-e511-434d-9b56-3912a17b7a70/svn/halex-conduit-fittings-58707-64_100.jpg',
#     'https://images.thdstatic.com/productImages/ef954a38-e511-434d-9b56-3912a17b7a70/svn/halex-conduit-fittings-58707-64_145.jpg',
#     'https://images.thdstatic.com/productImages/ef954a38-e511-434d-9b56-3912a17b7a70/svn/halex-conduit-fittings-58707-64_300.jpg',
#     'https://images.thdstatic.com/productImages/ef954a38-e511-434d-9b56-3912a17b7a70/svn/halex-conduit-fittings-58707-64_400.jpg',
#     'https://images.thdstatic.com/productImages/ef954a38-e511-434d-9b56-3912a17b7a70/svn/halex-conduit-fittings-58707-64_600.jpg',
#     'https://images.thdstatic.com/productImages/ef954a38-e511-434d-9b56-3912a17b7a70/svn/halex-conduit-fittings-58707-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/Halex-3-4-in-Electrical-Metallic-Tube-EMT-Type-LB-Set-Screw-Conduit-Body-58707/100180512',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100180512&store_id=2414',
#   'model_number': '58707',
#   'brand': 'Halex',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 140,
#   'rating': 4.76,
#   'reviews': 25,
#   'price': 12.87,
#   'delivery': {'free': True, 'free_delivery_threshold': False},
#   'pickup': {'quantity': 0, 'store_name': 'Bangor', 'distance': 0}},
#  {'position': 12,
#   'product_id': '203776539',
#   'title': '1/2 in. EMT/Rigid Pull Elbow',
#   'thumbnails': [['https://images.thdstatic.com/productImages/3f95cdea-7a78-4350-87a7-097456e3b088/svn/halex-conduit-fittings-94505-64_65.jpg',
#     'https://images.thdstatic.com/productImages/3f95cdea-7a78-4350-87a7-097456e3b088/svn/halex-conduit-fittings-94505-64_100.jpg',
#     'https://images.thdstatic.com/productImages/3f95cdea-7a78-4350-87a7-097456e3b088/svn/halex-conduit-fittings-94505-64_145.jpg',
#     'https://images.thdstatic.com/productImages/3f95cdea-7a78-4350-87a7-097456e3b088/svn/halex-conduit-fittings-94505-64_300.jpg',
#     'https://images.thdstatic.com/productImages/3f95cdea-7a78-4350-87a7-097456e3b088/svn/halex-conduit-fittings-94505-64_400.jpg',
#     'https://images.thdstatic.com/productImages/3f95cdea-7a78-4350-87a7-097456e3b088/svn/halex-conduit-fittings-94505-64_600.jpg',
#     'https://images.thdstatic.com/productImages/3f95cdea-7a78-4350-87a7-097456e3b088/svn/halex-conduit-fittings-94505-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/Halex-1-2-in-EMT-Rigid-Pull-Elbow-94505/203776539',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=203776539&store_id=2414',
#   'model_number': '94505',
#   'brand': 'Halex',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 286,
#   'rating': 4.3333,
#   'reviews': 12,
#   'price': 3.59,
#   'delivery': {'free': True, 'free_delivery_threshold': False},
#   'pickup': {'quantity': 9, 'store_name': 'Bangor', 'distance': 0}},
#  {'position': 13,
#   'product_id': '100167184',
#   'title': '1/2 in. 90-Degree Electric Metallic Tube (EMT) Elbow',
#   'thumbnails': [['https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64405-64_65.jpg',
#     'https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64405-64_100.jpg',
#     'https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64405-64_145.jpg',
#     'https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64405-64_300.jpg',
#     'https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64405-64_400.jpg',
#     'https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64405-64_600.jpg',
#     'https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64405-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/Halex-1-2-in-90-Degree-Electric-Metallic-Tube-EMT-Elbow-64405/100167184',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100167184&store_id=2414',
#   'model_number': '64405',
#   'brand': 'Halex',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 377,
#   'rating': 4.9286,
#   'reviews': 14,
#   'price': 3.79,
#   'delivery': {'free': True, 'free_delivery_threshold': False},
#   'pickup': {'quantity': 25, 'store_name': 'Bangor', 'distance': 0}},
#  {'position': 14,
#   'product_id': '203671378',
#   'title': '1/2 in. EMT Set-Screw Coupling (5-Pack)',
#   'thumbnails': [['https://images.thdstatic.com/productImages/058bea3f-d639-4802-973f-9c4a853959ee/svn/raco-conduit-fittings-2022b5-64_65.jpg',
#     'https://images.thdstatic.com/productImages/058bea3f-d639-4802-973f-9c4a853959ee/svn/raco-conduit-fittings-2022b5-64_100.jpg',
#     'https://images.thdstatic.com/productImages/058bea3f-d639-4802-973f-9c4a853959ee/svn/raco-conduit-fittings-2022b5-64_145.jpg',
#     'https://images.thdstatic.com/productImages/058bea3f-d639-4802-973f-9c4a853959ee/svn/raco-conduit-fittings-2022b5-64_300.jpg',
#     'https://images.thdstatic.com/productImages/058bea3f-d639-4802-973f-9c4a853959ee/svn/raco-conduit-fittings-2022b5-64_400.jpg',
#     'https://images.thdstatic.com/productImages/058bea3f-d639-4802-973f-9c4a853959ee/svn/raco-conduit-fittings-2022b5-64_600.jpg',
#     'https://images.thdstatic.com/productImages/058bea3f-d639-4802-973f-9c4a853959ee/svn/raco-conduit-fittings-2022b5-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/RACO-1-2-in-EMT-Set-Screw-Coupling-5-Pack-2022B5/203671378',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=203671378&store_id=2414',
#   'model_number': '2022B5',
#   'brand': 'RACO',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 933,
#   'rating': 4.9167,
#   'reviews': 12,
#   'price': 2.5,
#   'delivery': {'free': True, 'free_delivery_threshold': False},
#   'pickup': {'free_ship_to_store': True}},
#  {'position': 15,
#   'product_id': '100138440',
#   'title': '3/4 in. 90-Degree Electric Metallic Tube (EMT) Elbow',
#   'thumbnails': [['https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64407-64_65.jpg',
#     'https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64407-64_100.jpg',
#     'https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64407-64_145.jpg',
#     'https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64407-64_300.jpg',
#     'https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64407-64_400.jpg',
#     'https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64407-64_600.jpg',
#     'https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64407-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/Halex-3-4-in-90-Degree-Electric-Metallic-Tube-EMT-Elbow-64407/100138440',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100138440&store_id=2414',
#   'model_number': '64407',
#   'brand': 'Halex',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 182,
#   'rating': 4.2308,
#   'reviews': 13,
#   'price': 5.26,
#   'delivery': {'free': True, 'free_delivery_threshold': False},
#   'pickup': {'quantity': 0, 'store_name': 'Bangor', 'distance': 0}},
#  {'position': 16,
#   'product_id': '100400410',
#   'title': '1-1/4 in. EMT Conduit',
#   'thumbnails': [['https://images.thdstatic.com/productImages/0e81c382-08ab-48f5-bdd9-4f2f99edb88b/svn/conduit-101576-64_65.jpg',
#     'https://images.thdstatic.com/productImages/0e81c382-08ab-48f5-bdd9-4f2f99edb88b/svn/conduit-101576-64_100.jpg',
#     'https://images.thdstatic.com/productImages/0e81c382-08ab-48f5-bdd9-4f2f99edb88b/svn/conduit-101576-64_145.jpg',
#     'https://images.thdstatic.com/productImages/0e81c382-08ab-48f5-bdd9-4f2f99edb88b/svn/conduit-101576-64_300.jpg',
#     'https://images.thdstatic.com/productImages/0e81c382-08ab-48f5-bdd9-4f2f99edb88b/svn/conduit-101576-64_400.jpg',
#     'https://images.thdstatic.com/productImages/0e81c382-08ab-48f5-bdd9-4f2f99edb88b/svn/conduit-101576-64_600.jpg',
#     'https://images.thdstatic.com/productImages/0e81c382-08ab-48f5-bdd9-4f2f99edb88b/svn/conduit-101576-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/1-1-4-in-EMT-Conduit-101576/100400410',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100400410&store_id=2414',
#   'model_number': '101576',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 493,
#   'rating': 4.597,
#   'reviews': 67,
#   'price': 33.96,
#   'delivery': {'schedule_delivery': True},
#   'pickup': {'quantity': 27, 'store_name': 'Bangor', 'distance': 0}},
#  {'position': 17,
#   'product_id': '100198412',
#   'title': '1 in. 90 Deg. Electrical Metallic Tube (EMT) Elbow',
#   'thumbnails': [['https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64410-64_65.jpg',
#     'https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64410-64_100.jpg',
#     'https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64410-64_145.jpg',
#     'https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64410-64_300.jpg',
#     'https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64410-64_400.jpg',
#     'https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64410-64_600.jpg',
#     'https://images.thdstatic.com/productImages/94ef45c7-c94c-46b9-8910-4941b92359b3/svn/halex-conduit-fittings-64410-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/Halex-1-in-90-Deg-Electrical-Metallic-Tube-EMT-Elbow-64410/100198412',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100198412&store_id=2414',
#   'model_number': '64410',
#   'brand': 'Halex',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 125,
#   'rating': 4.6829,
#   'reviews': 41,
#   'price': 7.58,
#   'delivery': {'schedule_delivery': True},
#   'pickup': {'quantity': 6, 'store_name': 'Bangor', 'distance': 0}},
#  {'position': 18,
#   'product_id': '100534518',
#   'title': '1/2 in. Electrical Metallic Tube (EMT) Rain Tight Coupling (5-Pack)',
#   'thumbnails': [['https://images.thdstatic.com/productImages/cbe08394-66bc-4803-9ef2-ee7d7674096b/svn/halex-conduit-fittings-26261-64_65.jpg',
#     'https://images.thdstatic.com/productImages/cbe08394-66bc-4803-9ef2-ee7d7674096b/svn/halex-conduit-fittings-26261-64_100.jpg',
#     'https://images.thdstatic.com/productImages/cbe08394-66bc-4803-9ef2-ee7d7674096b/svn/halex-conduit-fittings-26261-64_145.jpg',
#     'https://images.thdstatic.com/productImages/cbe08394-66bc-4803-9ef2-ee7d7674096b/svn/halex-conduit-fittings-26261-64_300.jpg',
#     'https://images.thdstatic.com/productImages/cbe08394-66bc-4803-9ef2-ee7d7674096b/svn/halex-conduit-fittings-26261-64_400.jpg',
#     'https://images.thdstatic.com/productImages/cbe08394-66bc-4803-9ef2-ee7d7674096b/svn/halex-conduit-fittings-26261-64_600.jpg',
#     'https://images.thdstatic.com/productImages/cbe08394-66bc-4803-9ef2-ee7d7674096b/svn/halex-conduit-fittings-26261-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/Halex-1-2-in-Electrical-Metallic-Tube-EMT-Rain-Tight-Coupling-5-Pack-26261/100534518',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100534518&store_id=2414',
#   'model_number': '26261',
#   'brand': 'Halex',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 355,
#   'rating': 4.625,
#   'reviews': 8,
#   'price': 4.94,
#   'delivery': {'free': True, 'free_delivery_threshold': False},
#   'pickup': {'quantity': 5, 'store_name': 'Bangor', 'distance': 0}},
#  {'position': 19,
#   'product_id': '100572360',
#   'title': '3/4 in. Electrical Metallic Tube (EMT) Rain Tight Connector',
#   'thumbnails': [['https://images.thdstatic.com/productImages/99753052-87a1-40bf-bfac-d8565ff7ae23/svn/conduit-fittings-26252-64_65.jpg',
#     'https://images.thdstatic.com/productImages/99753052-87a1-40bf-bfac-d8565ff7ae23/svn/conduit-fittings-26252-64_100.jpg',
#     'https://images.thdstatic.com/productImages/99753052-87a1-40bf-bfac-d8565ff7ae23/svn/conduit-fittings-26252-64_145.jpg',
#     'https://images.thdstatic.com/productImages/99753052-87a1-40bf-bfac-d8565ff7ae23/svn/conduit-fittings-26252-64_300.jpg',
#     'https://images.thdstatic.com/productImages/99753052-87a1-40bf-bfac-d8565ff7ae23/svn/conduit-fittings-26252-64_400.jpg',
#     'https://images.thdstatic.com/productImages/99753052-87a1-40bf-bfac-d8565ff7ae23/svn/conduit-fittings-26252-64_600.jpg',
#     'https://images.thdstatic.com/productImages/99753052-87a1-40bf-bfac-d8565ff7ae23/svn/conduit-fittings-26252-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/3-4-in-Electrical-Metallic-Tube-EMT-Rain-Tight-Connector-26252/100572360',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100572360&store_id=2414',
#   'model_number': '26252',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 205,
#   'rating': 4.3143,
#   'reviews': 35,
#   'price': 7.97,
#   'delivery': {'free': True, 'free_delivery_threshold': False},
#   'pickup': {'quantity': 7, 'store_name': 'Ellsworth', 'distance': 27}},
#  {'position': 20,
#   'product_id': '100121305',
#   'title': '1/2 in. Electrical Metallic Tube Inside Corner Pull Elbow',
#   'thumbnails': [['https://images.thdstatic.com/productImages/007365b2-71d2-44f5-a139-d3171b8b7073/svn/halex-conduit-fittings-14605-64_65.jpg',
#     'https://images.thdstatic.com/productImages/007365b2-71d2-44f5-a139-d3171b8b7073/svn/halex-conduit-fittings-14605-64_100.jpg',
#     'https://images.thdstatic.com/productImages/007365b2-71d2-44f5-a139-d3171b8b7073/svn/halex-conduit-fittings-14605-64_145.jpg',
#     'https://images.thdstatic.com/productImages/007365b2-71d2-44f5-a139-d3171b8b7073/svn/halex-conduit-fittings-14605-64_300.jpg',
#     'https://images.thdstatic.com/productImages/007365b2-71d2-44f5-a139-d3171b8b7073/svn/halex-conduit-fittings-14605-64_400.jpg',
#     'https://images.thdstatic.com/productImages/007365b2-71d2-44f5-a139-d3171b8b7073/svn/halex-conduit-fittings-14605-64_600.jpg',
#     'https://images.thdstatic.com/productImages/007365b2-71d2-44f5-a139-d3171b8b7073/svn/halex-conduit-fittings-14605-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/Halex-1-2-in-Electrical-Metallic-Tube-Inside-Corner-Pull-Elbow-14605/100121305',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100121305&store_id=2414',
#   'model_number': '14605',
#   'brand': 'Halex',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 534,
#   'rating': 4.4925,
#   'reviews': 134,
#   'price': 6.21,
#   'delivery': {'free': True, 'free_delivery_threshold': False},
#   'pickup': {'quantity': 42, 'store_name': 'Bangor', 'distance': 0}},
#  {'position': 21,
#   'product_id': '202068069',
#   'title': '1/2 in. x 5 ft. EMT (Electrical Metallic Tubing) - Steel',
#   'thumbnails': [['https://images.thdstatic.com/productImages/a570ff17-983d-4aa9-851f-3bef484ec9fd/svn/conduit-0550005000-64_65.jpg',
#     'https://images.thdstatic.com/productImages/a570ff17-983d-4aa9-851f-3bef484ec9fd/svn/conduit-0550005000-64_100.jpg',
#     'https://images.thdstatic.com/productImages/a570ff17-983d-4aa9-851f-3bef484ec9fd/svn/conduit-0550005000-64_145.jpg',
#     'https://images.thdstatic.com/productImages/a570ff17-983d-4aa9-851f-3bef484ec9fd/svn/conduit-0550005000-64_300.jpg',
#     'https://images.thdstatic.com/productImages/a570ff17-983d-4aa9-851f-3bef484ec9fd/svn/conduit-0550005000-64_400.jpg',
#     'https://images.thdstatic.com/productImages/a570ff17-983d-4aa9-851f-3bef484ec9fd/svn/conduit-0550005000-64_600.jpg',
#     'https://images.thdstatic.com/productImages/a570ff17-983d-4aa9-851f-3bef484ec9fd/svn/conduit-0550005000-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/1-2-in-x-5-ft-EMT-Electrical-Metallic-Tubing-Steel-0550005000/202068069',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=202068069&store_id=2414',
#   'model_number': '0550005000',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 305,
#   'rating': 4.8684,
#   'reviews': 76,
#   'price': 5.21,
#   'delivery': {'schedule_delivery': True},
#   'pickup': {'quantity': 22, 'store_name': 'Bangor', 'distance': 0}},
#  {'position': 22,
#   'product_id': '100559992',
#   'title': '1/2 in. Electrical Metallic Tube (EMT) Compression Connectors (5-Pack)',
#   'thumbnails': [['https://images.thdstatic.com/productImages/8b45a10a-cb08-40d6-be36-774df2bc751a/svn/conduit-fittings-26230-64_65.jpg',
#     'https://images.thdstatic.com/productImages/8b45a10a-cb08-40d6-be36-774df2bc751a/svn/conduit-fittings-26230-64_100.jpg',
#     'https://images.thdstatic.com/productImages/8b45a10a-cb08-40d6-be36-774df2bc751a/svn/conduit-fittings-26230-64_145.jpg',
#     'https://images.thdstatic.com/productImages/8b45a10a-cb08-40d6-be36-774df2bc751a/svn/conduit-fittings-26230-64_300.jpg',
#     'https://images.thdstatic.com/productImages/8b45a10a-cb08-40d6-be36-774df2bc751a/svn/conduit-fittings-26230-64_400.jpg',
#     'https://images.thdstatic.com/productImages/8b45a10a-cb08-40d6-be36-774df2bc751a/svn/conduit-fittings-26230-64_600.jpg',
#     'https://images.thdstatic.com/productImages/8b45a10a-cb08-40d6-be36-774df2bc751a/svn/conduit-fittings-26230-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/1-2-in-Electrical-Metallic-Tube-EMT-Compression-Connectors-5-Pack-26230/100559992',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100559992&store_id=2414',
#   'model_number': '26230',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 359,
#   'rating': 4.3714,
#   'reviews': 35,
#   'price': 3.56,
#   'delivery': {'free': True, 'free_delivery_threshold': False},
#   'pickup': {'quantity': 2, 'store_name': 'Bangor', 'distance': 0}},
#  {'position': 23,
#   'product_id': '100567593',
#   'title': '3/4 in. Electrical Metallic Tube (EMT) Rain Tight Connectors with Insulated Throat (3-Pack)',
#   'thumbnails': [['https://images.thdstatic.com/productImages/42223eb2-041b-43df-bdfc-4258c50d1802/svn/halex-conduit-fittings-29252-64_65.jpg',
#     'https://images.thdstatic.com/productImages/42223eb2-041b-43df-bdfc-4258c50d1802/svn/halex-conduit-fittings-29252-64_100.jpg',
#     'https://images.thdstatic.com/productImages/42223eb2-041b-43df-bdfc-4258c50d1802/svn/halex-conduit-fittings-29252-64_145.jpg',
#     'https://images.thdstatic.com/productImages/42223eb2-041b-43df-bdfc-4258c50d1802/svn/halex-conduit-fittings-29252-64_300.jpg',
#     'https://images.thdstatic.com/productImages/42223eb2-041b-43df-bdfc-4258c50d1802/svn/halex-conduit-fittings-29252-64_400.jpg',
#     'https://images.thdstatic.com/productImages/42223eb2-041b-43df-bdfc-4258c50d1802/svn/halex-conduit-fittings-29252-64_600.jpg',
#     'https://images.thdstatic.com/productImages/42223eb2-041b-43df-bdfc-4258c50d1802/svn/halex-conduit-fittings-29252-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/Halex-3-4-in-Electrical-Metallic-Tube-EMT-Rain-Tight-Connectors-with-Insulated-Throat-3-Pack-29252/100567593',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=100567593&store_id=2414',
#   'model_number': '29252',
#   'brand': 'Halex',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 79,
#   'rating': 4.3913,
#   'reviews': 23,
#   'price': 6.2,
#   'delivery': {'free': True, 'free_delivery_threshold': False},
#   'pickup': {'free_ship_to_store': True}},
#  {'position': 24,
#   'product_id': '203776545',
#   'title': '3/4 in. EMT/Rigid Pull Elbow',
#   'thumbnails': [['https://images.thdstatic.com/productImages/3f95cdea-7a78-4350-87a7-097456e3b088/svn/halex-conduit-fittings-94507-64_65.jpg',
#     'https://images.thdstatic.com/productImages/3f95cdea-7a78-4350-87a7-097456e3b088/svn/halex-conduit-fittings-94507-64_100.jpg',
#     'https://images.thdstatic.com/productImages/3f95cdea-7a78-4350-87a7-097456e3b088/svn/halex-conduit-fittings-94507-64_145.jpg',
#     'https://images.thdstatic.com/productImages/3f95cdea-7a78-4350-87a7-097456e3b088/svn/halex-conduit-fittings-94507-64_300.jpg',
#     'https://images.thdstatic.com/productImages/3f95cdea-7a78-4350-87a7-097456e3b088/svn/halex-conduit-fittings-94507-64_400.jpg',
#     'https://images.thdstatic.com/productImages/3f95cdea-7a78-4350-87a7-097456e3b088/svn/halex-conduit-fittings-94507-64_600.jpg',
#     'https://images.thdstatic.com/productImages/3f95cdea-7a78-4350-87a7-097456e3b088/svn/halex-conduit-fittings-94507-64_1000.jpg']],
#   'link': 'https://www.homedepot.com/p/Halex-3-4-in-EMT-Rigid-Pull-Elbow-94507/203776545',
#   'serpapi_link': 'https://serpapi.com/search.json?delivery_zip=04401&engine=home_depot_product&product_id=203776545&store_id=2414',
#   'model_number': '94507',
#   'brand': 'Halex',
#   'collection': 'https://www.homedepot.com',
#   'favorite': 116,
#   'rating': 4.2,
#   'reviews': 10,
#   'price': 5.44,
#   'delivery': {'free': True, 'free_delivery_threshold': False},
#   'pickup': {'quantity': 21, 'store_name': 'Waterville', 'distance': 47}}]

# %%
for p in products:
    print(p['product_id'])
    print(p['title'])
    print(p['price'])
    print('-------------------------------------------')
# Out:
# 100400409
# 1 in. x 10 ft. Electric Metallic Tube (EMT) Conduit
# 20.62
# -------------------------------------------
# 100400406
# 3/4 in. x 10 ft. Electric Metallic Tube (EMT) Conduit
# 11.91
# -------------------------------------------
# 100172548
# 1/2 in. Electrical Metallic Tube (EMT) 1-Hole Straps (25-Pack)
# 5.57
# -------------------------------------------
# 100400412
# 1-1/2 in. x 10 ft. Electric Metallic Tube (EMT) Conduit
# 40.0
# -------------------------------------------
# 100120544
# 1/2 in. Electrical Metallic Tube (EMT) EMT-to-Box Offset Set-Screw Connector
# 2.36
# -------------------------------------------
# 100137321
# 1/2 in. Electrical Metallic Tube (EMT) Set-Screw Connectors (5-Pack)
# 3.98
# -------------------------------------------
# 100581713
# 1/2 in. Electrical Metallic Tube (EMT) Rain Tight Connector (5-Pack)
# 5.97
# -------------------------------------------
# 100400411
# 2 in. x 10 ft. Electric Metallic Tube (EMT) Conduit
# 47.5
# -------------------------------------------
# 100160823
# 1/2 in. Standard Fitting Electrical Metallic Tube (EMT) 2-Hole Straps (25-Pack)
# 6.43
# -------------------------------------------
# 100210850
# 3/4 in. Electrical Metallic Tube (EMT) Inside Corner Pull Elbow
# 8.72
# -------------------------------------------
# 100180512
# 3/4 in. Electrical Metallic Tube (EMT) Type LB Set-Screw Conduit Body
# 12.87
# -------------------------------------------
# 203776539
# 1/2 in. EMT/Rigid Pull Elbow
# 3.59
# -------------------------------------------
# 100167184
# 1/2 in. 90-Degree Electric Metallic Tube (EMT) Elbow
# 3.79
# -------------------------------------------
# 203671378
# 1/2 in. EMT Set-Screw Coupling (5-Pack)
# 2.5
# -------------------------------------------
# 100138440
# 3/4 in. 90-Degree Electric Metallic Tube (EMT) Elbow
# 5.26
# -------------------------------------------
# 100400410
# 1-1/4 in. EMT Conduit
# 33.96
# -------------------------------------------
# 100198412
# 1 in. 90 Deg. Electrical Metallic Tube (EMT) Elbow
# 7.58
# -------------------------------------------
# 100534518
# 1/2 in. Electrical Metallic Tube (EMT) Rain Tight Coupling (5-Pack)
# 4.94
# -------------------------------------------
# 100572360
# 3/4 in. Electrical Metallic Tube (EMT) Rain Tight Connector
# 7.97
# -------------------------------------------
# 100121305
# 1/2 in. Electrical Metallic Tube Inside Corner Pull Elbow
# 6.21
# -------------------------------------------
# 202068069
# 1/2 in. x 5 ft. EMT (Electrical Metallic Tubing) - Steel
# 5.21
# -------------------------------------------
# 100559992
# 1/2 in. Electrical Metallic Tube (EMT) Compression Connectors (5-Pack)
# 3.56
# -------------------------------------------
# 100567593
# 3/4 in. Electrical Metallic Tube (EMT) Rain Tight Connectors with Insulated Throat (3-Pack)
# 6.2
# -------------------------------------------
# 203776545
# 3/4 in. EMT/Rigid Pull Elbow
# 5.44
# -------------------------------------------

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\kijah\\Documents\\Data_Bootcamp\\Estimator_Project\\Resources'

# %%
item = []
price =[]
ids =['100400405', '100400406', '100400409', '100400410', '100400411', '100400412']
for i in ids:
    for p in products:
        if p['product_id']==i:
            item.append(p['title'])
            print(p['product_id'])
            print(p['title'])
            print(p['price'])
            price.append(p['price'])
            print('-------------------------------------------')
# Out:
# 100400406
# 3/4 in. x 10 ft. Electric Metallic Tube (EMT) Conduit
# 11.91
# -------------------------------------------
# 100400409
# 1 in. x 10 ft. Electric Metallic Tube (EMT) Conduit
# 20.62
# -------------------------------------------
# 100400410
# 1-1/4 in. EMT Conduit
# 33.96
# -------------------------------------------
# 100400411
# 2 in. x 10 ft. Electric Metallic Tube (EMT) Conduit
# 47.5
# -------------------------------------------
# 100400412
# 1-1/2 in. x 10 ft. Electric Metallic Tube (EMT) Conduit
# 40.0
# -------------------------------------------

# %%
import pandas as pd

# %%
EMT = pd.DataFrame(item)
EMT
# Out:
#                                                    0
# 0  3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...
# 1  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...
# 2                              1-1/4 in. EMT Conduit
# 3  2 in. x 10 ft. Electric Metallic Tube (EMT) Co...
# 4  1-1/2 in. x 10 ft. Electric Metallic Tube (EMT...

# %%
PRICE = pd.DataFrame(price)
PRICE
# Out:
#        0
# 0  11.91
# 1  20.62
# 2  33.96
# 3  47.50
# 4  40.00

# %%
EMT_df = pd.DataFrame(list(zip(item, price)),
               columns =['ITEM', 'PRICE'])
EMT_df
# Out:
#                                                 ITEM  PRICE
# 0  3/4 in. x 10 ft. Electric Metallic Tube (EMT) ...  11.91
# 1  1 in. x 10 ft. Electric Metallic Tube (EMT) Co...  20.62
# 2                              1-1/4 in. EMT Conduit  33.96
# 3  2 in. x 10 ft. Electric Metallic Tube (EMT) Co...  47.50
# 4  1-1/2 in. x 10 ft. Electric Metallic Tube (EMT...  40.00

# %%
display(item, price)
# Out:
# ['3/4 in. x 10 ft. Electric Metallic Tube (EMT) Conduit',
#  '1 in. x 10 ft. Electric Metallic Tube (EMT) Conduit',
#  '1/2 in. Electrical Metallic Tube (EMT) Set-Screw Connectors (5-Pack)',
#  '1/2 in. EMT Set-Screw Coupling (5-Pack)']
# [11.91, 20.62, 3.98, 2.5]

# %%
[{'title': p["title"], 'price':p["price"]} for p in products if "1/2 in" in p["title"].lower()]
# Out:
# [{'title': '2-1/2 in. x 25 ft. Galflex RWS Metallic Armored Steel Flexible Conduit',
#   'price': 122.61},
#  {'title': '1-1/2 in. x 10 ft. Electric Metallic Tube (EMT) Conduit',
#   'price': 40.0},
#  {'title': '1/2 in. Flexible Elbow', 'price': 7.8},
#  {'title': '1/2 in. x 10 ft. Sch. 40 PVC Conduit', 'price': 10.9},
#  {'title': 'Solid Braid MFP Utility Rope - 1/2 in. x 10 ft., Black',
#   'price': 10.84},
#  {'title': '1/2 in. Electrical Metallic Tube (EMT) Set-Screw Connectors (5-Pack)',
#   'price': 3.98},
#  {'title': '1/2 in. x 10 ft. Wire Core Swivel Snap Green Flipline',
#   'price': 69.95},
#  {'title': '1/2 in. x 10 ft. Wire Core Flipline with Triple Lock Carabiner Core Lanyard Steel Wire Core Flip Line Kit',
#   'price': 69.99},
#  {'title': '1/2 in. Standard Fitting Electrical Metallic Tube (EMT) 2-Hole Straps (25-Pack)',
#   'price': 6.43},
#  {'title': '1/2 in. x 5 ft. EMT (Electrical Metallic Tubing) - Steel',
#   'price': 5.21},
#  {'title': '1/2 in. Electrical Metallic Tube Inside Corner Pull Elbow',
#   'price': 6.21},
#  {'title': '1/2 in. Electrical Metallic Tube (EMT) EMT-to-Box Offset Set-Screw Connector',
#   'price': 2.36},
#  {'title': '1/2 in. 90-Degree Electric Metallic Tube (EMT) Elbow',
#   'price': 3.79},
#  {'title': '1/2 in. x 3/8 in. x 10 ft. Grey Vinyl Foam Weatherseal Tape',
#   'price': 2.97},
#  {'title': '1/2 in. x 10 ft. Stainless Steel Garden Leader Hose',
#   'price': 28.99},
#  {'title': '1/2 in. Electrical Metallic Tube (EMT) 1-Hole Straps (25-Pack)',
#   'price': 5.57},
#  {'title': '1/2 in. x 10 ft. #4 Rebar', 'price': 7.46},
#  {'title': '1/2 in. x 10 ft. Vinyl L-Trim with Tear Strip', 'price': 6.2}]

# %%
import requests
from config import weather_api_key
from datetime import datetime
import pandas as pd
import time

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ab2c313e19328afc7bb030a55a7548c8&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"base":"stations","main":{"temp":83.8,"feels_like":86.7,"temp_min":78.28,"temp_max":87.42,"pressure":1015,"humidity":58},"visibility":10000,"wind":{"speed":16.11,"deg":200},"clouds":{"all":75},"dt":1658098249,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1658049737,"sunset":1658103485},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Create an endpoint URL for a city.

if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 83.8,
#   'feels_like': 86.7,
#   'temp_min': 78.28,
#   'temp_max': 87.42,
#   'pressure': 1015,
#   'humidity': 58},
#  'visibility': 10000,
#  'wind': {'speed': 16.11, 'deg': 200},
#  'clouds': {'all': 75},
#  'dt': 1658098249,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1658049737,
#   'sunset': 1658103485},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 87.42 58 75 16.11

# %%
boston_data["dt"]
# Out:
# 1658098249

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2022, 7, 17, 22, 50, 49)

# %%
city_data_to_load = "weather_data/cities.csv"
city_data_df = pd.read_csv(city_data_to_load)
city_data_df.head(10)
# Out:
#    City_ID      City Country                 Date      Lat       Lng  \
# 0        0    Zhuhai      CN  2022-07-17 15:01:15  22.2769  113.5678
# 1        1   Te Anau      NZ  2022-07-17 15:01:16 -45.4167  167.7167
# 2        2    Bethel      US  2022-07-17 15:01:16  41.3712  -73.4140
# 3        3     Seoul      KR  2022-07-17 15:01:17  37.5683  126.9778
# 4        4     Aktau      KZ  2022-07-17 15:01:17  43.6500   51.2000
# 5        5  Hermanus      ZA  2022-07-17 15:01:18 -34.4187   19.2345
# 6        6    Atuona      PF  2022-07-17 15:01:18  -9.8000 -139.0333
# 7        7  Khatanga      RU  2022-07-17 15:01:18  71.9667  102.5000
# 8        8  San Juan      AR  2022-07-17 15:00:45 -31.5375  -68.5364
# 9        9    Bonfim      BR  2022-07-17 15:01:19   3.0833  -59.9500
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     88.86        84          40       11.50
# 1     50.77        90         100        8.97
# 2     83.19        71          45        1.99
# 3     76.44        73          16        3.18
# 4     84.78        50           0       11.10
# 5     63.70        71           0       17.83
# 6     77.83        76          23       20.45
# 7     59.74        61         100        7.49
# 8     54.05        22           0       11.95
# 9     85.96        64          47        2.98

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Get today's date in seconds.
today = time.strftime("%x")
today
# Out:
# '07/17/22'
